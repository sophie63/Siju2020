# %% [markdown]
# # Import data and modules

# %%
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#plt.style.use("v_paper")
import deepdish as dd
from scipy.signal import savgol_filter

# %matplotlib inline

# %%
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 20

# %%
esum = dd.io.load("experiments_summary.h5")

lobe_data_w_vinegar = pd.DataFrame(esum["lobe_summary"])

lobe_activities = np.row_stack(esum["df_fs"])
lobe_data_w_vinegar["df_f"] = np.mean(lobe_activities[:, 31:35], 1)
lobe_data_w_vinegar["ΔF/F"] = np.mean(lobe_activities[:, 31:35], 1)
#lobe_data["pre_ΔF/F"] = np.mean((lobe_activities[:, 6:30]-np.min(lobe_activities[:, 6:30],1).reshape((4860,1))), 1)
lobe_data_w_vinegar["pre_ΔF/F"] = np.mean(np.abs(lobe_activities[:, 6:30]),1)

# %%
lobe_data_w_vinegar=lobe_data_w_vinegar.replace("1-Heptanone",'2-Heptanone')

# %%
plt.plot(lobe_activities[990].T)
plt.show()

# %%
lobe_data_w_vinegar
# Out:
#                                 experiment_id      stimulus  valence  \
# 0                  TH-58E02_090816_Citronella    Citronella     -1.0
# 1                  TH-58E02_090816_Citronella    Citronella     -1.0
# 2                  TH-58E02_090816_Citronella    Citronella     -1.0
# 3                  TH-58E02_090816_Citronella    Citronella     -1.0
# 4                  TH-58E02_090816_Citronella    Citronella     -1.0
# 5                  TH-58E02_090816_Citronella    Citronella     -1.0
# 6                  TH-58E02_090816_Citronella    Citronella     -1.0
# 7                  TH-58E02_090816_Citronella    Citronella     -1.0
# 8                  TH-58E02_090816_Citronella    Citronella     -1.0
# 9                  TH-58E02_090816_Citronella    Citronella     -1.0
# 10                 TH-58E02_090816_Citronella    Citronella     -1.0
# 11                 TH-58E02_090816_Citronella    Citronella     -1.0
# 12                 TH-58E02_090816_Citronella    Citronella     -1.0
# 13                 TH-58E02_090816_Citronella    Citronella     -1.0
# 14                 TH-58E02_090816_Citronella    Citronella     -1.0
# 15                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 16                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 17                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 18                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 19                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 20                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 21                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 22                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 23                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 24                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 25                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 26                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 27                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 28                    TH-58E02_090816_Vinegar       Vinegar      1.0
# 29                    TH-58E02_090816_Vinegar       Vinegar      1.0
# ...                                       ...           ...      ...
# 5880  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5881  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5882  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5883  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5884  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5885  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5886  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5887  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5888  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5889  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5890  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5891  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5892  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5893  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5894  200220_0_TH58E02G6f_ST00_0_high_Vinegar  high_Vinegar      1.0
# 5895  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5896  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5897  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5898  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5899  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5900  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5901  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5902  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5903  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5904  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5905  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5906  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5907  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5908  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
# 5909  200220_0_TH58E02G6f_ST00_1_high_Vinegar  high_Vinegar      1.0
#
#       dorsal_to_ventral  hours_starved  order_presented  virgin lobe  \
# 0                  True              0                0   False   a1
# 1                  True              0                0   False   a2
# 2                  True              0                0   False   a3
# 3                  True              0                0   False  ap1
# 4                  True              0                0   False  ap2
# 5                  True              0                0   False  ap3
# 6                  True              0                0   False   b1
# 7                  True              0                0   False   b2
# 8                  True              0                0   False  bp1
# 9                  True              0                0   False  bp2
# 10                 True              0                0   False   g1
# 11                 True              0                0   False   g2
# 12                 True              0                0   False   g3
# 13                 True              0                0   False   g4
# 14                 True              0                0   False   g5
# 15                False              0                0   False   a1
# 16                False              0                0   False   a2
# 17                False              0                0   False   a3
# 18                False              0                0   False  ap1
# 19                False              0                0   False  ap2
# 20                False              0                0   False  ap3
# 21                False              0                0   False   b1
# 22                False              0                0   False   b2
# 23                False              0                0   False  bp1
# 24                False              0                0   False  bp2
# 25                False              0                0   False   g1
# 26                False              0                0   False   g2
# 27                False              0                0   False   g3
# 28                False              0                0   False   g4
# 29                False              0                0   False   g5
# ...                 ...            ...              ...     ...  ...
# 5880              False              0                0   False   a1
# 5881              False              0                0   False   a2
# 5882              False              0                0   False   a3
# 5883              False              0                0   False  ap1
# 5884              False              0                0   False  ap2
# 5885              False              0                0   False  ap3
# 5886              False              0                0   False   b1
# 5887              False              0                0   False   b2
# 5888              False              0                0   False  bp1
# 5889              False              0                0   False  bp2
# 5890              False              0                0   False   g1
# 5891              False              0                0   False   g2
# 5892              False              0                0   False   g3
# 5893              False              0                0   False   g4
# 5894              False              0                0   False   g5
# 5895               True              0                0   False   a1
# 5896               True              0                0   False   a2
# 5897               True              0                0   False   a3
# 5898               True              0                0   False  ap1
# 5899               True              0                0   False  ap2
# 5900               True              0                0   False  ap3
# 5901               True              0                0   False   b1
# 5902               True              0                0   False   b2
# 5903               True              0                0   False  bp1
# 5904               True              0                0   False  bp2
# 5905               True              0                0   False   g1
# 5906               True              0                0   False   g2
# 5907               True              0                0   False   g3
# 5908               True              0                0   False   g4
# 5909               True              0                0   False   g5
#
#       adaptation   pre_std  single_pre_std  single_pre_amp  response_std  \
# 0       0.007500  0.030948        0.170519        0.131845      0.181160
# 1      -0.010356  0.020711        0.159267        0.217365      0.157602
# 2      -0.027494  0.026490        0.115774        0.135316      0.343259
# 3       0.026010  0.041217        0.189557        0.139339      0.258084
# 4       0.000798  0.041212        0.239678        0.180607      0.268255
# 5      -0.027261  0.027549        0.175694        0.167012      0.273081
# 6      -0.002421  0.034793        0.142184        0.149589      0.279171
# 7       0.009707  0.068314        0.164304        0.334083      0.237697
# 8       0.011100  0.035849        0.108224        0.074150      0.156123
# 9      -0.018522  0.125490        0.196558        0.274213      0.287852
# 10     -0.007203  0.021038        0.137794        0.110233      0.107834
# 11      0.013759  0.035213        0.127957        0.183020      0.160005
# 12      0.019837  0.031795        0.123358        0.243052      0.331029
# 13      0.017980  0.060067        0.120468        0.197971      0.277750
# 14      0.003185  0.037449        0.123727        0.241436      0.191287
# 15      0.006003  0.050667        0.157195        0.165801      0.252064
# 16      0.000359  0.020669        0.134403        0.139700      0.120660
# 17     -0.003105  0.079580        0.253704        0.259550      0.265727
# 18      0.010708  0.048584        0.176255        0.137886      0.254735
# 19     -0.002916  0.037129        0.182894        0.231408      0.215393
# 20      0.014512  0.028553        0.167612        0.177772      0.153468
# 21     -0.049736  0.037839        0.165565        0.207894      0.346701
# 22     -0.034875  0.067813        0.217638        0.250736      0.467848
# 5905  2020-02-20 00:00:000          0          NaN  0.488242  0.488242
# 5906  2020-02-20 00:00:000          0          NaN  0.503006  0.503006
# 5907  2020-02-20 00:00:000          0          NaN  1.065506  1.065506
# 5908  2020-02-20 00:00:000          0          NaN  2.573360  2.573360
# 5909  2020-02-20 00:00:000          0          NaN  0.653263  0.653263
#
#           ΔF/F  pre_ΔF/F
# 0     0.341723  0.021723
# 1     0.230774  0.017802
# 2     1.023435  0.020086
# 3     0.476658  0.028166
# 4     0.412485  0.034686
# 5     0.226218  0.023734
# 6     0.624777  0.017043
# 7     0.990563  0.042188
# 8     0.586997  0.020067
# 9     0.837626  0.021509
# 10    0.051930  0.017589
# 11    0.292853  0.023531
# 12    0.707377  0.021163
# 13    0.790165  0.018434
# 14    0.337667  0.013740
# 15    0.292965  0.026501
# 16    0.294050  0.017455
# 17    0.007066  0.082038
# 18    0.090697  0.042378
# 19    0.369337  0.036962
# 20    0.113761  0.022836
# 21    1.009870  0.034362
# 22    1.265631  0.027185
# 23    0.717279  0.019635
# 24    1.066102  0.034498
# 25    0.141343  0.017833
# 26    0.118467  0.016327
# 27    0.950393  0.019538
# 28    1.152206  0.017092
# 29    0.189086  0.015647
# ...        ...       ...
# 5880  0.551961  0.055998
# 5881  1.438851  0.049405
# 5882  1.213167  0.050587
# 5883  1.105155  0.063171
# 5884  1.248200  0.056271
# 5885  1.291928  0.032390
# 5886  2.020796  0.076290
# 5887  1.477886  0.039695
# 5888  2.181922  0.070133
# 5889  1.372731  0.031136
# 5890  0.666373  0.031502
# 5891  0.830206  0.080532
# 5892  1.288106  0.069282
# 5893  1.940565  0.025620
# 5894  0.499865  0.019307
# 5895  0.496360  0.078428
# 5896  0.823168  0.041230
# 5897  0.595722  0.074735
# 5898  0.892770  0.132588
# 5899  1.072320  0.031983
# 5900  3.074082  0.031024
# 5901  2.710551  0.071869
# 5902  1.668044  0.061196
# 5903  2.402323  0.046595
# 5904  2.043902  0.049203
# 5905  0.488242  0.072854
# 5906  0.503006  0.164708
# 5907  1.065506  0.102147
# 5908  2.573360  0.041566
# 5909  0.653263  0.021787
#
# [5910 rows x 20 columns]

# %%
Lobes=lobe_data_w_vinegar.lobe.unique()
Lobes
# Out:
# array(['a1', 'a2', 'a3', 'ap1', 'ap2', 'ap3', 'b1', 'b2', 'bp1', 'bp2',
#        'g1', 'g2', 'g3', 'g4', 'g5'], dtype=object)

# %%
LobesGreek=['α1', 'α2', 'α3', "α'1", "α'2", "α'3", 'β1', 'β2', "β'1", "β'2",
       'γ1', 'γ2', 'γ3', 'γ4', 'γ5']

dictionaryGreek = dict(zip(Lobes, LobesGreek))

lobe_data_w_vinegar["greek_lobe"] = [dictionaryGreek[l] for l in lobe_data_w_vinegar.lobe]

# %% [markdown]
# Other pre-requisites

# %%
lobe_data_w_vinegar["hours starved"]=lobe_data_w_vinegar["hours_starved"]

# %%
valence_map = {
"high_Vinegar": np.nan,
"Vinegar": '1',
"Yeast": '1',
"Isoamylacetate": np.nan,
"2-Heptanone": np.nan,
"1-Heptanone": np.nan,
    
"cVA": np.nan,
        "3Octanol": '-1',
        "Ethanol": np.nan,

"1-Hexanol": np.nan,
"Peppermint": '-1',
"4MCH": '-1',
"Citronella": '-1',
"Geosmin": '-1',
}

lobe_data_w_vinegar["valence"] = [valence_map[s] for s in lobe_data_w_vinegar.stimulus]

# %%
lobe_data=lobe_data_w_vinegar[lobe_data_w_vinegar["stimulus"]!="high_Vinegar"]

# %% [markdown]
# # Plot all the data

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
b = sns.boxplot(x="greek_lobe", y="ΔF/F",data=lobe_data)

b.set(xlabel='Compartment')

for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('white')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')
plt.yticks([0,1,2,3])  
plt.ylim([-0.5,4.1])
plt.savefig('AllLobesDFF.svg')
    
plt.show()

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
b = sns.boxplot(x="stimulus", y="ΔF/F",data=lobe_data)

b.set(xlabel='Stimulus')

for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('purple')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')
plt.yticks([0,1,2,3])  
plt.ylim([-0.5,4.1])
b.set_xticklabels(b.get_xticklabels(),rotation=90)
#b.set_yticklabels(b.get_yticklabels(),rotation=90)
plt.savefig('AllStimuliDFF.svg')
plt.savefig('AllStimuliDFF.png')
    
plt.show()

# %%
Response_std=np.zeros((15))
for i in range(15):
    Response_std[i]=np.std(lobe_data[lobe_data["lobe"]==Lobes[i]]["df_f"])

# %%
Preamp_std=np.zeros((15))
for i in range(15):
    Preamp_std[i]=np.std(lobe_data[lobe_data["lobe"]==Lobes[i]]["pre_ΔF/F"])

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
b = sns.boxplot(x="greek_lobe", y="single_pre_amp",data=lobe_data)
b.set(xlabel='Compartment',ylabel='Average amplitude ΔF/F')

for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('white')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')

plt.savefig('LobesAvpreAmplNew.svg')
plt.savefig('LobesAvpreAmplNew.png')
plt.show()

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
plt.scatter(range(15),Preamp_std,c='g', marker='o',s=150,label='pre-stimulus signal')
axis=plt.scatter(range(15),Response_std,c='m', marker='o',s=150, label='odor response')
plt.xticks(range(15),
           LobesGreek)
plt.xlabel('MB Compartment')
plt.ylabel('Standard deviation')
plt.legend()

plt.savefig('LobesStd.svg')
plt.savefig('LobesStd.png')

plt.show()

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=3)

b = sns.catplot(x="hours starved", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data, linewidth=2, kind="box",palette='YlOrRd',height=6, aspect=.7)

#.set_titles("{col_name} {col_var}")
#b.set(xlabel="hours starved")
#b.set(ylabel="ΔF/F")
b.set_titles("{col_name}") # set new labels
plt.yticks([0,2])

plt.savefig('LobesStarvation.svg')

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=3)

b = sns.catplot(x="valence", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data,palette='seismic',linewidth=2, kind="box",height=6, aspect=.7)

b.set_titles("{col_name}") # set new labels
plt.yticks([0,2])
plt.savefig('LobesValence.svg')

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=3)

b = sns.catplot(x="hours starved", y="single_pre_amp", col="greek_lobe",col_wrap=5,data=lobe_data,linewidth=2, kind="box",height=6, aspect=.7)

b.set_titles("{col_name}") # set new labels
plt.yticks()
plt.savefig('SpontaneousStarvation.svg')
plt.savefig('SpontaneousStarvation.png')

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=3)

b = sns.catplot(x="virgin", y="single_pre_amp", col="greek_lobe",col_wrap=5,data=lobe_data[lobe_data['stimulus']=='cVA'],linewidth=2, kind="box",height=6, aspect=.7)

b.set_titles("{col_name}") # set new labels
#plt.yticks([0,0.2])
plt.savefig('SpontaneousMated.svg')
plt.savefig('SpontaneousMated.png')

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=3)

b = sns.catplot(x="dorsal_to_ventral", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data,linewidth=2, kind="box",height=6, aspect=.7)

b.set_titles("{col_name}") # set new labels
plt.yticks([0,2])
plt.savefig('LobesDirection.svg')
plt.savefig('LobesDirection.png')

# %%
lobe_data["adaptnorm"] = -lobe_data.adaptation/lobe_data.df_mean

lobe_data.adaptnorm[lobe_data.df_mean<0.3]=np.nan
# Out:
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
lobe_data["adaptnormperc"]=lobe_data.adaptnorm*100

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
b = sns.boxplot(x="greek_lobe", y="adaptnormperc",data=lobe_data)
b.set(xlabel='Compartment',ylabel='% Adaptation/odor presentation')

for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('white')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')
b.xaxis.set_ticks_position('top')
b.xaxis.set_label_position('top')
b.set(ylim=(-120, 100))
plt.yticks([-50, 0,50])
plt.savefig('Adaptation.svg')            
plt.show()

# %%
lobe_data_vin=lobe_data_w_vinegar[lobe_data_w_vinegar.stimulus.isin({"Vinegar","high_Vinegar"})]
lobe_data_vin_starved=lobe_data_vin[lobe_data_vin.hours_starved.isin({24,48})]

sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=2)


b = sns.catplot(x="stimulus", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data_vin,linewidth=2, height=6, aspect=.7,kind='box')

b.set_titles("{col_name}") # set new labels
plt.subplots_adjust(top=0.9)
b.fig.suptitle('All')
plt.yticks([0,2])
plt.savefig('LobesHighvsLowVinegar.svg')

# %%
lobe_data_vin=lobe_data_w_vinegar[lobe_data_w_vinegar.stimulus.isin({"Vinegar","high_Vinegar"})]
lobe_data_vin_starved=lobe_data_vin[lobe_data_vin.hours_starved.isin({24,48})]
lobe_data_vin["Starved"]=True
lobe_data_vin["Starved"][lobe_data_vin.hours_starved==0]=False

sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=2)


b = sns.catplot(x="Starved", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data_vin,linewidth=2, height=6, aspect=.7,kind='box')

b.set_titles("{col_name}") # set new labels
plt.subplots_adjust(top=0.9)
b.fig.suptitle('All')
plt.yticks([0,2])
plt.savefig('StarvedVsFedVinegar.svg')
# Out:
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\aimon\Anaconda3\lib\site-packages\pandas\core\generic.py:7626: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\aimon\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3267: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
lobe_data_vin=lobe_data_w_vinegar[lobe_data_w_vinegar.stimulus.isin({"Vinegar","high_Vinegar"})]
lobe_data_vin_starved=lobe_data_vin[lobe_data_vin.hours_starved.isin({24,48})]

sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=2)


b = sns.catplot(x="stimulus", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data_vin_starved,linewidth=2, height=6, aspect=.7,kind='box')

b.set_titles("{col_name}") # set new labels
plt.yticks([0,2])
plt.subplots_adjust(top=0.9)
b.fig.suptitle('Starved')
plt.savefig('LobesHighvsLowVinegarStarved.svg')

# %%
lobe_data_vin=lobe_data_w_vinegar[lobe_data_w_vinegar.stimulus.isin({"Vinegar","high_Vinegar"})]
lobe_data_vin_fed=lobe_data_vin[lobe_data_vin.hours_starved.isin({0})]

sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=2)


b = sns.catplot(x="stimulus", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data_vin_fed,linewidth=2, height=6, aspect=.7,kind='box')

b.set_titles("{col_name}") # set new labels
plt.yticks([0,2])
plt.subplots_adjust(top=0.9)
b.fig.suptitle('Fed')
plt.savefig('LobesHighvsLowVinegarFed.svg')

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=2)

#lobe_data_end=lobe_data[1:4900]
data_cva=lobe_data[lobe_data['stimulus']=='cVA']
data_cva_mated=data_cva[data_cva['virgin']==False]
data_cva_mated=data_cva_mated.fillna(False)

b = sns.catplot(x="mated_single", y="ΔF/F", col="greek_lobe",col_wrap=5,data=data_cva_mated,palette='rainbow',linewidth=2, height=6, aspect=.7)

b.set_titles("{col_name}") # set new labels
plt.yticks([0,2])
plt.savefig('LobesMatedSingle.svg')
plt.savefig('LobesMatedSingle.png')

# %%
len(lobe_data[lobe_data['stimulus']=='cVA'])
# Out:
# 1020

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=3)


b = sns.catplot(x="virgin", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data[lobe_data['stimulus']=='cVA'],palette='rainbow',linewidth=2, height=6, aspect=.7,kind='box')

b.set_titles("{col_name}") # set new labels

plt.yticks([0,2])
plt.savefig('LobesMated.svg')
plt.savefig('LobesMated.png')

# %%
data_tastequi=pd.read_excel("Taste_data.xlsx",'quinine').transpose()

data_tastesuc=pd.read_excel("Taste_data.xlsx",'sucrose').transpose()

db1=data_tastesuc.stack().reset_index()

db2=data_tastequi.stack().reset_index()

#taste_mean=pd.concat([suc_mean,qui_mean], ignore_index=True, sort=False)

db2['taste']='quinine'
db1['taste']='sucrose'

data_taste = pd.concat([db1, db2], ignore_index=True, sort=False)

data_taste.columns = ['lobe', 'num','df_f','taste']

data_taste['df_f_norm']=0
data_taste['norm']=0

Nums=[170,110,29,177,176,173,188,151,174,175,168,170]

for taste in ['quinine', 'sucrose']:
    for i in Nums:
        if any((data_taste['num']==i) & (data_taste['taste']==taste)):
            subData=data_taste[data_taste['num']==i][data_taste['taste']==taste]
            Norm=np.float(subData[subData['lobe']=='Mean'].df_f)
            data_taste.loc[(data_taste['num']==i) & (data_taste['taste']==taste),'norm']=Norm


data_taste.df_f_norm=data_taste.df_f-data_taste.norm
# Out:
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=2)


b = sns.catplot(x="taste", y="df_f", col="lobe",col_wrap=5,data=data_taste,linewidth=2, height=6, aspect=.7,palette='RdBu')

b.set_titles("{col_name}") # set new labels
#plt.ylim([-3,6])
plt.savefig('DataTaste.svg')

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=2)


b = sns.catplot(x="taste", y="df_f_norm", col="lobe",col_wrap=5,data=data_taste,linewidth=2, height=6, aspect=.7,kind='box',palette='RdBu')

b.set_titles("{col_name}") # set new labels
plt.ylim([-0.05,0.25])
plt.savefig('DataTaste.svg')

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=3)

b = sns.catplot(x="dorsal_to_ventral", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data,palette='rainbow',linewidth=2, kind="box",height=6, aspect=.7)

b.set_titles("{col_name}") # set new labels
plt.yticks([0,2])
plt.savefig('LobesDirection.svg')

# %%
data=pd.read_csv("ResultWalk.txt",
           delim_whitespace=True,
           skipinitialspace=True,
                header=None)

# %%
WalkRsq=np.zeros((15,7))
WalkBeta=np.zeros((15,7))
for j in range(7):
    for i in range(15):
        WalkRsq[i,j]=data[j][2+i*3]
        WalkBeta[i,j]=data[j][1+i*3]

# %%
DataWalk=pd.DataFrame(WalkRsq.T,columns=LobesGreek)
DataWalkbetas=pd.DataFrame(WalkBeta.T,columns=LobesGreek)

# %%
import matplotlib as mpl
mpl.rcParams['lines.markersize'] =200
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
b = sns.stripplot(data=DataWalk, color='black',jitter=False,size=10)
b.set(xlabel='Compartment',ylabel='R square')

b.xaxis.set_ticks_position('top')
b.xaxis.set_label_position('top')
plt.savefig('WalkSqr.svg')      
plt.savefig('WalkSqr.png')
plt.show()

# %%
import matplotlib as mpl
mpl.rcParams['lines.markersize'] =200
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
b = sns.stripplot(data=DataWalkbetas, color='black',jitter=False,size=10)
b.set(xlabel='Compartment',ylabel='Correlation coef.')

b.xaxis.set_ticks_position('top')
b.xaxis.set_label_position('top')
plt.savefig('WalkBetas.svg')      
plt.savefig('WalkBetas.png')  
plt.show()

# %%
np.mean(DataWalkbetas.values,0)
# Out:
# array([0.01185791, 0.00786684, 0.00831484, 0.01032995, 0.00741971,
#        0.01087686, 0.02580228, 0.02794888, 0.02756843, 0.04469564,
#        0.0187518 , 0.01637661, 0.0456082 , 0.05365562, 0.03737648])

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})

sns.set_context("notebook",font_scale=3)

b = sns.catplot(x="dorsal_to_ventral", y="ΔF/F", col="greek_lobe",col_wrap=5,data=lobe_data,palette='rainbow',linewidth=2, kind="box",height=6, aspect=.7)

b.set_titles("{col_name}") # set new labels
plt.yticks([0,2])
plt.savefig('LobesDirection.svg')

# %%
#CI
#import statsmodels.stats.api as sms
#sms.DescrStatsW(lobe_data[lobe_data.lobe=="a1"]["adaptnormperc"]).tconfint_mean()
