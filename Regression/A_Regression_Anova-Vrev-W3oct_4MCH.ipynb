# %% [markdown]
# Import all we need and prepare data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import deepdish as dd
from scipy.signal import savgol_filter
from matplotlib.lines import Line2D
# %matplotlib inline
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
import cmocean

# %%
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 20

# %%
import statsmodels.formula.api as smf

from statsmodels.stats.anova import anova_lm

import statsmodels.api as smapi

import seaborn as sns

import statsmodels as sm

# %%
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.model_selection import cross_val_score

class SMFormulaWrapper(BaseEstimator, RegressorMixin):
    """ A sklearn-style wrapper for formula-based statsmodels regressors """
    def __init__(self, model_class, formula):
        self.model_class = model_class
        self.formula = formula
    def fit(self, X, y=None):
        self.model_ = self.model_class(self.formula, data=X)
        self.results_ = self.model_.fit()
    def predict(self, X):
        return self.results_.predict(X)

# %%
esum = dd.io.load("experiments_summary.h5")

lobe_data = pd.DataFrame(esum["lobe_summary"])

lobe_activities = np.row_stack(esum["df_fs"])

lobe_data["df_f"] = np.mean(lobe_activities[:, 31:35], 1)

# %%
lobe_data=pd.DataFrame(lobe_data)

# %%
len(lobe_activities[0])
# Out:
# 80

# %%
plt.plot(lobe_activities.T)
plt.show()

# %%
valence_map = {
"Vinegar": 1,
"high_Vinegar":np.nan,
"Yeast": 1,
"Isoamylacetate": np.nan,
"2-Heptanone": np.nan,
"1-Heptanone": np.nan,
    
"cVA": np.nan,
"3Octanol": -1,
"Ethanol": np.nan,

"1-Hexanol": np.nan,
"Peppermint": -1,
"4MCH": -1,
"Citronella": -1,
"Geosmin": -1,
}

lobe_data["valence"] = [valence_map[s] for s in lobe_data.stimulus]

# %%
lobes = lobe_data.lobe.unique()
n_lobes = len(lobes)
n_time = lobe_activities.shape[1]

# %%
Lobes=lobe_data.lobe.unique()

# %%
Stimuli=lobe_data.stimulus.unique()

# %%
Flies=lobe_data.fly_id.unique()

# %%
FedFlies=lobe_data[lobe_data["hours_starved"]==0].fly_id.unique()

# %%
len(Flies)
# Out:
# 201

# %%
len(FedFlies)
# Out:
# 90

# %%
165-62
# Out:
# 103

# %%
# Contrasts
lobe_data['dorsal_to_ventral_val']=[int(s) for s in lobe_data.dorsal_to_ventral]
lobe_data['virgin_val']=[int(s) for s in lobe_data.virgin]
# Normalization
lobe_data['starved']=[int(s)/24 for s in lobe_data.hours_starved]

# %%
LobesGreek=['α1', 'α2', 'α3', "α'1", "α'2", "α'3", 'β1', 'β2', "β'1", "β'2",
       'γ1', 'γ2', 'γ3', 'γ4', 'γ5']
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 16

# %%
lobe_data=lobe_data.replace("1-Heptanone",'2-Heptanone')

# %%
lobe_data=lobe_data[lobe_data["stimulus"]!="high_Vinegar"]

# %%
#lobe_data=lobe_data[lobe_data["stimulus"]!="cVA"]

# %%
Flies=lobe_data.fly_id.unique()

# %%
len(Flies)
# Out:
# 185

# %%
lobe_data.stimulus.unique()
# Out:
# array(['Citronella', 'Vinegar', 'Yeast', 'Peppermint', '2-Heptanone',
#        '1-Hexanol', 'cVA', 'Geosmin', '4MCH', 'Isoamylacetate',
#        '3Octanol', 'Ethanol'], dtype=object)

# %% [markdown]
# # Finding good regression models

# %% [markdown]
# ## Deciding if using individual flies is meaningful

# %% [markdown]
# As there are just a couple of odors per fly, adding fly ID is likely to overfit.

# %%
result = smf.ols(formula="df_f ~ lobe+stimulus+order_presented+dorsal_to_ventral_val+fly_id+starved", data=lobe_data).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     15.29
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):               0.00
# Time:                        16:37:05   Log-Likelihood:                -2690.9
# No. Observations:                5430   AIC:                             5804.
# Df Residuals:                    5219   BIC:                             7196.
# Df Model:                         210
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.2445      0.128      1.910      0.056      -0.006       0.496
# lobe[T.a2]                         0.2088      0.030      6.933      0.000       0.150       0.268
# lobe[T.a3]                         0.2453      0.030      8.145      0.000       0.186       0.304
# lobe[T.ap1]                        0.3101      0.030     10.299      0.000       0.251       0.369
# lobe[T.ap2]                        0.2012      0.030      6.681      0.000       0.142       0.260
# lobe[T.ap3]                        0.6560      0.030     21.784      0.000       0.597       0.715
# lobe[T.b1]                         0.3267      0.030     10.850      0.000       0.268       0.386
# lobe[T.b2]                         0.5223      0.030     17.344      0.000       0.463       0.581
# lobe[T.bp1]                        0.9422      0.030     31.288      0.000       0.883       1.001
# lobe[T.bp2]                        0.5145      0.030     17.085      0.000       0.455       0.574
# lobe[T.g1]                         0.2565      0.030      8.519      0.000       0.197       0.316
# lobe[T.g2]                         0.3322      0.030     11.032      0.000       0.273       0.391
# lobe[T.g3]                         0.6166      0.030     20.477      0.000       0.558       0.676
# lobe[T.g4]                         0.4541      0.030     15.081      0.000       0.395       0.513
# lobe[T.g5]                         0.0278      0.030      0.923      0.356      -0.031       0.087
# stimulus[T.2-Heptanone]           -0.1039      0.080     -1.292      0.196      -0.262       0.054
# stimulus[T.3Octanol]               0.0334      0.093      0.358      0.720      -0.149       0.216
# stimulus[T.4MCH]                   0.1653      0.090      1.832      0.067      -0.012       0.342
# stimulus[T.Citronella]            -0.1306      0.107     -1.224      0.221      -0.340       0.079
# stimulus[T.Ethanol]               -0.0982      0.100     -0.985      0.325      -0.294       0.097
# stimulus[T.Geosmin]               -0.2496      0.102     -2.440      0.015      -0.450      -0.049
# stimulus[T.Isoamylacetate]         0.0067      0.073      0.092      0.927      -0.137       0.151
# stimulus[T.Peppermint]            -0.0047      0.068     -0.068      0.946      -0.138       0.129
# stimulus[T.Vinegar]               -0.0243      0.103     -0.236      0.813      -0.226       0.177
# stimulus[T.Yeast]                  0.0479      0.103      0.467      0.641      -0.153       0.249
# stimulus[T.cVA]                   -0.1067      0.123     -0.865      0.387      -0.349       0.135
# fly_id[T.2016-08-10 00:00:000]    -0.2608      0.106     -2.451      0.014      -0.469      -0.052
# fly_id[T.2016-08-11 00:00:000]    -0.2281      0.106     -2.145      0.032      -0.437      -0.020
# fly_id[T.2016-08-16 00:00:000]     0.2224      0.106      2.091      0.037       0.014       0.431
# fly_id[T.2016-08-17 00:00:000]    -0.1389      0.105     -1.327      0.184      -0.344       0.066
# fly_id[T.2016-08-19 00:00:000]     0.1760      0.132      1.330      0.184      -0.083       0.435
# fly_id[T.2016-08-23 00:00:000]    -0.1369      0.106     -1.286      0.198      -0.345       0.072
# fly_id[T.2016-10-17 00:00:000]    -0.0810      0.107     -0.760      0.447      -0.290       0.128
# fly_id[T.2016-11-07 00:00:000]    -0.2857      0.110     -2.606      0.009      -0.501      -0.071
# fly_id[T.2016-11-28 00:00:000]     0.0468      0.132      0.354      0.724      -0.213       0.306
# fly_id[T.2016-12-01 00:00:000]    -0.2860      0.107     -2.684      0.007      -0.495      -0.077
# fly_id[T.2017-02-03 00:00:000]    -0.0664      0.107     -0.623      0.533      -0.275       0.143
# fly_id[T.2017-02-06 00:00:000]    -0.1395      0.130     -1.074      0.283      -0.394       0.115
# fly_id[T.2017-02-10 00:00:000]    -0.1928      0.107     -1.809      0.071      -0.402       0.016
# fly_id[T.2017-02-13 00:00:000]    -0.2292      0.110     -2.090      0.037      -0.444      -0.014
# fly_id[T.2017-03-02 00:00:000]     0.1716      0.120      1.436      0.151      -0.063       0.406
# fly_id[T.2017-03-03 00:00:000]     0.0365      0.121      0.301      0.763      -0.201       0.274
# fly_id[T.2017-03-03 00:00:001]     0.4598      0.121      3.800      0.000       0.223       0.697
# fly_id[T.2017-03-09 00:00:000]    -0.0540      0.119     -0.455      0.649      -0.287       0.179
# fly_id[T.2017-03-09 00:00:001]    -0.3319      0.119     -2.795      0.005      -0.565      -0.099
# fly_id[T.2017-03-10 00:00:000]     0.0473      0.121      0.391      0.696      -0.190       0.285
# fly_id[T.2017-03-10 00:00:001]    -0.1654      0.093     -1.777      0.076      -0.348       0.017
# fly_id[T.2017-03-14 00:00:000]     0.2133      0.093      2.296      0.022       0.031       0.395
# fly_id[T.2017-03-21 00:00:000]    -0.0087      0.087     -0.101      0.920      -0.179       0.161
# fly_id[T.2017-03-22 00:00:000]    -0.0496      0.115     -0.432      0.666      -0.275       0.175
# fly_id[T.2017-03-24 00:00:000]     0.2315      0.115      2.016      0.044       0.006       0.457
# fly_id[T.2017-03-28 00:00:000]    -0.0423      0.115     -0.369      0.712      -0.267       0.183
# fly_id[T.2017-03-29 00:00:000]     0.3164      0.115      2.751      0.006       0.091       0.542
# fly_id[T.2017-04-07 00:00:000]    -0.1335      0.114     -1.171      0.241      -0.357       0.090
# fly_id[T.2017-04-11 00:00:000]     0.0863      0.114      0.757      0.449      -0.137       0.310
# fly_id[T.2017-04-12 00:00:000]    -0.2791      0.115     -2.426      0.015      -0.505      -0.054
# fly_id[T.2017-04-13 00:00:000]     0.0945      0.088      1.077      0.282      -0.077       0.266
# fly_id[T.2017-04-18 00:00:000]     0.1221      0.088      1.386      0.166      -0.051       0.295
# fly_id[T.2017-04-19 00:00:000]    -0.1401      0.115     -1.221      0.222      -0.365       0.085
# fly_id[T.2017-05-03 00:00:000]    -0.2439      0.085     -2.861      0.004      -0.411      -0.077
# fly_id[T.2017-05-05 00:00:000]     0.1411      0.115      1.226      0.220      -0.084       0.367
# fly_id[T.2017-05-05 00:00:001]     0.1026      0.085      1.210      0.226      -0.064       0.269
# fly_id[T.2017-05-09 00:00:000]     0.2346      0.115      2.043      0.041       0.009       0.460
# fly_id[T.2017-05-09 00:00:001]     0.3022      0.115      2.628      0.009       0.077       0.528
# fly_id[T.2017-05-12 00:00:000]    -0.2106      0.115     -1.831      0.067      -0.436       0.015
# fly_id[T.2017-05-15 00:00:000]    -0.0973      0.085     -1.141      0.254      -0.264       0.070
# fly_id[T.2017-05-16 00:00:000]     0.0230      0.085      0.272      0.786      -0.143       0.189
# fly_id[T.2017-05-17 00:00:000]    -0.3174      0.086     -3.700      0.000      -0.486      -0.149
# fly_id[T.2017-05-19 00:00:000]     0.0931      0.114      0.817      0.414      -0.130       0.317
# fly_id[T.2017-05-29 00:00:000]     0.2258      0.115      1.967      0.049       0.001       0.451
# fly_id[T.2017-05-31 00:00:000]     0.3414      0.115      2.974      0.003       0.116       0.567
# fly_id[T.2017-06-01 00:00:000]     0.0188      0.114      0.165      0.869      -0.205       0.242
# fly_id[T.2017-06-02 00:00:000]    -0.1919      0.114     -1.683      0.092      -0.415       0.032
# fly_id[T.2017-06-14 00:00:000]     0.2566      0.115      2.235      0.025       0.031       0.482
# fly_id[T.2017-06-23 00:00:000]     0.0370      0.115      0.323      0.747      -0.188       0.262
# fly_id[T.2017-06-28 00:00:000]    -0.1761      0.088     -1.999      0.046      -0.349      -0.003
# fly_id[T.2017-06-30 00:00:000]     0.1261      0.114      1.106      0.269      -0.097       0.350
# fly_id[T.2017-07-05 00:00:000]    -0.1164      0.114     -1.021      0.307      -0.340       0.107
# fly_id[T.2017-07-06 00:00:000]     0.1335      0.115      1.162      0.245      -0.092       0.359
# fly_id[T.2017-07-14 00:00:000]    -0.0008      0.115     -0.007      0.995      -0.226       0.224
# fly_id[T.2017-07-18 00:00:000]    -0.3735      0.114     -3.276      0.001      -0.597      -0.150
# fly_id[T.2017-07-21 00:00:000]     0.0442      0.088      0.504      0.614      -0.128       0.216
# fly_id[T.2017-07-31 00:00:000]    -0.3151      0.087     -3.633      0.000      -0.485      -0.145
# fly_id[T.2017-08-01 00:00:000]     0.1367      0.115      1.191      0.234      -0.088       0.362
# fly_id[T.2017-08-02 00:00:000]    -0.0666      0.115     -0.580      0.562      -0.292       0.159
# fly_id[T.2017-08-03 00:00:000]    -0.0642      0.115     -0.559      0.576      -0.289       0.161
# fly_id[T.2017-08-04 00:00:000]    -0.0598      0.086     -0.697      0.486      -0.228       0.108
# fly_id[T.2017-08-14 00:00:000]    -0.0876      0.086     -1.022      0.307      -0.256       0.081
# fly_id[T.2017-11-03 00:00:000]    -0.0435      0.079     -0.550      0.582      -0.199       0.112
# fly_id[T.2017-11-06 00:00:000]    -0.1927      0.093     -2.070      0.039      -0.375      -0.010
# fly_id[T.2017-11-09 00:00:000]    -0.1370      0.076     -1.800      0.072      -0.286       0.012
# fly_id[T.2017-11-30 00:00:000]    -0.3319      0.083     -4.019      0.000      -0.494      -0.170
# fly_id[T.2017-12-01 00:00:000]     0.0115      0.078      0.149      0.882      -0.140       0.164
# fly_id[T.2017-12-08 00:00:000]    -0.0526      0.093     -0.563      0.573      -0.236       0.131
# fly_id[T.2017-12-11 00:00:000]     0.2342      0.087      2.703      0.007       0.064       0.404
# fly_id[T.2017-12-13 00:00:000]    -0.0750      0.119     -0.632      0.527      -0.308       0.158
# fly_id[T.2017-12-15 00:00:000]    -0.0786      0.077     -1.018      0.309      -0.230       0.073
# fly_id[T.2018-01-15 00:00:000]    -0.0668      0.092     -0.727      0.467      -0.247       0.113
# fly_id[T.2018-01-17 00:00:000]     0.0153      0.093      0.165      0.869      -0.167       0.197
# fly_id[T.2018-01-19 00:00:000]     0.0992      0.076      1.304      0.192      -0.050       0.248
# fly_id[T.2018-02-16 00:00:000]     0.0442      0.119      0.372      0.710      -0.189       0.277
# fly_id[T.2018-02-20 00:00:000]     0.0818      0.083      0.984      0.325      -0.081       0.245
# fly_id[T.2018-02-21 00:00:000]     0.1890      0.071      2.674      0.008       0.050       0.328
# fly_id[T.2018-03-07 00:00:000]     0.0780      0.140      0.556      0.578      -0.197       0.353
# fly_id[T.2018-03-09 00:00:000]     0.2446      0.137      1.786      0.074      -0.024       0.513
# fly_id[T.2018-03-13 00:00:000]    -0.3476      0.052     -6.640      0.000      -0.450      -0.245
# fly_id[T.2018-03-14 00:00:000]     0.1754      0.052      3.352      0.001       0.073       0.278
# fly_id[T.2018-03-19 00:00:000]    -0.1257      0.155     -0.812      0.417      -0.429       0.178
# fly_id[T.2018-04-03 00:00:000]    -0.2528      0.147     -1.722      0.085      -0.541       0.035
# fly_id[T.2018-04-04 00:00:000]    -0.1594      0.114     -1.396      0.163      -0.383       0.064
# fly_id[T.2018-04-06 00:00:000]    -0.1728      0.090     -1.927      0.054      -0.348       0.003
# fly_id[T.2018-04-16 00:00:000]     0.0275      0.141      0.194      0.846      -0.249       0.304
# fly_id[T.2018-08-22 00:00:000]    -0.2796      0.147     -1.905      0.057      -0.567       0.008
# fly_id[T.2018-08-23 00:00:000]    -0.0459      0.122     -0.377      0.706      -0.284       0.192
# fly_id[T.2018-08-24 00:00:000]     0.2706      0.142      1.906      0.057      -0.008       0.549
# fly_id[T.2018-08-29 00:00:000]     0.2143      0.141      1.517      0.129      -0.063       0.491
# fly_id[T.2018-08-31 00:00:000]     0.2018      0.126      1.607      0.108      -0.044       0.448
# fly_id[T.2018-09-04 00:00:000]     0.0317      0.093      0.339      0.734      -0.151       0.215
# fly_id[T.2018-09-05 00:00:000]    -0.0553      0.112     -0.492      0.623      -0.276       0.165
# fly_id[T.2018-09-07 00:00:000]    -0.0964      0.126     -0.768      0.443      -0.343       0.150
# fly_id[T.2018-09-07 00:00:001]     0.0212      0.083      0.256      0.798      -0.141       0.184
# fly_id[T.2018-09-12 00:00:000]    -0.0564      0.094     -0.600      0.548      -0.241       0.128
# fly_id[T.2018-09-12 00:00:001]     0.2376      0.087      2.730      0.006       0.067       0.408
# fly_id[T.2018-09-13 00:00:000]    -0.1446      0.134     -1.078      0.281      -0.408       0.118
# fly_id[T.2018-09-14 00:00:000]    -0.0891      0.087     -1.024      0.306      -0.260       0.081
# fly_id[T.2018-09-14 00:00:001]     0.3023      0.094      3.216      0.001       0.118       0.487
# fly_id[T.2018-09-14 00:00:002]    -0.2500      0.149     -1.679      0.093      -0.542       0.042
# fly_id[T.2018-09-26 00:00:000]    -0.1249      0.107     -1.172      0.241      -0.334       0.084
# fly_id[T.2018-10-22 00:00:000]    -0.0731      0.107     -0.685      0.493      -0.282       0.136
# fly_id[T.2018-10-22 00:00:001]    -0.2543      0.158     -1.610      0.107      -0.564       0.055
# fly_id[T.2018-10-24 00:00:000]    -0.2565      0.110     -2.339      0.019      -0.471      -0.042
# fly_id[T.2018-10-24 00:00:001]    -0.1995      0.127     -1.566      0.117      -0.449       0.050
# fly_id[T.2018-10-25 00:00:000]     0.0652      0.149      0.437      0.662      -0.228       0.358
# fly_id[T.2018-10-25 00:00:001]     0.1753      0.145      1.213      0.225      -0.108       0.459
# fly_id[T.2018-10-26 00:00:000]     0.0962      0.105      0.919      0.358      -0.109       0.301
# fly_id[T.2018-10-26 00:00:001]    -0.0850      0.102     -0.830      0.407      -0.286       0.116
# fly_id[T.2018-11-22 00:00:000]     0.0685      0.153      0.449      0.653      -0.230       0.368
# fly_id[T.2018-11-22 00:00:001]    -0.1610      0.135     -1.192      0.233      -0.426       0.104
# fly_id[T.2018-11-23 00:00:000]    -0.1073      0.085     -1.263      0.207      -0.274       0.059
# fly_id[T.2018-11-23 00:00:001]     0.3354      0.097      3.467      0.001       0.146       0.525
# fly_id[T.2018-11-29 00:00:000]     0.0282      0.142      0.198      0.843      -0.251       0.307
# fly_id[T.2018-11-30 00:00:001]    -0.0425      0.118     -0.359      0.720      -0.275       0.190
# fly_id[T.2018-12-03 00:00:000]    -0.0390      0.163     -0.239      0.811      -0.359       0.281
# fly_id[T.2018-12-05 00:00:000]    -0.0405      0.113     -0.357      0.721      -0.263       0.182
# fly_id[T.2018-12-05 00:00:001]    -0.3122      0.089     -3.508      0.000      -0.487      -0.138
# fly_id[T.2018-12-07 00:00:000]     0.0526      0.110      0.477      0.634      -0.164       0.269
# fly_id[T.2018-12-07 00:00:001]     0.0759      0.090      0.846      0.398      -0.100       0.252
# fly_id[T.2018-12-13 00:00:000]     0.1806      0.095      1.909      0.056      -0.005       0.366
# fly_id[T.2018-12-13 00:00:001]    -0.0106      0.113     -0.094      0.925      -0.233       0.212
# fly_id[T.2018-12-14 00:00:000]    -0.0814      0.150     -0.541      0.589      -0.376       0.214
# fly_id[T.2018-12-14 00:00:001]     0.0295      0.162      0.182      0.855      -0.287       0.346
# fly_id[T.2018-12-17 00:00:000]    -0.0504      0.156     -0.323      0.747      -0.356       0.255
# fly_id[T.2018-12-19 00:00:000]     0.0093      0.093      0.100      0.920      -0.174       0.192
# fly_id[T.2019-01-14 00:00:000]    -0.1866      0.162     -1.154      0.248      -0.504       0.130
# fly_id[T.2019-01-15 00:00:000]     0.2847      0.155      1.836      0.066      -0.019       0.589
# fly_id[T.2019-01-15 00:00:001]    -0.1177      0.148     -0.796      0.426      -0.408       0.172
# fly_id[T.2019-01-16 00:00:000]    -0.1182      0.110     -1.073      0.283      -0.334       0.098
# fly_id[T.2019-01-16 00:00:001]    -0.2013      0.094     -2.149      0.032      -0.385      -0.018
# fly_id[T.2019-01-17 00:00:000]     0.2397      0.105      2.291      0.022       0.035       0.445
# fly_id[T.2019-01-17 00:00:001]    -0.2392      0.095     -2.519      0.012      -0.425      -0.053
# fly_id[T.2019-01-18 00:00:000]    -0.0538      0.100     -0.536      0.592      -0.250       0.143
# fly_id[T.2019-01-18 00:00:001]    -0.2056      0.092     -2.238      0.025      -0.386      -0.026
# fly_id[T.2019-01-21 00:00:000]    -0.3463      0.149     -2.318      0.020      -0.639      -0.053
# fly_id[T.2019-01-23 00:00:000]    -0.3132      0.073     -4.299      0.000      -0.456      -0.170
# fly_id[T.2019-01-23 00:00:001]    -0.2244      0.073     -3.079      0.002      -0.367      -0.082
# fly_id[T.2019-01-24 00:00:000]    -0.1508      0.073     -2.070      0.039      -0.294      -0.008
# fly_id[T.2019-01-24 00:00:001]     0.0580      0.073      0.796      0.426      -0.085       0.201
# fly_id[T.2019-01-25 00:00:000]    -0.0425      0.147     -0.290      0.772      -0.330       0.245
# fly_id[T.2019-01-30 00:00:000]    -0.0657      0.150     -0.439      0.661      -0.359       0.228
# fly_id[T.2019-02-01 00:00:000]     0.0014      0.073      0.019      0.985      -0.141       0.144
# fly_id[T.2019-02-01 00:00:001]    -0.1338      0.073     -1.836      0.066      -0.277       0.009
# fly_id[T.2019-02-06 00:00:000]     0.1564      0.099      1.578      0.115      -0.038       0.351
# fly_id[T.2019-02-06 00:00:001]     0.0709      0.098      0.727      0.467      -0.120       0.262
# fly_id[T.2019-02-08 00:00:000]     0.0284      0.123      0.231      0.817      -0.213       0.269
# fly_id[T.2019-02-15 00:00:000]     0.0978      0.135      0.726      0.468      -0.166       0.362
# fly_id[T.2019-02-18 00:00:000]     0.5176      0.130      3.990      0.000       0.263       0.772
# fly_id[T.2019-02-20 00:00:000]     0.1659      0.096      1.729      0.084      -0.022       0.354
# fly_id[T.2019-02-28 00:00:000]    -0.0281      0.158     -0.178      0.859      -0.338       0.282
# fly_id[T.2019-03-01 00:00:000]     0.0412      0.150      0.274      0.784      -0.253       0.336
# fly_id[T.2019-03-06 00:00:000]    -0.0301      0.121     -0.248      0.804      -0.268       0.208
# fly_id[T.2019-03-07 00:00:000]    -0.2261      0.073     -3.104      0.002      -0.369      -0.083
# fly_id[T.2019-03-07 00:00:001]    -0.1131      0.073     -1.552      0.121      -0.256       0.030
# fly_id[T.2019-03-29 00:00:000]     0.0282      0.134      0.210      0.834      -0.235       0.292
# fly_id[T.2019-04-04 00:00:000]    -0.2129      0.083     -2.555      0.011      -0.376      -0.050
# fly_id[T.2019-04-25 00:00:000]    -0.1628      0.114     -1.430      0.153      -0.386       0.060
# fly_id[T.2019-04-26 00:00:000]     0.0421      0.114      0.370      0.711      -0.181       0.265
# fly_id[T.2019-04-29 00:00:000]     0.0396      0.073      0.544      0.587      -0.103       0.182
# fly_id[T.2019-04-29 00:00:001]    -0.1683      0.073     -2.309      0.021      -0.311      -0.025
# fly_id[T.2019-05-10 00:00:000]    -0.1578      0.083     -1.912      0.056      -0.320       0.004
# fly_id[T.2019-05-15 00:00:000]    -0.0865      0.112     -0.770      0.441      -0.307       0.134
# fly_id[T.2019-12-23 00:00:000]    -0.0607      0.073     -0.834      0.405      -0.204       0.082
# fly_id[T.2019-12-23 00:00:001]     0.0792      0.073      1.087      0.277      -0.064       0.222
# fly_id[T.2020-01-02 00:00:000]    -0.0835      0.073     -1.146      0.252      -0.226       0.059
# fly_id[T.2020-01-09 00:00:000]    -0.1300      0.073     -1.784      0.074      -0.273       0.013
# fly_id[T.2020-01-09 00:00:001]    -0.2549      0.073     -3.498      0.000      -0.398      -0.112
# fly_id[T.2020-01-13 00:00:000]     0.7031      0.073      9.649      0.000       0.560       0.846
# fly_id[T.2020-01-13 00:00:001]    -0.1193      0.073     -1.638      0.102      -0.262       0.024
# fly_id[T.2020-01-15 00:00:000]    -0.0812      0.073     -1.115      0.265      -0.224       0.062
# fly_id[T.2020-01-20 00:00:000]    -0.1755      0.073     -2.409      0.016      -0.318      -0.033
# fly_id[T.2020-01-27 00:00:000]     0.2535      0.073      3.479      0.001       0.111       0.396
# fly_id[T.2020-01-28 00:00:000]     0.5142      0.073      7.057      0.000       0.371       0.657
# fly_id[T.2020-01-28 00:00:001]     0.3150      0.073      4.322      0.000       0.172       0.458
# fly_id[T.2020-01-29 00:00:000]     0.0062      0.073      0.085      0.932      -0.137       0.149
# fly_id[T.2020-01-29 00:00:001]    -0.1241      0.073     -1.703      0.089      -0.267       0.019
# fly_id[T.2020-01-30 00:00:000]     0.0529      0.073      0.726      0.468      -0.090       0.196
# fly_id[T.2020-01-31 00:00:000]     0.3983      0.073      5.466      0.000       0.255       0.541
# fly_id[T.2020-02-03 00:00:000]     0.0004      0.073      0.005      0.996      -0.142       0.143
# fly_id[T.2020-02-04 00:00:000]     0.0704      0.073      0.966      0.334      -0.072       0.213
# fly_id[T.2020-02-13 00:00:000]    -0.0863      0.073     -1.184      0.236      -0.229       0.057
# fly_id[T.2020-02-14 00:00:000]     0.0187      0.073      0.256      0.798      -0.124       0.162
# order_presented                   -0.1513      0.128     -1.180      0.238      -0.403       0.100
# dorsal_to_ventral_val             -0.0354      0.012     -2.961      0.003      -0.059      -0.012
# starved                            0.0011      0.052      0.022      0.982      -0.100       0.102
# ==============================================================================
# Omnibus:                     1489.529   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6346.016
# Skew:                           1.283   Prob(JB):                         0.00
# Kurtosis:                       7.633   Cond. No.                     1.42e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.44e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# Indeed, show up as warning in the summary

# %% [markdown]
# ### Characterize multicolinearity

# %% [markdown]
# from wikipedia:
# "the quotient of the variance in a model with multiple terms by the variance of a model with one term alone"
#
# "how much the variance (the square of the estimate's standard deviation) of an estimated regression coefficient is increased because of collinearity"
#
# from https://www.statpac.com/manual/index.htm?turl=varianceinflationfactors.htm
# "the degree to which a regression coefficient will be affected because of the variable's redundancy with other independent variables."

# %%
y, X = dmatrices('df_f ~ lobe+stimulus+order_presented+dorsal_to_ventral_val+fly_id+starved', lobe_data, return_type='dataframe')
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif.round(1)
# Out:
# C:\Users\aimon\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#      VIF Factor                        features
# 0    542.500000                       Intercept
# 1      1.900000                      lobe[T.a2]
# 2      1.900000                      lobe[T.a3]
# 3      1.900000                     lobe[T.ap1]
# 4      1.900000                     lobe[T.ap2]
# 5      1.900000                     lobe[T.ap3]
# 6      1.900000                      lobe[T.b1]
# 7      1.900000                      lobe[T.b2]
# 8      1.900000                     lobe[T.bp1]
# 9      1.900000                     lobe[T.bp2]
# 10     1.900000                      lobe[T.g1]
# 11     1.900000                      lobe[T.g2]
# 12     1.900000                      lobe[T.g3]
# 13     1.900000                      lobe[T.g4]
# 14     1.900000                      lobe[T.g5]
# 15    11.700000         stimulus[T.2-Heptanone]
# 16    12.800000            stimulus[T.3Octanol]
# 17    15.400000                stimulus[T.4MCH]
# 18    44.100000          stimulus[T.Citronella]
# 19    11.400000             stimulus[T.Ethanol]
# 20    13.700000             stimulus[T.Geosmin]
# 21    11.500000      stimulus[T.Isoamylacetate]
# 22     9.900000          stimulus[T.Peppermint]
# 23    35.800000             stimulus[T.Vinegar]
# 24    38.000000               stimulus[T.Yeast]
# 25          inf                 stimulus[T.cVA]
# 26     2.100000  fly_id[T.2016-08-10 00:00:000]
# 27     2.100000  fly_id[T.2016-08-11 00:00:000]
# 28     2.100000  fly_id[T.2016-08-16 00:00:000]
# 29     2.000000  fly_id[T.2016-08-17 00:00:000]
# ..          ...                             ...
# 183         inf  fly_id[T.2019-04-04 00:00:000]
# 184    2.400000  fly_id[T.2019-04-25 00:00:000]
# 185    2.400000  fly_id[T.2019-04-26 00:00:000]
# 186         inf  fly_id[T.2019-04-29 00:00:000]
# 187         inf  fly_id[T.2019-04-29 00:00:001]
# 188         inf  fly_id[T.2019-05-10 00:00:000]
# 189    2.300000  fly_id[T.2019-05-15 00:00:000]
# 190         inf  fly_id[T.2019-12-23 00:00:000]
# 191         inf  fly_id[T.2019-12-23 00:00:001]
# 192         inf  fly_id[T.2020-01-02 00:00:000]
# 193         inf  fly_id[T.2020-01-09 00:00:000]
# 194         inf  fly_id[T.2020-01-09 00:00:001]
# 195         inf  fly_id[T.2020-01-13 00:00:000]
# 196         inf  fly_id[T.2020-01-13 00:00:001]
# 197         inf  fly_id[T.2020-01-15 00:00:000]
# 198         inf  fly_id[T.2020-01-20 00:00:000]
# 199         inf  fly_id[T.2020-01-27 00:00:000]
# 200         inf  fly_id[T.2020-01-28 00:00:000]
# 201         inf  fly_id[T.2020-01-28 00:00:001]
# 202         inf  fly_id[T.2020-01-29 00:00:000]
# 203         inf  fly_id[T.2020-01-29 00:00:001]
# 204         inf  fly_id[T.2020-01-30 00:00:000]
# 205         inf  fly_id[T.2020-01-31 00:00:000]
# 206         inf  fly_id[T.2020-02-03 00:00:000]
# 207         inf  fly_id[T.2020-02-04 00:00:000]
# 208         inf  fly_id[T.2020-02-13 00:00:000]
# 209         inf  fly_id[T.2020-02-14 00:00:000]
# 210    1.500000                 order_presented
# 211    1.200000           dorsal_to_ventral_val
# 212         inf                         starved
#
# [213 rows x 2 columns]

# %% [markdown]
# Many fly_id factors have an infinite VIF, and many factors have high VIF.

# %%
y, X = dmatrices('df_f ~ lobe+stimulus+order_presented+dorsal_to_ventral_val+starved-1', lobe_data, return_type='dataframe')
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif.round(1)
# Out:
#     VIF Factor                    features
# 0          2.3                    lobe[a1]
# 1          2.3                    lobe[a2]
# 2          2.3                    lobe[a3]
# 3          2.3                   lobe[ap1]
# 4          2.3                   lobe[ap2]
# 5          2.3                   lobe[ap3]
# 6          2.3                    lobe[b1]
# 7          2.3                    lobe[b2]
# 8          2.3                   lobe[bp1]
# 9          2.3                   lobe[bp2]
# 10         2.3                    lobe[g1]
# 11         2.3                    lobe[g2]
# 12         2.3                    lobe[g3]
# 13         2.3                    lobe[g4]
# 14         2.3                    lobe[g5]
# 15         1.9     stimulus[T.2-Heptanone]
# 16         1.8        stimulus[T.3Octanol]
# 17         2.0            stimulus[T.4MCH]
# 18         3.0      stimulus[T.Citronella]
# 19         1.6         stimulus[T.Ethanol]
# 20         1.7         stimulus[T.Geosmin]
# 21         2.1  stimulus[T.Isoamylacetate]
# 22         2.1      stimulus[T.Peppermint]
# 23         2.7         stimulus[T.Vinegar]
# 24         2.9           stimulus[T.Yeast]
# 25         3.9             stimulus[T.cVA]
# 26         1.0             order_presented
# 27         1.0       dorsal_to_ventral_val
# 28         1.3                     starved

# %% [markdown]
# Now VIFs are reasonable

# %%
result = smf.ols(formula="df_f ~ lobe+stimulus+order_presented+dorsal_to_ventral_val+starved", data=lobe_data).fit()

aov_table = anova_lm(result, typ=2)
print(result.rsquared)
aov_table
# Out:
# 0.25738553079932003
#                             sum_sq      df           F         PR(>F)
# lobe                    313.009229    14.0  117.518296  1.208695e-298
# stimulus                 34.680558    11.0   16.571803   1.343960e-32
# order_presented           1.083264     1.0    5.693912   1.705811e-02
# dorsal_to_ventral_val     3.408663     1.0   17.916798   2.346029e-05
# starved                   2.529495     1.0   13.295667   2.685245e-04
# Residual               1027.537780  5401.0         NaN            NaN

# %% [markdown]
# We thus choose to remove fly_id from the model. We will nevertheless do one mixed model (see below) to see if fly_id affects regression coefficients.

# %% [markdown]
# ### Interaction with lobes

# %% [markdown]
# We want to know if different lobes respond differently to different factors

# %%
resInter = smf.ols(formula="df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val+starved)", data=lobe_data).fit()

resInter.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.328
# Method:                 Least Squares   F-statistic:                     12.84
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):               0.00
# Time:                        16:37:47   Log-Likelihood:                -2798.3
# No. Observations:                5430   AIC:                             6047.
# Df Residuals:                    5205   BIC:                             7532.
# Df Model:                         224
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  0.2160      0.100      2.169      0.030       0.021       0.411
# lobe[T.a2]                                 0.1460      0.141      1.037      0.300      -0.130       0.422
# lobe[T.a3]                                 0.1784      0.141      1.267      0.205      -0.098       0.455
# lobe[T.ap1]                                0.3392      0.141      2.408      0.016       0.063       0.615
# lobe[T.ap2]                                0.1167      0.141      0.829      0.407      -0.159       0.393
# lobe[T.ap3]                                0.5920      0.141      4.203      0.000       0.316       0.868
# lobe[T.b1]                                 0.2849      0.141      2.023      0.043       0.009       0.561
# lobe[T.b2]                                 0.4893      0.141      3.474      0.001       0.213       0.765
# lobe[T.bp1]                                0.9091      0.141      6.454      0.000       0.633       1.185
# lobe[T.bp2]                                0.5101      0.141      3.621      0.000       0.234       0.786
# lobe[T.g1]                                 0.3046      0.141      2.163      0.031       0.028       0.581
# lobe[T.g2]                                 0.4941      0.141      3.508      0.000       0.218       0.770
# lobe[T.g3]                                 0.7779      0.141      5.523      0.000       0.502       1.054
# lobe[T.g4]                                 0.6610      0.141      4.693      0.000       0.385       0.937
# lobe[T.g5]                                 0.0562      0.141      0.399      0.690      -0.220       0.332
# stimulus[T.2-Heptanone]                   -0.1427      0.129     -1.103      0.270      -0.396       0.111
# stimulus[T.3Octanol]                       0.0725      0.137      0.531      0.595      -0.195       0.340
# stimulus[T.4MCH]                           0.0514      0.128      0.402      0.688      -0.200       0.302
# stimulus[T.Citronella]                    -0.1406      0.110     -1.279      0.201      -0.356       0.075
# stimulus[T.Ethanol]                       -0.0686      0.147     -0.465      0.642      -0.358       0.220
# stimulus[T.Geosmin]                       -0.1859      0.142     -1.313      0.189      -0.463       0.092
# stimulus[T.Isoamylacetate]                -0.0373      0.124     -0.301      0.764      -0.281       0.206
# stimulus[T.Peppermint]                    -0.0995      0.124     -0.801      0.423      -0.343       0.144
# stimulus[T.Vinegar]                       -0.1933      0.112     -1.720      0.086      -0.414       0.027
# stimulus[T.Yeast]                         -0.1602      0.112     -1.435      0.151      -0.379       0.059
# stimulus[T.cVA]                           -0.0866      0.110     -0.790      0.429      -0.301       0.128
# lobe[T.a2]:stimulus[T.2-Heptanone]         0.2152      0.183      1.177      0.239      -0.143       0.574
# lobe[T.a3]:stimulus[T.2-Heptanone]         0.2394      0.183      1.309      0.191      -0.119       0.598
# lobe[T.ap1]:stimulus[T.2-Heptanone]        0.1809      0.183      0.989      0.323      -0.178       0.539
# lobe[T.ap2]:stimulus[T.2-Heptanone]        0.2607      0.183      1.426      0.154      -0.098       0.619
# lobe[T.ap3]:stimulus[T.2-Heptanone]        0.0051      0.183      0.028      0.978      -0.353       0.364
# lobe[T.b1]:stimulus[T.2-Heptanone]        -0.1599      0.183     -0.874      0.382      -0.518       0.199
# lobe[T.b2]:stimulus[T.2-Heptanone]        -0.1617      0.183     -0.884      0.377      -0.520       0.197
# lobe[T.bp1]:stimulus[T.2-Heptanone]       -0.2068      0.183     -1.131      0.258      -0.565       0.152
# lobe[T.bp2]:stimulus[T.2-Heptanone]       -0.1032      0.183     -0.564      0.572      -0.462       0.255
# lobe[T.g1]:stimulus[T.2-Heptanone]         0.2178      0.183      1.191      0.234      -0.141       0.576
# lobe[T.g2]:stimulus[T.2-Heptanone]         0.0036      0.183      0.020      0.984      -0.355       0.362
# lobe[T.g3]:stimulus[T.2-Heptanone]         0.1766      0.183      0.966      0.334      -0.182       0.535
# lobe[T.g4]:stimulus[T.2-Heptanone]        -0.3041      0.183     -1.663      0.096      -0.663       0.054
# lobe[T.g5]:stimulus[T.2-Heptanone]         0.0277      0.183      0.151      0.880      -0.331       0.386
# lobe[T.a2]:stimulus[T.3Octanol]            0.3170      0.193      1.642      0.101      -0.062       0.696
# lobe[T.a3]:stimulus[T.3Octanol]            0.4023      0.193      2.084      0.037       0.024       0.781
# lobe[T.ap1]:stimulus[T.3Octanol]           0.1519      0.193      0.786      0.432      -0.227       0.530
# lobe[T.ap2]:stimulus[T.3Octanol]           0.3115      0.193      1.613      0.107      -0.067       0.690
# lobe[T.ap3]:stimulus[T.3Octanol]          -0.1325      0.193     -0.686      0.492      -0.511       0.246
# lobe[T.b1]:stimulus[T.3Octanol]            0.0728      0.193      0.377      0.706      -0.306       0.451
# lobe[T.b2]:stimulus[T.3Octanol]           -0.2064      0.193     -1.069      0.285      -0.585       0.172
# lobe[T.bp1]:stimulus[T.3Octanol]          -0.0358      0.193     -0.186      0.853      -0.414       0.343
# lobe[T.bp2]:stimulus[T.3Octanol]          -0.1760      0.193     -0.912      0.362      -0.555       0.203
# lobe[T.g1]:stimulus[T.3Octanol]           -0.0661      0.193     -0.343      0.732      -0.445       0.312
# lobe[T.g2]:stimulus[T.3Octanol]           -0.0359      0.193     -0.186      0.853      -0.414       0.343
# lobe[T.g3]:stimulus[T.3Octanol]           -0.2530      0.193     -1.310      0.190      -0.632       0.126
# lobe[T.g4]:stimulus[T.3Octanol]           -0.5947      0.193     -3.080      0.002      -0.973      -0.216
# lobe[T.g5]:stimulus[T.3Octanol]           -0.2359      0.193     -1.222      0.222      -0.614       0.143
# lobe[T.a2]:stimulus[T.4MCH]               -0.1017      0.181     -0.562      0.574      -0.457       0.253
# lobe[T.a3]:stimulus[T.4MCH]               -0.0157      0.181     -0.087      0.931      -0.371       0.339
# lobe[T.ap1]:stimulus[T.4MCH]              -0.1684      0.181     -0.930      0.352      -0.523       0.187
# lobe[T.ap2]:stimulus[T.4MCH]              -0.0642      0.181     -0.355      0.723      -0.419       0.291
# lobe[T.ap3]:stimulus[T.4MCH]              -0.3229      0.181     -1.784      0.074      -0.678       0.032
# lobe[T.b1]:stimulus[T.4MCH]                0.4284      0.181      2.367      0.018       0.074       0.783
# lobe[T.b2]:stimulus[T.4MCH]                0.4803      0.181      2.653      0.008       0.125       0.835
# lobe[T.bp1]:stimulus[T.4MCH]               0.0303      0.181      0.168      0.867      -0.325       0.385
# lobe[T.bp2]:stimulus[T.4MCH]               0.3214      0.181      1.776      0.076      -0.033       0.676
# lobe[T.g1]:stimulus[T.4MCH]               -0.0768      0.181     -0.424      0.672      -0.432       0.278
# lobe[T.g2]:stimulus[T.4MCH]               -0.2216      0.181     -1.224      0.221      -0.577       0.133
# lobe[T.g3]:stimulus[T.4MCH]               -0.1976      0.181     -1.092      0.275      -0.553       0.157
# lobe[T.g4]:stimulus[T.4MCH]                0.2200      0.181      1.215      0.224      -0.135       0.575
# lobe[T.g5]:stimulus[T.4MCH]                0.0242      0.181      0.134      0.894      -0.331       0.379
# lobe[T.a2]:stimulus[T.Citronella]          0.2072      0.155      1.333      0.183      -0.098       0.512
# lobe[T.a3]:stimulus[T.Citronella]          0.1969      0.155      1.266      0.205      -0.108       0.502
# lobe[T.ap1]:stimulus[T.Citronella]         0.0898      0.155      0.577      0.564      -0.215       0.395
# lobe[T.ap2]:stimulus[T.Citronella]         0.2426      0.155      1.560      0.119      -0.062       0.547
# lobe[T.ap3]:stimulus[T.Citronella]         0.3147      0.155      2.024      0.043       0.010       0.619
# lobe[T.b1]:stimulus[T.Citronella]         -0.0915      0.155     -0.588      0.556      -0.396       0.213
# lobe[T.b2]:stimulus[T.Citronella]         -0.0717      0.155     -0.461      0.645      -0.376       0.233
# lobe[T.bp1]:stimulus[T.Citronella]        -0.2628      0.155     -1.691      0.091      -0.568       0.042
# lobe[T.bp2]:stimulus[T.Citronella]        -0.0176      0.155     -0.113      0.910      -0.322       0.287
# lobe[T.g1]:stimulus[T.Citronella]         -0.0820      0.155     -0.528      0.598      -0.387       0.223
# lobe[T.g2]:stimulus[T.Citronella]         -0.0366      0.155     -0.235      0.814      -0.341       0.268
# lobe[T.g3]:stimulus[T.Citronella]         -0.1121      0.155     -0.721      0.471      -0.417       0.193
# lobe[T.g4]:stimulus[T.Citronella]         -0.2691      0.155     -1.731      0.084      -0.574       0.036
# lobe[T.g5]:stimulus[T.Citronella]          0.0133      0.155      0.085      0.932      -0.292       0.318
# lobe[T.a2]:stimulus[T.Ethanol]             0.1290      0.209      0.619      0.536      -0.280       0.538
# lobe[T.a3]:stimulus[T.Ethanol]             0.0622      0.209      0.298      0.766      -0.347       0.471
# lobe[T.ap1]:stimulus[T.Ethanol]           -0.1698      0.209     -0.814      0.415      -0.579       0.239
# lobe[T.ap2]:stimulus[T.Ethanol]            0.0920      0.209      0.441      0.659      -0.317       0.501
# lobe[T.ap3]:stimulus[T.Ethanol]            0.4969      0.209      2.382      0.017       0.088       0.906
# lobe[T.b1]:stimulus[T.Ethanol]            -0.0340      0.209     -0.163      0.870      -0.443       0.375
# lobe[T.b2]:stimulus[T.Ethanol]            -0.0057      0.209     -0.027      0.978      -0.414       0.403
# lobe[T.bp1]:stimulus[T.Ethanol]            0.1263      0.209      0.606      0.545      -0.283       0.535
# lobe[T.bp2]:stimulus[T.Ethanol]           -0.2378      0.209     -1.140      0.254      -0.647       0.171
# lobe[T.g1]:stimulus[T.Ethanol]            -0.2036      0.209     -0.976      0.329      -0.612       0.205
# lobe[T.g2]:stimulus[T.Ethanol]            -0.2044      0.209     -0.980      0.327      -0.613       0.204
# lobe[T.g3]:stimulus[T.Ethanol]            -0.3660      0.209     -1.755      0.079      -0.775       0.043
# lobe[T.g4]:stimulus[T.Ethanol]            -0.4903      0.209     -2.351      0.019      -0.899      -0.081
# lobe[T.g5]:stimulus[T.Ethanol]            -0.1270      0.209     -0.609      0.543      -0.536       0.282
# lobe[T.a2]:stimulus[T.Geosmin]             0.1249      0.200      0.624      0.533      -0.268       0.517
# lobe[T.a3]:stimulus[T.Geosmin]            -0.0202      0.200     -0.101      0.919      -0.413       0.372
# lobe[T.ap1]:stimulus[T.Geosmin]           -0.1472      0.200     -0.735      0.462      -0.540       0.245
# lobe[T.ap2]:stimulus[T.Geosmin]            0.1479      0.200      0.739      0.460      -0.245       0.540
# lobe[T.ap3]:stimulus[T.Geosmin]            0.0041      0.200      0.020      0.984      -0.388       0.397
# lobe[T.b1]:stimulus[T.Geosmin]            -0.0255      0.200     -0.128      0.899      -0.418       0.367
# lobe[T.b2]:stimulus[T.Geosmin]            -0.0087      0.200     -0.043      0.965      -0.401       0.384
# lobe[T.bp1]:stimulus[T.Geosmin]           -0.0836      0.200     -0.418      0.676      -0.476       0.309
# lobe[T.bp2]:stimulus[T.Geosmin]           -0.1029      0.200     -0.514      0.607      -0.495       0.290
# lobe[T.g1]:stimulus[T.Geosmin]            -0.1932      0.200     -0.965      0.335      -0.586       0.199
# lobe[T.g2]:stimulus[T.Geosmin]            -0.2667      0.200     -1.332      0.183      -0.659       0.126
# lobe[T.g3]:stimulus[T.Geosmin]            -0.5191      0.200     -2.593      0.010      -0.912      -0.127
# lobe[T.g4]:stimulus[T.Geosmin]            -0.4108      0.200     -2.052      0.040      -0.803      -0.018
# lobe[T.g5]:stimulus[T.Geosmin]             0.0134      0.200      0.067      0.947      -0.379       0.406
# lobe[T.a2]:stimulus[T.Isoamylacetate]      0.2757      0.176      1.569      0.117      -0.069       0.620
# lobe[T.a3]:stimulus[T.Isoamylacetate]      0.2932      0.176      1.669      0.095      -0.051       0.638
# lobe[T.ap1]:stimulus[T.Isoamylacetate]     0.0725      0.176      0.413      0.680      -0.272       0.417
# lobe[T.ap2]:stimulus[T.Isoamylacetate]     0.2535      0.176      1.443      0.149      -0.091       0.598
# lobe[T.ap3]:stimulus[T.Isoamylacetate]     0.1499      0.176      0.853      0.394      -0.194       0.494
# lobe[T.b1]:stimulus[T.Isoamylacetate]     -0.1249      0.176     -0.711      0.477      -0.469       0.219
# lobe[T.b2]:stimulus[T.Isoamylacetate]     -0.2676      0.176     -1.523      0.128      -0.612       0.077
# lobe[T.bp1]:stimulus[T.Isoamylacetate]     0.1870      0.176      1.065      0.287      -0.157       0.531
# lobe[T.bp2]:stimulus[T.Isoamylacetate]    -0.1839      0.176     -1.047      0.295      -0.528       0.160
# lobe[T.g1]:stimulus[T.Isoamylacetate]      0.1402      0.176      0.798      0.425      -0.204       0.484
# lobe[T.g2]:stimulus[T.Isoamylacetate]     -0.0024      0.176     -0.014      0.989      -0.347       0.342
# lobe[T.g3]:stimulus[T.Isoamylacetate]      0.0324      0.176      0.185      0.854      -0.312       0.377
# lobe[T.g4]:stimulus[T.Isoamylacetate]     -0.3870      0.176     -2.203      0.028      -0.731      -0.043
# lobe[T.g5]:stimulus[T.Isoamylacetate]     -0.0733      0.176     -0.417      0.677      -0.418       0.271
# lobe[T.a2]:stimulus[T.Peppermint]          0.2506      0.176      1.426      0.154      -0.094       0.595
# lobe[T.a3]:stimulus[T.Peppermint]          0.2930      0.176      1.667      0.096      -0.052       0.638
# lobe[T.ap1]:stimulus[T.Peppermint]         0.3028      0.176      1.723      0.085      -0.042       0.647
# lobe[T.ap2]:stimulus[T.Peppermint]         0.3027      0.176      1.722      0.085      -0.042       0.647
# lobe[T.ap3]:stimulus[T.Peppermint]         0.3625      0.176      2.062      0.039       0.018       0.707
# lobe[T.b1]:stimulus[T.Peppermint]          0.0055      0.176      0.031      0.975      -0.339       0.350
# lobe[T.b2]:stimulus[T.Peppermint]         -0.1500      0.176     -0.853      0.394      -0.495       0.195
# lobe[T.bp1]:stimulus[T.Peppermint]         0.4025      0.176      2.290      0.022       0.058       0.747
# lobe[T.bp2]:stimulus[T.Peppermint]         0.0194      0.176      0.111      0.912      -0.325       0.364
# lobe[T.g1]:stimulus[T.Peppermint]          0.1262      0.176      0.718      0.473      -0.218       0.471
# lobe[T.g2]:stimulus[T.Peppermint]          0.1139      0.176      0.648      0.517      -0.231       0.459
# lobe[T.g3]:stimulus[T.Peppermint]          0.2965      0.176      1.687      0.092      -0.048       0.641
# lobe[T.g4]:stimulus[T.Peppermint]         -0.1201      0.176     -0.683      0.495      -0.465       0.224
# lobe[T.g5]:stimulus[T.Peppermint]          0.0553      0.176      0.315      0.753      -0.289       0.400
# lobe[T.a2]:stimulus[T.Vinegar]             0.1446      0.159      0.910      0.363      -0.167       0.456
# lobe[T.a3]:stimulus[T.Vinegar]            -0.0058      0.159     -0.036      0.971      -0.317       0.306
# lobe[T.ap1]:stimulus[T.Vinegar]           -0.0865      0.159     -0.544      0.587      -0.398       0.225
# lobe[T.ap2]:stimulus[T.Vinegar]            0.1711      0.159      1.076      0.282      -0.141       0.483
# lobe[T.ap3]:stimulus[T.Vinegar]            0.2965      0.159      1.865      0.062      -0.015       0.608
# lobe[T.b1]:stimulus[T.Vinegar]             0.2004      0.159      1.260      0.208      -0.111       0.512
# lobe[T.b2]:stimulus[T.Vinegar]             0.2762      0.159      1.737      0.082      -0.036       0.588
# lobe[T.bp1]:stimulus[T.Vinegar]           -0.1341      0.159     -0.843      0.399      -0.446       0.178
# lobe[T.bp2]:stimulus[T.Vinegar]            0.2694      0.159      1.694      0.090      -0.042       0.581
# lobe[T.g1]:stimulus[T.Vinegar]            -0.0430      0.159     -0.270      0.787      -0.355       0.269
# lobe[T.g2]:stimulus[T.Vinegar]            -0.1971      0.159     -1.239      0.215      -0.509       0.115
# lobe[T.g3]:stimulus[T.Vinegar]            -0.0813      0.159     -0.511      0.609      -0.393       0.230
# lobe[T.g4]:stimulus[T.Vinegar]             0.2850      0.159      1.792      0.073      -0.027       0.597
# lobe[T.g5]:stimulus[T.Vinegar]             0.1521      0.159      0.957      0.339      -0.160       0.464
# lobe[T.a2]:stimulus[T.Yeast]               0.1983      0.158      1.256      0.209      -0.111       0.508
# lobe[T.a3]:stimulus[T.Yeast]               0.0940      0.158      0.595      0.552      -0.216       0.404
# lobe[T.ap1]:stimulus[T.Yeast]             -0.0230      0.158     -0.146      0.884      -0.333       0.287
# lobe[T.ap2]:stimulus[T.Yeast]              0.2469      0.158      1.563      0.118      -0.063       0.556
# lobe[T.ap3]:stimulus[T.Yeast]              0.4736      0.158      2.999      0.003       0.164       0.783
# lobe[T.b1]:stimulus[T.Yeast]               0.0473      0.158      0.300      0.764      -0.262       0.357
# lobe[T.b2]:stimulus[T.Yeast]               0.1507      0.158      0.954      0.340      -0.159       0.460
# lobe[T.bp1]:stimulus[T.Yeast]             -0.0132      0.158     -0.084      0.933      -0.323       0.296
# lobe[T.bp2]:stimulus[T.Yeast]              0.3170      0.158      2.008      0.045       0.007       0.627
# lobe[T.g1]:stimulus[T.Yeast]               0.0448      0.158      0.283      0.777      -0.265       0.354
# lobe[T.g2]:stimulus[T.Yeast]              -0.1568      0.158     -0.993      0.321      -0.466       0.153
# lobe[T.g3]:stimulus[T.Yeast]              -0.0180      0.158     -0.114      0.909      -0.328       0.292
# lobe[T.g4]:stimulus[T.Yeast]               0.1859      0.158      1.177      0.239      -0.124       0.495
# lobe[T.g5]:stimulus[T.Yeast]               0.1394      0.158      0.882      0.378      -0.170       0.449
# lobe[T.a2]:stimulus[T.cVA]                 0.2961      0.155      1.911      0.056      -0.008       0.600
# lobe[T.a3]:stimulus[T.cVA]                 0.1424      0.155      0.919      0.358      -0.161       0.446
# lobe[T.ap1]:stimulus[T.cVA]                0.1584      0.155      1.022      0.307      -0.145       0.462
# lobe[T.ap2]:stimulus[T.cVA]                0.2921      0.155      1.885      0.059      -0.012       0.596
# lobe[T.ap3]:stimulus[T.cVA]                0.2377      0.155      1.534      0.125      -0.066       0.541
# lobe[T.b1]:stimulus[T.cVA]                -0.0782      0.155     -0.504      0.614      -0.382       0.226
# lobe[T.b2]:stimulus[T.cVA]                 0.0196      0.155      0.127      0.899      -0.284       0.323
# lobe[T.bp1]:stimulus[T.cVA]                0.0701      0.155      0.452      0.651      -0.234       0.374
# lobe[T.bp2]:stimulus[T.cVA]               -0.2206      0.155     -1.424      0.154      -0.524       0.083
# lobe[T.g1]:stimulus[T.cVA]                -0.1078      0.155     -0.696      0.487      -0.412       0.196
# lobe[T.g2]:stimulus[T.cVA]                 0.0013      0.155      0.009      0.993      -0.302       0.305
# lobe[T.g3]:stimulus[T.cVA]                -0.3151      0.155     -2.034      0.042      -0.619      -0.011
# lobe[T.g4]:stimulus[T.cVA]                -0.5078      0.155     -3.278      0.001      -0.812      -0.204
# lobe[T.g5]:stimulus[T.cVA]                -0.1134      0.155     -0.732      0.464      -0.417       0.190
# order_presented                           -0.0458      0.420     -0.109      0.913      -0.869       0.777
# lobe[T.a2]:order_presented                -0.3260      0.594     -0.549      0.583      -1.490       0.838
# lobe[T.a3]:order_presented                -0.2438      0.594     -0.411      0.681      -1.408       0.920
# lobe[T.ap1]:order_presented               -0.1895      0.594     -0.319      0.750      -1.353       0.974
# lobe[T.ap2]:order_presented               -0.2310      0.594     -0.389      0.697      -1.395       0.933
# lobe[T.ap3]:order_presented               -1.0367      0.594     -1.746      0.081      -2.201       0.127
# lobe[T.b1]:order_presented                 0.3309      0.594      0.557      0.577      -0.833       1.495
# lobe[T.b2]:order_presented                 0.0900      0.594      0.152      0.880      -1.074       1.254
# lobe[T.bp1]:order_presented               -0.5851      0.594     -0.986      0.324      -1.749       0.579
# lobe[T.bp2]:order_presented               -0.2268      0.594     -0.382      0.702      -1.391       0.937
# lobe[T.g1]:order_presented                -0.1848      0.594     -0.311      0.756      -1.349       0.979
# lobe[T.g2]:order_presented                -0.0100      0.594     -0.017      0.987      -1.174       1.154
# lobe[T.g3]:order_presented                -0.3124      0.594     -0.526      0.599      -1.476       0.851
# lobe[T.g4]:order_presented                -0.5422      0.594     -0.913      0.361      -1.706       0.622
# lobe[T.g5]:order_presented                 0.0645      0.594      0.109      0.913      -1.099       1.228
# dorsal_to_ventral_val                     -0.0215      0.044     -0.484      0.628      -0.108       0.065
# lobe[T.a2]:dorsal_to_ventral_val          -0.1643      0.063     -2.620      0.009      -0.287      -0.041
# lobe[T.a3]:dorsal_to_ventral_val          -0.0297      0.063     -0.473      0.636      -0.153       0.093
# lobe[T.ap1]:dorsal_to_ventral_val         -0.0595      0.063     -0.948      0.343      -0.182       0.064
# lobe[T.ap2]:dorsal_to_ventral_val         -0.1387      0.063     -2.211      0.027      -0.262      -0.016
# lobe[T.ap3]:dorsal_to_ventral_val         -0.1766      0.063     -2.815      0.005      -0.300      -0.054
# lobe[T.b1]:dorsal_to_ventral_val          -0.0272      0.063     -0.434      0.664      -0.150       0.096
# lobe[T.b2]:dorsal_to_ventral_val           0.0307      0.063      0.489      0.625      -0.092       0.154
# lobe[T.bp1]:dorsal_to_ventral_val          0.0171      0.063      0.273      0.785      -0.106       0.140
# lobe[T.bp2]:dorsal_to_ventral_val          0.0247      0.063      0.394      0.694      -0.098       0.148
# lobe[T.g1]:dorsal_to_ventral_val           0.0002      0.063      0.003      0.998      -0.123       0.123
# lobe[T.g2]:dorsal_to_ventral_val          -0.0621      0.063     -0.989      0.323      -0.185       0.061
# lobe[T.g3]:dorsal_to_ventral_val           0.0584      0.063      0.932      0.352      -0.065       0.181
# lobe[T.g4]:dorsal_to_ventral_val           0.0325      0.063      0.518      0.605      -0.090       0.155
# lobe[T.g5]:dorsal_to_ventral_val           0.0499      0.063      0.796      0.426      -0.073       0.173
# starved                                    0.0676      0.028      2.451      0.014       0.014       0.122
# lobe[T.a2]:starved                        -0.0702      0.039     -1.798      0.072      -0.147       0.006
# lobe[T.a3]:starved                        -0.0700      0.039     -1.793      0.073      -0.146       0.007
# lobe[T.ap1]:starved                       -0.0642      0.039     -1.645      0.100      -0.141       0.012
# lobe[T.ap2]:starved                       -0.0812      0.039     -2.081      0.037      -0.158      -0.005
# lobe[T.ap3]:starved                       -0.0792      0.039     -2.030      0.042      -0.156      -0.003
# lobe[T.b1]:starved                         0.0495      0.039      1.268      0.205      -0.027       0.126
# lobe[T.b2]:starved                        -0.0073      0.039     -0.187      0.852      -0.084       0.069
# lobe[T.bp1]:starved                        0.0448      0.039      1.148      0.251      -0.032       0.121
# lobe[T.bp2]:starved                       -0.0164      0.039     -0.421      0.674      -0.093       0.060
# lobe[T.g1]:starved                        -0.0300      0.039     -0.770      0.441      -0.107       0.046
# lobe[T.g2]:starved                        -0.0756      0.039     -1.938      0.053      -0.152       0.001
# lobe[T.g3]:starved                        -0.0895      0.039     -2.294      0.022      -0.166      -0.013
# lobe[T.g4]:starved                        -0.0508      0.039     -1.301      0.193      -0.127       0.026
# lobe[T.g5]:starved                        -0.0633      0.039     -1.623      0.105      -0.140       0.013
# ==============================================================================
# Omnibus:                     1838.206   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11089.392
# Skew:                           1.487   Prob(JB):                         0.00
# Kurtosis:                       9.338   Cond. No.                         469.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
aov_table = anova_lm(resInter, typ=2)
print(resInter.rsquared)
aov_table
# Out:
# 0.3559549739696527
#                                 sum_sq      df           F        PR(>F)
# lobe                        313.009229    14.0  130.586782  0.000000e+00
# stimulus                     34.680558    11.0   18.414651  1.263860e-36
# lobe:stimulus               116.885093   154.0    4.433110  2.977103e-62
# order_presented               1.083264     1.0    6.327096  1.192056e-02
# lobe:order_presented          1.456470    14.0    0.607636  8.611169e-01
# dorsal_to_ventral_val         3.408663     1.0   19.909215  8.292013e-06
# lobe:dorsal_to_ventral_val    7.141583    14.0    2.979453  1.433614e-04
# starved                       2.529495     1.0   14.774196  1.226271e-04
# lobe:starved                  6.416982    14.0    2.677151  6.440503e-04
# Residual                    891.149612  5205.0         NaN           NaN

# %%
aov_table.to_csv("FullAnovaTable_W3oct&Mch.csv")

# %% [markdown]
# Order presented is not significant so remove it. Also make sure there is no intercept for global lobe response, and remove the global effect of starvation to see the simple effects of starvation for each lobe.

# %%
resnoid = smf.ols(formula="df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val)+lobe:starved-1", data=lobe_data).fit()
resnoid.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.328
# Method:                 Least Squares   F-statistic:                     12.84
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):               0.00
# Time:                        16:48:00   Log-Likelihood:                -2798.3
# No. Observations:                5430   AIC:                             6047.
# Df Residuals:                    5205   BIC:                             7532.
# Df Model:                         224
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# lobe[a1]                                   0.2160      0.100      2.169      0.030       0.021       0.411
# lobe[a2]                                   0.3620      0.100      3.635      0.000       0.167       0.557
# lobe[a3]                                   0.3944      0.100      3.960      0.000       0.199       0.590
# lobe[ap1]                                  0.5552      0.100      5.575      0.000       0.360       0.750
# lobe[ap2]                                  0.3328      0.100      3.341      0.001       0.138       0.528
# lobe[ap3]                                  0.8080      0.100      8.113      0.000       0.613       1.003
# lobe[b1]                                   0.5010      0.100      5.030      0.000       0.306       0.696
# lobe[b2]                                   0.7054      0.100      7.082      0.000       0.510       0.901
# lobe[bp1]                                  1.1251      0.100     11.296      0.000       0.930       1.320
# lobe[bp2]                                  0.7261      0.100      7.290      0.000       0.531       0.921
# lobe[g1]                                   0.5206      0.100      5.227      0.000       0.325       0.716
# lobe[g2]                                   0.7101      0.100      7.130      0.000       0.515       0.905
# lobe[g3]                                   0.9939      0.100      9.979      0.000       0.799       1.189
# lobe[g4]                                   0.8771      0.100      8.806      0.000       0.682       1.072
# lobe[g5]                                   0.2722      0.100      2.733      0.006       0.077       0.467
# stimulus[T.2-Heptanone]                   -0.1427      0.129     -1.103      0.270      -0.396       0.111
# stimulus[T.3Octanol]                       0.0725      0.137      0.531      0.595      -0.195       0.340
# stimulus[T.4MCH]                           0.0514      0.128      0.402      0.688      -0.200       0.302
# stimulus[T.Citronella]                    -0.1406      0.110     -1.279      0.201      -0.356       0.075
# stimulus[T.Ethanol]                       -0.0686      0.147     -0.465      0.642      -0.358       0.220
# stimulus[T.Geosmin]                       -0.1859      0.142     -1.313      0.189      -0.463       0.092
# stimulus[T.Isoamylacetate]                -0.0373      0.124     -0.301      0.764      -0.281       0.206
# stimulus[T.Peppermint]                    -0.0995      0.124     -0.801      0.423      -0.343       0.144
# stimulus[T.Vinegar]                       -0.1933      0.112     -1.720      0.086      -0.414       0.027
# stimulus[T.Yeast]                         -0.1602      0.112     -1.435      0.151      -0.379       0.059
# stimulus[T.cVA]                           -0.0866      0.110     -0.790      0.429      -0.301       0.128
# lobe[T.a2]:stimulus[T.2-Heptanone]         0.2152      0.183      1.177      0.239      -0.143       0.574
# lobe[T.a3]:stimulus[T.2-Heptanone]         0.2394      0.183      1.309      0.191      -0.119       0.598
# lobe[T.ap1]:stimulus[T.2-Heptanone]        0.1809      0.183      0.989      0.323      -0.178       0.539
# lobe[T.ap2]:stimulus[T.2-Heptanone]        0.2607      0.183      1.426      0.154      -0.098       0.619
# lobe[T.ap3]:stimulus[T.2-Heptanone]        0.0051      0.183      0.028      0.978      -0.353       0.364
# lobe[T.b1]:stimulus[T.2-Heptanone]        -0.1599      0.183     -0.874      0.382      -0.518       0.199
# lobe[T.b2]:stimulus[T.2-Heptanone]        -0.1617      0.183     -0.884      0.377      -0.520       0.197
# lobe[T.bp1]:stimulus[T.2-Heptanone]       -0.2068      0.183     -1.131      0.258      -0.565       0.152
# lobe[T.bp2]:stimulus[T.2-Heptanone]       -0.1032      0.183     -0.564      0.572      -0.462       0.255
# lobe[T.g1]:stimulus[T.2-Heptanone]         0.2178      0.183      1.191      0.234      -0.141       0.576
# lobe[T.g2]:stimulus[T.2-Heptanone]         0.0036      0.183      0.020      0.984      -0.355       0.362
# lobe[T.g3]:stimulus[T.2-Heptanone]         0.1766      0.183      0.966      0.334      -0.182       0.535
# lobe[T.g4]:stimulus[T.2-Heptanone]        -0.3041      0.183     -1.663      0.096      -0.663       0.054
# lobe[T.g5]:stimulus[T.2-Heptanone]         0.0277      0.183      0.151      0.880      -0.331       0.386
# lobe[T.a2]:stimulus[T.3Octanol]            0.3170      0.193      1.642      0.101      -0.062       0.696
# lobe[T.a3]:stimulus[T.3Octanol]            0.4023      0.193      2.084      0.037       0.024       0.781
# lobe[T.ap1]:stimulus[T.3Octanol]           0.1519      0.193      0.786      0.432      -0.227       0.530
# lobe[T.ap2]:stimulus[T.3Octanol]           0.3115      0.193      1.613      0.107      -0.067       0.690
# lobe[T.ap3]:stimulus[T.3Octanol]          -0.1325      0.193     -0.686      0.492      -0.511       0.246
# lobe[T.b1]:stimulus[T.3Octanol]            0.0728      0.193      0.377      0.706      -0.306       0.451
# lobe[T.b2]:stimulus[T.3Octanol]           -0.2064      0.193     -1.069      0.285      -0.585       0.172
# lobe[T.bp1]:stimulus[T.3Octanol]          -0.0358      0.193     -0.186      0.853      -0.414       0.343
# lobe[T.bp2]:stimulus[T.3Octanol]          -0.1760      0.193     -0.912      0.362      -0.555       0.203
# lobe[T.g1]:stimulus[T.3Octanol]           -0.0661      0.193     -0.343      0.732      -0.445       0.312
# lobe[T.g2]:stimulus[T.3Octanol]           -0.0359      0.193     -0.186      0.853      -0.414       0.343
# lobe[T.g3]:stimulus[T.3Octanol]           -0.2530      0.193     -1.310      0.190      -0.632       0.126
# lobe[T.g4]:stimulus[T.3Octanol]           -0.5947      0.193     -3.080      0.002      -0.973      -0.216
# lobe[T.g5]:stimulus[T.3Octanol]           -0.2359      0.193     -1.222      0.222      -0.614       0.143
# lobe[T.a2]:stimulus[T.4MCH]               -0.1017      0.181     -0.562      0.574      -0.457       0.253
# lobe[T.a3]:stimulus[T.4MCH]               -0.0157      0.181     -0.087      0.931      -0.371       0.339
# lobe[T.ap1]:stimulus[T.4MCH]              -0.1684      0.181     -0.930      0.352      -0.523       0.187
# lobe[T.ap2]:stimulus[T.4MCH]              -0.0642      0.181     -0.355      0.723      -0.419       0.291
# lobe[T.ap3]:stimulus[T.4MCH]              -0.3229      0.181     -1.784      0.074      -0.678       0.032
# lobe[T.b1]:stimulus[T.4MCH]                0.4284      0.181      2.367      0.018       0.074       0.783
# lobe[T.b2]:stimulus[T.4MCH]                0.4803      0.181      2.653      0.008       0.125       0.835
# lobe[T.bp1]:stimulus[T.4MCH]               0.0303      0.181      0.168      0.867      -0.325       0.385
# lobe[T.bp2]:stimulus[T.4MCH]               0.3214      0.181      1.776      0.076      -0.033       0.676
# lobe[T.g1]:stimulus[T.4MCH]               -0.0768      0.181     -0.424      0.672      -0.432       0.278
# lobe[T.g2]:stimulus[T.4MCH]               -0.2216      0.181     -1.224      0.221      -0.577       0.133
# lobe[T.g3]:stimulus[T.4MCH]               -0.1976      0.181     -1.092      0.275      -0.553       0.157
# lobe[T.g4]:stimulus[T.4MCH]                0.2200      0.181      1.215      0.224      -0.135       0.575
# lobe[T.g5]:stimulus[T.4MCH]                0.0242      0.181      0.134      0.894      -0.331       0.379
# lobe[T.a2]:stimulus[T.Citronella]          0.2072      0.155      1.333      0.183      -0.098       0.512
# lobe[T.a3]:stimulus[T.Citronella]          0.1969      0.155      1.266      0.205      -0.108       0.502
# lobe[T.ap1]:stimulus[T.Citronella]         0.0898      0.155      0.577      0.564      -0.215       0.395
# lobe[T.ap2]:stimulus[T.Citronella]         0.2426      0.155      1.560      0.119      -0.062       0.547
# lobe[T.ap3]:stimulus[T.Citronella]         0.3147      0.155      2.024      0.043       0.010       0.619
# lobe[T.b1]:stimulus[T.Citronella]         -0.0915      0.155     -0.588      0.556      -0.396       0.213
# lobe[T.b2]:stimulus[T.Citronella]         -0.0717      0.155     -0.461      0.645      -0.376       0.233
# lobe[T.bp1]:stimulus[T.Citronella]        -0.2628      0.155     -1.691      0.091      -0.568       0.042
# lobe[T.bp2]:stimulus[T.Citronella]        -0.0176      0.155     -0.113      0.910      -0.322       0.287
# lobe[T.g1]:stimulus[T.Citronella]         -0.0820      0.155     -0.528      0.598      -0.387       0.223
# lobe[T.g2]:stimulus[T.Citronella]         -0.0366      0.155     -0.235      0.814      -0.341       0.268
# lobe[T.g3]:stimulus[T.Citronella]         -0.1121      0.155     -0.721      0.471      -0.417       0.193
# lobe[T.g4]:stimulus[T.Citronella]         -0.2691      0.155     -1.731      0.084      -0.574       0.036
# lobe[T.g5]:stimulus[T.Citronella]          0.0133      0.155      0.085      0.932      -0.292       0.318
# lobe[T.a2]:stimulus[T.Ethanol]             0.1290      0.209      0.619      0.536      -0.280       0.538
# lobe[T.a3]:stimulus[T.Ethanol]             0.0622      0.209      0.298      0.766      -0.347       0.471
# lobe[T.ap1]:stimulus[T.Ethanol]           -0.1698      0.209     -0.814      0.415      -0.579       0.239
# lobe[T.ap2]:stimulus[T.Ethanol]            0.0920      0.209      0.441      0.659      -0.317       0.501
# lobe[T.ap3]:stimulus[T.Ethanol]            0.4969      0.209      2.382      0.017       0.088       0.906
# lobe[T.b1]:stimulus[T.Ethanol]            -0.0340      0.209     -0.163      0.870      -0.443       0.375
# lobe[T.b2]:stimulus[T.Ethanol]            -0.0057      0.209     -0.027      0.978      -0.414       0.403
# lobe[T.bp1]:stimulus[T.Ethanol]            0.1263      0.209      0.606      0.545      -0.283       0.535
# lobe[T.bp2]:stimulus[T.Ethanol]           -0.2378      0.209     -1.140      0.254      -0.647       0.171
# lobe[T.g1]:stimulus[T.Ethanol]            -0.2036      0.209     -0.976      0.329      -0.612       0.205
# lobe[T.g2]:stimulus[T.Ethanol]            -0.2044      0.209     -0.980      0.327      -0.613       0.204
# lobe[T.g3]:stimulus[T.Ethanol]            -0.3660      0.209     -1.755      0.079      -0.775       0.043
# lobe[T.g4]:stimulus[T.Ethanol]            -0.4903      0.209     -2.351      0.019      -0.899      -0.081
# lobe[T.g5]:stimulus[T.Ethanol]            -0.1270      0.209     -0.609      0.543      -0.536       0.282
# lobe[T.a2]:stimulus[T.Geosmin]             0.1249      0.200      0.624      0.533      -0.268       0.517
# lobe[T.a3]:stimulus[T.Geosmin]            -0.0202      0.200     -0.101      0.919      -0.413       0.372
# lobe[T.ap1]:stimulus[T.Geosmin]           -0.1472      0.200     -0.735      0.462      -0.540       0.245
# lobe[T.ap2]:stimulus[T.Geosmin]            0.1479      0.200      0.739      0.460      -0.245       0.540
# lobe[T.ap3]:stimulus[T.Geosmin]            0.0041      0.200      0.020      0.984      -0.388       0.397
# lobe[T.b1]:stimulus[T.Geosmin]            -0.0255      0.200     -0.128      0.899      -0.418       0.367
# lobe[T.b2]:stimulus[T.Geosmin]            -0.0087      0.200     -0.043      0.965      -0.401       0.384
# lobe[T.bp1]:stimulus[T.Geosmin]           -0.0836      0.200     -0.418      0.676      -0.476       0.309
# lobe[T.bp2]:stimulus[T.Geosmin]           -0.1029      0.200     -0.514      0.607      -0.495       0.290
# lobe[T.g1]:stimulus[T.Geosmin]            -0.1932      0.200     -0.965      0.335      -0.586       0.199
# lobe[T.g2]:stimulus[T.Geosmin]            -0.2667      0.200     -1.332      0.183      -0.659       0.126
# lobe[T.g3]:stimulus[T.Geosmin]            -0.5191      0.200     -2.593      0.010      -0.912      -0.127
# lobe[T.g4]:stimulus[T.Geosmin]            -0.4108      0.200     -2.052      0.040      -0.803      -0.018
# lobe[T.g5]:stimulus[T.Geosmin]             0.0134      0.200      0.067      0.947      -0.379       0.406
# lobe[T.a2]:stimulus[T.Isoamylacetate]      0.2757      0.176      1.569      0.117      -0.069       0.620
# lobe[T.a3]:stimulus[T.Isoamylacetate]      0.2932      0.176      1.669      0.095      -0.051       0.638
# lobe[T.ap1]:stimulus[T.Isoamylacetate]     0.0725      0.176      0.413      0.680      -0.272       0.417
# lobe[T.ap2]:stimulus[T.Isoamylacetate]     0.2535      0.176      1.443      0.149      -0.091       0.598
# lobe[T.ap3]:stimulus[T.Isoamylacetate]     0.1499      0.176      0.853      0.394      -0.194       0.494
# lobe[T.b1]:stimulus[T.Isoamylacetate]     -0.1249      0.176     -0.711      0.477      -0.469       0.219
# lobe[T.b2]:stimulus[T.Isoamylacetate]     -0.2676      0.176     -1.523      0.128      -0.612       0.077
# lobe[T.bp1]:stimulus[T.Isoamylacetate]     0.1870      0.176      1.065      0.287      -0.157       0.531
# lobe[T.bp2]:stimulus[T.Isoamylacetate]    -0.1839      0.176     -1.047      0.295      -0.528       0.160
# lobe[T.g1]:stimulus[T.Isoamylacetate]      0.1402      0.176      0.798      0.425      -0.204       0.484
# lobe[T.g2]:stimulus[T.Isoamylacetate]     -0.0024      0.176     -0.014      0.989      -0.347       0.342
# lobe[T.g3]:stimulus[T.Isoamylacetate]      0.0324      0.176      0.185      0.854      -0.312       0.377
# lobe[T.g4]:stimulus[T.Isoamylacetate]     -0.3870      0.176     -2.203      0.028      -0.731      -0.043
# lobe[T.g5]:stimulus[T.Isoamylacetate]     -0.0733      0.176     -0.417      0.677      -0.418       0.271
# lobe[T.a2]:stimulus[T.Peppermint]          0.2506      0.176      1.426      0.154      -0.094       0.595
# lobe[T.a3]:stimulus[T.Peppermint]          0.2930      0.176      1.667      0.096      -0.052       0.638
# lobe[T.ap1]:stimulus[T.Peppermint]         0.3028      0.176      1.723      0.085      -0.042       0.647
# lobe[T.ap2]:stimulus[T.Peppermint]         0.3027      0.176      1.722      0.085      -0.042       0.647
# lobe[T.ap3]:stimulus[T.Peppermint]         0.3625      0.176      2.062      0.039       0.018       0.707
# lobe[T.b1]:stimulus[T.Peppermint]          0.0055      0.176      0.031      0.975      -0.339       0.350
# lobe[T.b2]:stimulus[T.Peppermint]         -0.1500      0.176     -0.853      0.394      -0.495       0.195
# lobe[T.bp1]:stimulus[T.Peppermint]         0.4025      0.176      2.290      0.022       0.058       0.747
# lobe[T.bp2]:stimulus[T.Peppermint]         0.0194      0.176      0.111      0.912      -0.325       0.364
# lobe[T.g1]:stimulus[T.Peppermint]          0.1262      0.176      0.718      0.473      -0.218       0.471
# lobe[T.g2]:stimulus[T.Peppermint]          0.1139      0.176      0.648      0.517      -0.231       0.459
# lobe[T.g3]:stimulus[T.Peppermint]          0.2965      0.176      1.687      0.092      -0.048       0.641
# lobe[T.g4]:stimulus[T.Peppermint]         -0.1201      0.176     -0.683      0.495      -0.465       0.224
# lobe[T.g5]:stimulus[T.Peppermint]          0.0553      0.176      0.315      0.753      -0.289       0.400
# lobe[T.a2]:stimulus[T.Vinegar]             0.1446      0.159      0.910      0.363      -0.167       0.456
# lobe[T.a3]:stimulus[T.Vinegar]            -0.0058      0.159     -0.036      0.971      -0.317       0.306
# lobe[T.ap1]:stimulus[T.Vinegar]           -0.0865      0.159     -0.544      0.587      -0.398       0.225
# lobe[T.ap2]:stimulus[T.Vinegar]            0.1711      0.159      1.076      0.282      -0.141       0.483
# lobe[T.ap3]:stimulus[T.Vinegar]            0.2965      0.159      1.865      0.062      -0.015       0.608
# lobe[T.b1]:stimulus[T.Vinegar]             0.2004      0.159      1.260      0.208      -0.111       0.512
# lobe[T.b2]:stimulus[T.Vinegar]             0.2762      0.159      1.737      0.082      -0.036       0.588
# lobe[T.bp1]:stimulus[T.Vinegar]           -0.1341      0.159     -0.843      0.399      -0.446       0.178
# lobe[T.bp2]:stimulus[T.Vinegar]            0.2694      0.159      1.694      0.090      -0.042       0.581
# lobe[T.g1]:stimulus[T.Vinegar]            -0.0430      0.159     -0.270      0.787      -0.355       0.269
# lobe[T.g2]:stimulus[T.Vinegar]            -0.1971      0.159     -1.239      0.215      -0.509       0.115
# lobe[T.g3]:stimulus[T.Vinegar]            -0.0813      0.159     -0.511      0.609      -0.393       0.230
# lobe[T.g4]:stimulus[T.Vinegar]             0.2850      0.159      1.792      0.073      -0.027       0.597
# lobe[T.g5]:stimulus[T.Vinegar]             0.1521      0.159      0.957      0.339      -0.160       0.464
# lobe[T.a2]:stimulus[T.Yeast]               0.1983      0.158      1.256      0.209      -0.111       0.508
# lobe[T.a3]:stimulus[T.Yeast]               0.0940      0.158      0.595      0.552      -0.216       0.404
# lobe[T.ap1]:stimulus[T.Yeast]             -0.0230      0.158     -0.146      0.884      -0.333       0.287
# lobe[T.ap2]:stimulus[T.Yeast]              0.2469      0.158      1.563      0.118      -0.063       0.556
# lobe[T.ap3]:stimulus[T.Yeast]              0.4736      0.158      2.999      0.003       0.164       0.783
# lobe[T.b1]:stimulus[T.Yeast]               0.0473      0.158      0.300      0.764      -0.262       0.357
# lobe[T.b2]:stimulus[T.Yeast]               0.1507      0.158      0.954      0.340      -0.159       0.460
# lobe[T.bp1]:stimulus[T.Yeast]             -0.0132      0.158     -0.084      0.933      -0.323       0.296
# lobe[T.bp2]:stimulus[T.Yeast]              0.3170      0.158      2.008      0.045       0.007       0.627
# lobe[T.g1]:stimulus[T.Yeast]               0.0448      0.158      0.283      0.777      -0.265       0.354
# lobe[T.g2]:stimulus[T.Yeast]              -0.1568      0.158     -0.993      0.321      -0.466       0.153
# lobe[T.g3]:stimulus[T.Yeast]              -0.0180      0.158     -0.114      0.909      -0.328       0.292
# lobe[T.g4]:stimulus[T.Yeast]               0.1859      0.158      1.177      0.239      -0.124       0.495
# lobe[T.g5]:stimulus[T.Yeast]               0.1394      0.158      0.882      0.378      -0.170       0.449
# lobe[T.a2]:stimulus[T.cVA]                 0.2961      0.155      1.911      0.056      -0.008       0.600
# lobe[T.a3]:stimulus[T.cVA]                 0.1424      0.155      0.919      0.358      -0.161       0.446
# lobe[T.ap1]:stimulus[T.cVA]                0.1584      0.155      1.022      0.307      -0.145       0.462
# lobe[T.ap2]:stimulus[T.cVA]                0.2921      0.155      1.885      0.059      -0.012       0.596
# lobe[T.ap3]:stimulus[T.cVA]                0.2377      0.155      1.534      0.125      -0.066       0.541
# lobe[T.b1]:stimulus[T.cVA]                -0.0782      0.155     -0.504      0.614      -0.382       0.226
# lobe[T.b2]:stimulus[T.cVA]                 0.0196      0.155      0.127      0.899      -0.284       0.323
# lobe[T.bp1]:stimulus[T.cVA]                0.0701      0.155      0.452      0.651      -0.234       0.374
# lobe[T.bp2]:stimulus[T.cVA]               -0.2206      0.155     -1.424      0.154      -0.524       0.083
# lobe[T.g1]:stimulus[T.cVA]                -0.1078      0.155     -0.696      0.487      -0.412       0.196
# lobe[T.g2]:stimulus[T.cVA]                 0.0013      0.155      0.009      0.993      -0.302       0.305
# lobe[T.g3]:stimulus[T.cVA]                -0.3151      0.155     -2.034      0.042      -0.619      -0.011
# lobe[T.g4]:stimulus[T.cVA]                -0.5078      0.155     -3.278      0.001      -0.812      -0.204
# lobe[T.g5]:stimulus[T.cVA]                -0.1134      0.155     -0.732      0.464      -0.417       0.190
# order_presented                           -0.0458      0.420     -0.109      0.913      -0.869       0.777
# lobe[T.a2]:order_presented                -0.3260      0.594     -0.549      0.583      -1.490       0.838
# lobe[T.a3]:order_presented                -0.2438      0.594     -0.411      0.681      -1.408       0.920
# lobe[T.ap1]:order_presented               -0.1895      0.594     -0.319      0.750      -1.353       0.974
# lobe[T.ap2]:order_presented               -0.2310      0.594     -0.389      0.697      -1.395       0.933
# lobe[T.ap3]:order_presented               -1.0367      0.594     -1.746      0.081      -2.201       0.127
# lobe[T.b1]:order_presented                 0.3309      0.594      0.557      0.577      -0.833       1.495
# lobe[T.b2]:order_presented                 0.0900      0.594      0.152      0.880      -1.074       1.254
# lobe[T.bp1]:order_presented               -0.5851      0.594     -0.986      0.324      -1.749       0.579
# lobe[T.bp2]:order_presented               -0.2268      0.594     -0.382      0.702      -1.391       0.937
# lobe[T.g1]:order_presented                -0.1848      0.594     -0.311      0.756      -1.349       0.979
# lobe[T.g2]:order_presented                -0.0100      0.594     -0.017      0.987      -1.174       1.154
# lobe[T.g3]:order_presented                -0.3124      0.594     -0.526      0.599      -1.476       0.851
# lobe[T.g4]:order_presented                -0.5422      0.594     -0.913      0.361      -1.706       0.622
# lobe[T.g5]:order_presented                 0.0645      0.594      0.109      0.913      -1.099       1.228
# dorsal_to_ventral_val                     -0.0215      0.044     -0.484      0.628      -0.108       0.065
# lobe[T.a2]:dorsal_to_ventral_val          -0.1643      0.063     -2.620      0.009      -0.287      -0.041
# lobe[T.a3]:dorsal_to_ventral_val          -0.0297      0.063     -0.473      0.636      -0.153       0.093
# lobe[T.ap1]:dorsal_to_ventral_val         -0.0595      0.063     -0.948      0.343      -0.182       0.064
# lobe[T.ap2]:dorsal_to_ventral_val         -0.1387      0.063     -2.211      0.027      -0.262      -0.016
# lobe[T.ap3]:dorsal_to_ventral_val         -0.1766      0.063     -2.815      0.005      -0.300      -0.054
# lobe[T.b1]:dorsal_to_ventral_val          -0.0272      0.063     -0.434      0.664      -0.150       0.096
# lobe[T.b2]:dorsal_to_ventral_val           0.0307      0.063      0.489      0.625      -0.092       0.154
# lobe[T.bp1]:dorsal_to_ventral_val          0.0171      0.063      0.273      0.785      -0.106       0.140
# lobe[T.bp2]:dorsal_to_ventral_val          0.0247      0.063      0.394      0.694      -0.098       0.148
# lobe[T.g1]:dorsal_to_ventral_val           0.0002      0.063      0.003      0.998      -0.123       0.123
# lobe[T.g2]:dorsal_to_ventral_val          -0.0621      0.063     -0.989      0.323      -0.185       0.061
# lobe[T.g3]:dorsal_to_ventral_val           0.0584      0.063      0.932      0.352      -0.065       0.181
# lobe[T.g4]:dorsal_to_ventral_val           0.0325      0.063      0.518      0.605      -0.090       0.155
# lobe[T.g5]:dorsal_to_ventral_val           0.0499      0.063      0.796      0.426      -0.073       0.173
# lobe[a1]:starved                           0.0676      0.028      2.451      0.014       0.014       0.122
# lobe[a2]:starved                          -0.0025      0.028     -0.092      0.927      -0.057       0.052
# lobe[a3]:starved                          -0.0023      0.028     -0.085      0.932      -0.056       0.052
# lobe[ap1]:starved                          0.0034      0.028      0.124      0.902      -0.051       0.058
# lobe[ap2]:starved                         -0.0136      0.028     -0.493      0.622      -0.068       0.040
# lobe[ap3]:starved                         -0.0116      0.028     -0.421      0.674      -0.066       0.042
# lobe[b1]:starved                           0.1171      0.028      4.243      0.000       0.063       0.171
# lobe[b2]:starved                           0.0603      0.028      2.186      0.029       0.006       0.114
# lobe[bp1]:starved                          0.1124      0.028      4.075      0.000       0.058       0.167
# lobe[bp2]:starved                          0.0512      0.028      1.855      0.064      -0.003       0.105
# lobe[g1]:starved                           0.0376      0.028      1.362      0.173      -0.017       0.092
# lobe[g2]:starved                          -0.0080      0.028     -0.290      0.772      -0.062       0.046
# lobe[g3]:starved                          -0.0219      0.028     -0.794      0.427      -0.076       0.032
# lobe[g4]:starved                           0.0169      0.028      0.611      0.541      -0.037       0.071
# lobe[g5]:starved                           0.0043      0.028      0.156      0.876      -0.050       0.058
# ==============================================================================
# Omnibus:                     1838.206   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11089.392
# Skew:                           1.487   Prob(JB):                         0.00
# Kurtosis:                       9.338   Cond. No.                         228.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
resnoidb = smf.ols(formula="df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val)+lobe:starved+stimulus:starved-1", data=lobe_data).fit()
resnoidb.summary()
# Out:
# C:\Users\aimon\Anaconda3\lib\site-packages\statsmodels\base\model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\aimon\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\aimon\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\aimon\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     12.80
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):               0.00
# Time:                        16:48:01   Log-Likelihood:                -2756.8
# No. Observations:                5430   AIC:                             5984.
# Df Residuals:                    5195   BIC:                             7535.
# Df Model:                         234
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# lobe[a1]                                   0.3061      0.102      2.987      0.003       0.105       0.507
# lobe[a2]                                   0.4521      0.102      4.412      0.000       0.251       0.653
# lobe[a3]                                   0.4845      0.102      4.729      0.000       0.284       0.685
# lobe[ap1]                                  0.6453      0.102      6.298      0.000       0.444       0.846
# lobe[ap2]                                  0.4228      0.102      4.127      0.000       0.222       0.624
# lobe[ap3]                                  0.8981      0.102      8.765      0.000       0.697       1.099
# lobe[b1]                                   0.5910      0.102      5.768      0.000       0.390       0.792
# lobe[b2]                                   0.7954      0.102      7.763      0.000       0.595       0.996
# lobe[bp1]                                  1.2151      0.102     11.860      0.000       1.014       1.416
# lobe[bp2]                                  0.8161      0.102      7.966      0.000       0.615       1.017
# lobe[g1]                                   0.6107      0.102      5.960      0.000       0.410       0.812
# lobe[g2]                                   0.8002      0.102      7.810      0.000       0.599       1.001
# lobe[g3]                                   1.0839      0.102     10.580      0.000       0.883       1.285
# lobe[g4]                                   0.9671      0.102      9.439      0.000       0.766       1.168
# lobe[g5]                                   0.3623      0.102      3.536      0.000       0.161       0.563
# stimulus[T.2-Heptanone]                   -0.2070      0.134     -1.543      0.123      -0.470       0.056
# stimulus[T.3Octanol]                      -0.0345      0.141     -0.245      0.807      -0.311       0.242
# stimulus[T.4MCH]                          -0.1765      0.132     -1.339      0.181      -0.435       0.082
# stimulus[T.Citronella]                    -0.2926      0.115     -2.546      0.011      -0.518      -0.067
# stimulus[T.Ethanol]                       -0.1406      0.152     -0.923      0.356      -0.439       0.158
# stimulus[T.Geosmin]                       -0.3066      0.145     -2.113      0.035      -0.591      -0.022
# stimulus[T.Isoamylacetate]                -0.0482      0.128     -0.376      0.707      -0.300       0.203
# stimulus[T.Peppermint]                    -0.1553      0.128     -1.212      0.226      -0.407       0.096
# stimulus[T.Vinegar]                       -0.2814      0.117     -2.399      0.016      -0.511      -0.051
# stimulus[T.Yeast]                         -0.2533      0.116     -2.181      0.029      -0.481      -0.026
# stimulus[T.cVA]                           -0.1789      0.112     -1.597      0.110      -0.399       0.041
# lobe[T.a2]:stimulus[T.2-Heptanone]         0.2152      0.182      1.185      0.236      -0.141       0.571
# lobe[T.a3]:stimulus[T.2-Heptanone]         0.2394      0.182      1.318      0.188      -0.117       0.596
# lobe[T.ap1]:stimulus[T.2-Heptanone]        0.1809      0.182      0.996      0.319      -0.175       0.537
# lobe[T.ap2]:stimulus[T.2-Heptanone]        0.2607      0.182      1.435      0.151      -0.095       0.617
# lobe[T.ap3]:stimulus[T.2-Heptanone]        0.0051      0.182      0.028      0.978      -0.351       0.361
# lobe[T.b1]:stimulus[T.2-Heptanone]        -0.1599      0.182     -0.880      0.379      -0.516       0.196
# lobe[T.b2]:stimulus[T.2-Heptanone]        -0.1617      0.182     -0.890      0.374      -0.518       0.194
# lobe[T.bp1]:stimulus[T.2-Heptanone]       -0.2068      0.182     -1.138      0.255      -0.563       0.149
# lobe[T.bp2]:stimulus[T.2-Heptanone]       -0.1032      0.182     -0.568      0.570      -0.459       0.253
# lobe[T.g1]:stimulus[T.2-Heptanone]         0.2178      0.182      1.199      0.231      -0.138       0.574
# lobe[T.g2]:stimulus[T.2-Heptanone]         0.0036      0.182      0.020      0.984      -0.353       0.360
# lobe[T.g3]:stimulus[T.2-Heptanone]         0.1766      0.182      0.972      0.331      -0.180       0.533
# lobe[T.g4]:stimulus[T.2-Heptanone]        -0.3041      0.182     -1.674      0.094      -0.660       0.052
# lobe[T.g5]:stimulus[T.2-Heptanone]         0.0277      0.182      0.152      0.879      -0.328       0.384
# lobe[T.a2]:stimulus[T.3Octanol]            0.3170      0.192      1.653      0.098      -0.059       0.693
# lobe[T.a3]:stimulus[T.3Octanol]            0.4023      0.192      2.098      0.036       0.026       0.778
# lobe[T.ap1]:stimulus[T.3Octanol]           0.1519      0.192      0.792      0.429      -0.224       0.528
# lobe[T.ap2]:stimulus[T.3Octanol]           0.3115      0.192      1.624      0.104      -0.064       0.688
# lobe[T.ap3]:stimulus[T.3Octanol]          -0.1325      0.192     -0.691      0.490      -0.509       0.243
# lobe[T.b1]:stimulus[T.3Octanol]            0.0728      0.192      0.380      0.704      -0.303       0.449
# lobe[T.b2]:stimulus[T.3Octanol]           -0.2064      0.192     -1.076      0.282      -0.582       0.170
# lobe[T.bp1]:stimulus[T.3Octanol]          -0.0358      0.192     -0.187      0.852      -0.412       0.340
# lobe[T.bp2]:stimulus[T.3Octanol]          -0.1760      0.192     -0.918      0.359      -0.552       0.200
# lobe[T.g1]:stimulus[T.3Octanol]           -0.0661      0.192     -0.345      0.730      -0.442       0.310
# lobe[T.g2]:stimulus[T.3Octanol]           -0.0359      0.192     -0.187      0.852      -0.412       0.340
# lobe[T.g3]:stimulus[T.3Octanol]           -0.2530      0.192     -1.319      0.187      -0.629       0.123
# lobe[T.g4]:stimulus[T.3Octanol]           -0.5947      0.192     -3.101      0.002      -0.971      -0.219
# lobe[T.g5]:stimulus[T.3Octanol]           -0.2359      0.192     -1.230      0.219      -0.612       0.140
# lobe[T.a2]:stimulus[T.4MCH]               -0.1017      0.180     -0.565      0.572      -0.454       0.251
# lobe[T.a3]:stimulus[T.4MCH]               -0.0157      0.180     -0.087      0.930      -0.368       0.337
# lobe[T.ap1]:stimulus[T.4MCH]              -0.1684      0.180     -0.936      0.349      -0.521       0.184
# lobe[T.ap2]:stimulus[T.4MCH]              -0.0642      0.180     -0.357      0.721      -0.417       0.288
# lobe[T.ap3]:stimulus[T.4MCH]              -0.3229      0.180     -1.796      0.073      -0.675       0.030
# lobe[T.b1]:stimulus[T.4MCH]                0.4284      0.180      2.382      0.017       0.076       0.781
# lobe[T.b2]:stimulus[T.4MCH]                0.4803      0.180      2.671      0.008       0.128       0.833
# lobe[T.bp1]:stimulus[T.4MCH]               0.0303      0.180      0.169      0.866      -0.322       0.383
# lobe[T.bp2]:stimulus[T.4MCH]               0.3214      0.180      1.787      0.074      -0.031       0.674
# lobe[T.g1]:stimulus[T.4MCH]               -0.0768      0.180     -0.427      0.669      -0.429       0.276
# lobe[T.g2]:stimulus[T.4MCH]               -0.2216      0.180     -1.233      0.218      -0.574       0.131
# lobe[T.g3]:stimulus[T.4MCH]               -0.1976      0.180     -1.099      0.272      -0.550       0.155
# lobe[T.g4]:stimulus[T.4MCH]                0.2200      0.180      1.223      0.221      -0.133       0.572
# lobe[T.g5]:stimulus[T.4MCH]                0.0242      0.180      0.135      0.893      -0.328       0.377
# lobe[T.a2]:stimulus[T.Citronella]          0.2072      0.154      1.342      0.180      -0.096       0.510
# lobe[T.a3]:stimulus[T.Citronella]          0.1969      0.154      1.275      0.202      -0.106       0.500
# lobe[T.ap1]:stimulus[T.Citronella]         0.0898      0.154      0.581      0.561      -0.213       0.393
# lobe[T.ap2]:stimulus[T.Citronella]         0.2426      0.154      1.571      0.116      -0.060       0.545
# lobe[T.ap3]:stimulus[T.Citronella]         0.3147      0.154      2.038      0.042       0.012       0.617
# lobe[T.b1]:stimulus[T.Citronella]         -0.0915      0.154     -0.592      0.554      -0.394       0.211
# lobe[T.b2]:stimulus[T.Citronella]         -0.0717      0.154     -0.464      0.643      -0.374       0.231
# lobe[T.bp1]:stimulus[T.Citronella]        -0.2628      0.154     -1.702      0.089      -0.566       0.040
# lobe[T.bp2]:stimulus[T.Citronella]        -0.0176      0.154     -0.114      0.909      -0.320       0.285
# lobe[T.g1]:stimulus[T.Citronella]         -0.0820      0.154     -0.531      0.595      -0.385       0.221
# lobe[T.g2]:stimulus[T.Citronella]         -0.0366      0.154     -0.237      0.813      -0.339       0.266
# lobe[T.g3]:stimulus[T.Citronella]         -0.1121      0.154     -0.726      0.468      -0.415       0.191
# lobe[T.g4]:stimulus[T.Citronella]         -0.2691      0.154     -1.742      0.082      -0.572       0.034
# lobe[T.g5]:stimulus[T.Citronella]          0.0133      0.154      0.086      0.932      -0.289       0.316
# lobe[T.a2]:stimulus[T.Ethanol]             0.1290      0.207      0.623      0.533      -0.277       0.535
# lobe[T.a3]:stimulus[T.Ethanol]             0.0622      0.207      0.300      0.764      -0.344       0.468
# lobe[T.ap1]:stimulus[T.Ethanol]           -0.1698      0.207     -0.820      0.412      -0.576       0.236
# lobe[T.ap2]:stimulus[T.Ethanol]            0.0920      0.207      0.444      0.657      -0.314       0.498
# lobe[T.ap3]:stimulus[T.Ethanol]            0.4969      0.207      2.398      0.016       0.091       0.903
# lobe[T.b1]:stimulus[T.Ethanol]            -0.0340      0.207     -0.164      0.870      -0.440       0.372
# lobe[T.b2]:stimulus[T.Ethanol]            -0.0057      0.207     -0.027      0.978      -0.412       0.400
# lobe[T.bp1]:stimulus[T.Ethanol]            0.1263      0.207      0.610      0.542      -0.280       0.532
# lobe[T.bp2]:stimulus[T.Ethanol]           -0.2378      0.207     -1.148      0.251      -0.644       0.168
# lobe[T.g1]:stimulus[T.Ethanol]            -0.2036      0.207     -0.983      0.326      -0.610       0.202
# lobe[T.g2]:stimulus[T.Ethanol]            -0.2044      0.207     -0.987      0.324      -0.611       0.202
# lobe[T.g3]:stimulus[T.Ethanol]            -0.3660      0.207     -1.767      0.077      -0.772       0.040
# lobe[T.g4]:stimulus[T.Ethanol]            -0.4903      0.207     -2.367      0.018      -0.896      -0.084
# lobe[T.g5]:stimulus[T.Ethanol]            -0.1270      0.207     -0.613      0.540      -0.533       0.279
# lobe[T.a2]:stimulus[T.Geosmin]             0.1249      0.199      0.628      0.530      -0.265       0.515
# lobe[T.a3]:stimulus[T.Geosmin]            -0.0202      0.199     -0.102      0.919      -0.410       0.370
# lobe[T.ap1]:stimulus[T.Geosmin]           -0.1472      0.199     -0.740      0.459      -0.537       0.243
# lobe[T.ap2]:stimulus[T.Geosmin]            0.1479      0.199      0.744      0.457      -0.242       0.538
# lobe[T.ap3]:stimulus[T.Geosmin]            0.0041      0.199      0.020      0.984      -0.386       0.394
# lobe[T.b1]:stimulus[T.Geosmin]            -0.0255      0.199     -0.128      0.898      -0.415       0.364
# lobe[T.b2]:stimulus[T.Geosmin]            -0.0087      0.199     -0.044      0.965      -0.399       0.381
# lobe[T.bp1]:stimulus[T.Geosmin]           -0.0836      0.199     -0.421      0.674      -0.474       0.306
# lobe[T.bp2]:stimulus[T.Geosmin]           -0.1029      0.199     -0.518      0.605      -0.493       0.287
# lobe[T.g1]:stimulus[T.Geosmin]            -0.1932      0.199     -0.971      0.331      -0.583       0.197
# lobe[T.g2]:stimulus[T.Geosmin]            -0.2667      0.199     -1.341      0.180      -0.657       0.123
# lobe[T.g3]:stimulus[T.Geosmin]            -0.5191      0.199     -2.610      0.009      -0.909      -0.129
# lobe[T.g4]:stimulus[T.Geosmin]            -0.4108      0.199     -2.066      0.039      -0.801      -0.021
# lobe[T.g5]:stimulus[T.Geosmin]             0.0134      0.199      0.067      0.946      -0.377       0.403
# lobe[T.a2]:stimulus[T.Isoamylacetate]      0.2757      0.174      1.580      0.114      -0.066       0.618
# lobe[T.a3]:stimulus[T.Isoamylacetate]      0.2932      0.174      1.680      0.093      -0.049       0.635
# lobe[T.ap1]:stimulus[T.Isoamylacetate]     0.0725      0.174      0.416      0.678      -0.269       0.415
# lobe[T.ap2]:stimulus[T.Isoamylacetate]     0.2535      0.174      1.453      0.146      -0.089       0.596
# lobe[T.ap3]:stimulus[T.Isoamylacetate]     0.1499      0.174      0.859      0.390      -0.192       0.492
# lobe[T.b1]:stimulus[T.Isoamylacetate]     -0.1249      0.174     -0.716      0.474      -0.467       0.217
# lobe[T.b2]:stimulus[T.Isoamylacetate]     -0.2676      0.174     -1.534      0.125      -0.610       0.074
# lobe[T.bp1]:stimulus[T.Isoamylacetate]     0.1870      0.174      1.072      0.284      -0.155       0.529
# lobe[T.bp2]:stimulus[T.Isoamylacetate]    -0.1839      0.174     -1.054      0.292      -0.526       0.158
# lobe[T.g1]:stimulus[T.Isoamylacetate]      0.1402      0.174      0.803      0.422      -0.202       0.482
# lobe[T.g2]:stimulus[T.Isoamylacetate]     -0.0024      0.174     -0.014      0.989      -0.344       0.340
# lobe[T.g3]:stimulus[T.Isoamylacetate]      0.0324      0.174      0.186      0.853      -0.310       0.374
# lobe[T.g4]:stimulus[T.Isoamylacetate]     -0.3870      0.174     -2.218      0.027      -0.729      -0.045
# lobe[T.g5]:stimulus[T.Isoamylacetate]     -0.0733      0.174     -0.420      0.674      -0.415       0.269
# lobe[T.a2]:stimulus[T.Peppermint]          0.2506      0.175      1.435      0.151      -0.092       0.593
# lobe[T.a3]:stimulus[T.Peppermint]          0.2930      0.175      1.678      0.093      -0.049       0.635
# lobe[T.ap1]:stimulus[T.Peppermint]         0.3028      0.175      1.734      0.083      -0.040       0.645
# lobe[T.ap2]:stimulus[T.Peppermint]         0.3027      0.175      1.733      0.083      -0.040       0.645
# lobe[T.ap3]:stimulus[T.Peppermint]         0.3625      0.175      2.076      0.038       0.020       0.705
# lobe[T.b1]:stimulus[T.Peppermint]          0.0055      0.175      0.032      0.975      -0.337       0.348
# lobe[T.b2]:stimulus[T.Peppermint]         -0.1500      0.175     -0.859      0.390      -0.492       0.192
# lobe[T.bp1]:stimulus[T.Peppermint]         0.4025      0.175      2.305      0.021       0.060       0.745
# lobe[T.bp2]:stimulus[T.Peppermint]         0.0194      0.175      0.111      0.911      -0.323       0.362
# lobe[T.g1]:stimulus[T.Peppermint]          0.1262      0.175      0.723      0.470      -0.216       0.468
# lobe[T.g2]:stimulus[T.Peppermint]          0.1139      0.175      0.653      0.514      -0.228       0.456
# lobe[T.g3]:stimulus[T.Peppermint]          0.2965      0.175      1.698      0.090      -0.046       0.639
# lobe[T.g4]:stimulus[T.Peppermint]         -0.1201      0.175     -0.688      0.492      -0.462       0.222
# lobe[T.g5]:stimulus[T.Peppermint]          0.0553      0.175      0.317      0.752      -0.287       0.398
# lobe[T.a2]:stimulus[T.Vinegar]             0.1446      0.158      0.916      0.360      -0.165       0.454
# lobe[T.a3]:stimulus[T.Vinegar]            -0.0058      0.158     -0.037      0.971      -0.315       0.304
# lobe[T.ap1]:stimulus[T.Vinegar]           -0.0865      0.158     -0.547      0.584      -0.396       0.223
# lobe[T.ap2]:stimulus[T.Vinegar]            0.1711      0.158      1.084      0.279      -0.138       0.481
# lobe[T.ap3]:stimulus[T.Vinegar]            0.2965      0.158      1.877      0.061      -0.013       0.606
# lobe[T.b1]:stimulus[T.Vinegar]             0.2004      0.158      1.269      0.205      -0.109       0.510
# lobe[T.b2]:stimulus[T.Vinegar]             0.2762      0.158      1.749      0.080      -0.033       0.586
# lobe[T.bp1]:stimulus[T.Vinegar]           -0.1341      0.158     -0.849      0.396      -0.444       0.176
# lobe[T.bp2]:stimulus[T.Vinegar]            0.2694      0.158      1.705      0.088      -0.040       0.579
# lobe[T.g1]:stimulus[T.Vinegar]            -0.0430      0.158     -0.272      0.785      -0.353       0.267
# lobe[T.g2]:stimulus[T.Vinegar]            -0.1971      0.158     -1.248      0.212      -0.507       0.113
# lobe[T.g3]:stimulus[T.Vinegar]            -0.0813      0.158     -0.515      0.607      -0.391       0.228
# lobe[T.g4]:stimulus[T.Vinegar]             0.2850      0.158      1.804      0.071      -0.025       0.595
# lobe[T.g5]:stimulus[T.Vinegar]             0.1521      0.158      0.963      0.336      -0.158       0.462
# lobe[T.a2]:stimulus[T.Yeast]               0.1983      0.157      1.264      0.206      -0.109       0.506
# lobe[T.a3]:stimulus[T.Yeast]               0.0940      0.157      0.599      0.549      -0.214       0.402
# lobe[T.ap1]:stimulus[T.Yeast]             -0.0230      0.157     -0.147      0.883      -0.331       0.285
# lobe[T.ap2]:stimulus[T.Yeast]              0.2469      0.157      1.574      0.116      -0.061       0.554
# lobe[T.ap3]:stimulus[T.Yeast]              0.4736      0.157      3.019      0.003       0.166       0.781
# lobe[T.b1]:stimulus[T.Yeast]               0.0473      0.157      0.302      0.763      -0.260       0.355
# lobe[T.b2]:stimulus[T.Yeast]               0.1507      0.157      0.961      0.337      -0.157       0.458
# lobe[T.bp1]:stimulus[T.Yeast]             -0.0132      0.157     -0.084      0.933      -0.321       0.294
# lobe[T.bp2]:stimulus[T.Yeast]              0.3170      0.157      2.021      0.043       0.010       0.625
# lobe[T.g1]:stimulus[T.Yeast]               0.0448      0.157      0.285      0.775      -0.263       0.352
# lobe[T.g2]:stimulus[T.Yeast]              -0.1568      0.157     -1.000      0.318      -0.464       0.151
# lobe[T.g3]:stimulus[T.Yeast]              -0.0180      0.157     -0.115      0.909      -0.326       0.290
# lobe[T.g4]:stimulus[T.Yeast]               0.1859      0.157      1.185      0.236      -0.122       0.493
# lobe[T.g5]:stimulus[T.Yeast]               0.1394      0.157      0.888      0.374      -0.168       0.447
# lobe[T.a2]:stimulus[T.cVA]                 0.2961      0.154      1.924      0.054      -0.006       0.598
# lobe[T.a3]:stimulus[T.cVA]                 0.1424      0.154      0.925      0.355      -0.159       0.444
# lobe[T.ap1]:stimulus[T.cVA]                0.1584      0.154      1.029      0.303      -0.143       0.460
# lobe[T.ap2]:stimulus[T.cVA]                0.2921      0.154      1.898      0.058      -0.010       0.594
# lobe[T.ap3]:stimulus[T.cVA]                0.2377      0.154      1.545      0.123      -0.064       0.539
# lobe[T.b1]:stimulus[T.cVA]                -0.0782      0.154     -0.508      0.612      -0.380       0.224
# lobe[T.b2]:stimulus[T.cVA]                 0.0196      0.154      0.128      0.898      -0.282       0.321
# lobe[T.bp1]:stimulus[T.cVA]                0.0701      0.154      0.456      0.649      -0.232       0.372
# lobe[T.bp2]:stimulus[T.cVA]               -0.2206      0.154     -1.434      0.152      -0.522       0.081
# lobe[T.g1]:stimulus[T.cVA]                -0.1078      0.154     -0.701      0.484      -0.409       0.194
# lobe[T.g2]:stimulus[T.cVA]                 0.0013      0.154      0.009      0.993      -0.300       0.303
# lobe[T.g3]:stimulus[T.cVA]                -0.3151      0.154     -2.047      0.041      -0.617      -0.013
# lobe[T.g4]:stimulus[T.cVA]                -0.5078      0.154     -3.300      0.001      -0.810      -0.206
# lobe[T.g5]:stimulus[T.cVA]                -0.1134      0.154     -0.737      0.461      -0.415       0.188
# order_presented                           -0.0428      0.417     -0.102      0.918      -0.861       0.776
# lobe[T.a2]:order_presented                -0.3260      0.590     -0.553      0.580      -1.482       0.830
# lobe[T.a3]:order_presented                -0.2438      0.590     -0.413      0.679      -1.400       0.912
# lobe[T.ap1]:order_presented               -0.1895      0.590     -0.321      0.748      -1.346       0.967
# lobe[T.ap2]:order_presented               -0.2310      0.590     -0.392      0.695      -1.387       0.925
# lobe[T.ap3]:order_presented               -1.0367      0.590     -1.758      0.079      -2.193       0.119
# lobe[T.b1]:order_presented                 0.3309      0.590      0.561      0.575      -0.825       1.487
# lobe[T.b2]:order_presented                 0.0900      0.590      0.153      0.879      -1.066       1.246
# lobe[T.bp1]:order_presented               -0.5851      0.590     -0.992      0.321      -1.741       0.571
# lobe[T.bp2]:order_presented               -0.2268      0.590     -0.385      0.701      -1.383       0.929
# lobe[T.g1]:order_presented                -0.1848      0.590     -0.313      0.754      -1.341       0.971
# lobe[T.g2]:order_presented                -0.0100      0.590     -0.017      0.986      -1.166       1.146
# lobe[T.g3]:order_presented                -0.3124      0.590     -0.530      0.596      -1.469       0.844
# lobe[T.g4]:order_presented                -0.5422      0.590     -0.919      0.358      -1.698       0.614
# lobe[T.g5]:order_presented                 0.0645      0.590      0.109      0.913      -1.092       1.221
# dorsal_to_ventral_val                     -0.0169      0.044     -0.383      0.702      -0.103       0.070
# lobe[T.a2]:dorsal_to_ventral_val          -0.1643      0.062     -2.637      0.008      -0.286      -0.042
# lobe[T.a3]:dorsal_to_ventral_val          -0.0297      0.062     -0.476      0.634      -0.152       0.092
# lobe[T.ap1]:dorsal_to_ventral_val         -0.0595      0.062     -0.954      0.340      -0.182       0.063
# lobe[T.ap2]:dorsal_to_ventral_val         -0.1387      0.062     -2.226      0.026      -0.261      -0.017
# lobe[T.ap3]:dorsal_to_ventral_val         -0.1766      0.062     -2.833      0.005      -0.299      -0.054
# lobe[T.b1]:dorsal_to_ventral_val          -0.0272      0.062     -0.437      0.662      -0.149       0.095
# lobe[T.b2]:dorsal_to_ventral_val           0.0307      0.062      0.493      0.622      -0.091       0.153
# lobe[T.bp1]:dorsal_to_ventral_val          0.0171      0.062      0.275      0.783      -0.105       0.139
# lobe[T.bp2]:dorsal_to_ventral_val          0.0247      0.062      0.397      0.692      -0.097       0.147
# lobe[T.g1]:dorsal_to_ventral_val           0.0002      0.062      0.003      0.998      -0.122       0.122
# lobe[T.g2]:dorsal_to_ventral_val          -0.0621      0.062     -0.996      0.319      -0.184       0.060
# lobe[T.g3]:dorsal_to_ventral_val           0.0584      0.062      0.938      0.348      -0.064       0.181
# lobe[T.g4]:dorsal_to_ventral_val           0.0325      0.062      0.521      0.602      -0.090       0.155
# lobe[T.g5]:dorsal_to_ventral_val           0.0499      0.062      0.801      0.423      -0.072       0.172
# lobe[a1]:starved                          -0.0161      0.037     -0.441      0.659      -0.088       0.055
# lobe[a2]:starved                          -0.0863      0.037     -2.362      0.018      -0.158      -0.015
# lobe[a3]:starved                          -0.0861      0.037     -2.357      0.018      -0.158      -0.014
# lobe[ap1]:starved                         -0.0803      0.037     -2.199      0.028      -0.152      -0.009
# lobe[ap2]:starved                         -0.0974      0.037     -2.665      0.008      -0.169      -0.026
# lobe[ap3]:starved                         -0.0954      0.037     -2.611      0.009      -0.167      -0.024
# lobe[b1]:starved                           0.0333      0.037      0.913      0.361      -0.038       0.105
# lobe[b2]:starved                          -0.0234      0.037     -0.641      0.521      -0.095       0.048
# lobe[bp1]:starved                          0.0287      0.037      0.785      0.432      -0.043       0.100
# lobe[bp2]:starved                         -0.0325      0.037     -0.891      0.373      -0.104       0.039
# lobe[g1]:starved                          -0.0462      0.037     -1.264      0.206      -0.118       0.025
# lobe[g2]:starved                          -0.0918      0.037     -2.512      0.012      -0.163      -0.020
# lobe[g3]:starved                          -0.1057      0.037     -2.893      0.004      -0.177      -0.034
# lobe[g4]:starved                          -0.0669      0.037     -1.831      0.067      -0.139       0.005
# lobe[g5]:starved                          -0.0795      0.037     -2.175      0.030      -0.151      -0.008
# stimulus[T.2-Heptanone]:starved            0.0597      0.034      1.736      0.083      -0.008       0.127
# stimulus[T.3Octanol]:starved               0.0986      0.037      2.696      0.007       0.027       0.170
# stimulus[T.4MCH]:starved                   0.2410      0.035      6.847      0.000       0.172       0.310
# stimulus[T.Citronella]:starved             0.1396      0.033      4.265      0.000       0.075       0.204
# stimulus[T.Ethanol]:starved                0.0647      0.039      1.667      0.095      -0.011       0.141
# stimulus[T.Geosmin]:starved                0.1193      0.038      3.172      0.002       0.046       0.193
# stimulus[T.Isoamylacetate]:starved        -0.0011      0.034     -0.032      0.974      -0.067       0.065
# stimulus[T.Peppermint]:starved             0.0423      0.034      1.232      0.218      -0.025       0.110
# stimulus[T.Vinegar]:starved                0.0803      0.033      2.451      0.014       0.016       0.144
# stimulus[T.Yeast]:starved                  0.0850      0.032      2.677      0.007       0.023       0.147
# stimulus[T.cVA]:starved                         0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                     1838.861   Durbin-Watson:                   1.465
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11013.163
# Skew:                           1.490   Prob(JB):                         0.00
# Kurtosis:                       9.309   Cond. No.                     1.43e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.73e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# Evaluate the model using cross validation and VIF

# %%
#formulanoid="df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val)+starved:lobe-1"
##cv_ols_noid = cross_val_score(SMFormulaWrapper(smf.ols, formulanoid),lobe_data, lobe_data['df_f'], cv=6)
#print ("All no ID "+str(np.mean(cv_ols_noid)))

# %%
y, X = dmatrices('df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val)+starved:lobe-1', lobe_data, return_type='dataframe')
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
np.max(vif.round(1))
# Out:
# VIF Factor               58.1
# features      stimulus[T.cVA]
# dtype: object

# %% [markdown]
# There is definitely some overfitting and still multicolinearity: will need to compare the coefficient obtained with this model with simpler and/or regularized models

# %% [markdown]
# #### Regularized model:lasso

# %%
result_reg_lasso = smf.ols(formula="df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val)+starved:lobe-1", data=lobe_data).fit_regularized(L1_wt=1)

# %%
result_reg = smf.ols(formula="df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val)+starved:lobe-1", data=lobe_data).fit_regularized()

# %%
result_reg_ridge = smf.ols(formula="df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val)+starved:lobe-1", data=lobe_data).fit_regularized(L1_wt=0)

# %% [markdown]
# #### Mixed model with fly individuality

# %%
resAllmm = smf.mixedlm(formula="df_f ~ lobe*(stimulus+order_presented+dorsal_to_ventral_val)+starved:lobe-1", data=lobe_data,groups=lobe_data["fly_id"]).fit()

resAllmm.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:                     MixedLM         Dependent Variable:         df_f
# No. Observations:          5430            Method:                     REML
# No. Groups:                185             Scale:                      0.1433
# Min. group size:           15              Likelihood:                 -2863.2076
# Max. group size:           60              Converged:                  Yes
# Mean group size:           29.4
# ---------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------
# lobe[a1]                                0.194    0.101  1.918 0.055 -0.004  0.392
# lobe[a2]                                0.340    0.101  3.363 0.001  0.142  0.538
# lobe[a3]                                0.372    0.101  3.683 0.000  0.174  0.570
# lobe[ap1]                               0.533    0.101  5.275 0.000  0.335  0.731
# lobe[ap2]                               0.310    0.101  3.073 0.002  0.112  0.509
# lobe[ap3]                               0.786    0.101  7.777 0.000  0.588  0.984
# lobe[b1]                                0.479    0.101  4.738 0.000  0.281  0.677
# lobe[b2]                                0.683    0.101  6.761 0.000  0.485  0.881
# lobe[bp1]                               1.103    0.101 10.915 0.000  0.905  1.301
# lobe[bp2]                               0.704    0.101  6.966 0.000  0.506  0.902
# lobe[g1]                                0.498    0.101  4.933 0.000  0.300  0.696
# lobe[g2]                                0.688    0.101  6.808 0.000  0.490  0.886
# lobe[g3]                                0.972    0.101  9.617 0.000  0.774  1.170
# lobe[g4]                                0.855    0.101  8.460 0.000  0.657  1.053
# lobe[g5]                                0.250    0.101  2.474 0.013  0.052  0.448
# stimulus[T.2-Heptanone]                -0.138    0.128 -1.078 0.281 -0.389  0.113
# stimulus[T.3Octanol]                    0.068    0.135  0.505 0.613 -0.197  0.334
# stimulus[T.4MCH]                        0.127    0.128  0.993 0.321 -0.124  0.378
# stimulus[T.Citronella]                 -0.139    0.110 -1.259 0.208 -0.355  0.077
# stimulus[T.Ethanol]                    -0.046    0.146 -0.313 0.754 -0.333  0.241
# stimulus[T.Geosmin]                    -0.157    0.142 -1.105 0.269 -0.436  0.122
# stimulus[T.Isoamylacetate]             -0.026    0.122 -0.212 0.832 -0.264  0.213
# stimulus[T.Peppermint]                 -0.144    0.121 -1.187 0.235 -0.382  0.094
# stimulus[T.Vinegar]                    -0.145    0.112 -1.291 0.197 -0.365  0.075
# stimulus[T.Yeast]                      -0.100    0.112 -0.897 0.370 -0.319  0.119
# stimulus[T.cVA]                        -0.066    0.113 -0.582 0.561 -0.288  0.156
# lobe[T.a2]:stimulus[T.2-Heptanone]      0.215    0.167  1.286 0.198 -0.113  0.543
# lobe[T.a3]:stimulus[T.2-Heptanone]      0.239    0.167  1.431 0.153 -0.089  0.567
# lobe[T.ap1]:stimulus[T.2-Heptanone]     0.181    0.167  1.081 0.280 -0.147  0.509
# lobe[T.ap2]:stimulus[T.2-Heptanone]     0.261    0.167  1.558 0.119 -0.067  0.589
# lobe[T.ap3]:stimulus[T.2-Heptanone]     0.005    0.167  0.031 0.976 -0.323  0.333
# lobe[T.b1]:stimulus[T.2-Heptanone]     -0.160    0.167 -0.956 0.339 -0.488  0.168
# lobe[T.b2]:stimulus[T.2-Heptanone]     -0.162    0.167 -0.966 0.334 -0.490  0.166
# lobe[T.bp1]:stimulus[T.2-Heptanone]    -0.207    0.167 -1.236 0.217 -0.535  0.121
# lobe[T.bp2]:stimulus[T.2-Heptanone]    -0.103    0.167 -0.617 0.537 -0.431  0.225
# lobe[T.g1]:stimulus[T.2-Heptanone]      0.218    0.167  1.302 0.193 -0.110  0.546
# lobe[T.g2]:stimulus[T.2-Heptanone]      0.004    0.167  0.021 0.983 -0.324  0.332
# lobe[T.g3]:stimulus[T.2-Heptanone]      0.177    0.167  1.055 0.291 -0.151  0.505
# lobe[T.g4]:stimulus[T.2-Heptanone]     -0.304    0.167 -1.817 0.069 -0.632  0.024
# lobe[T.g5]:stimulus[T.2-Heptanone]      0.028    0.167  0.166 0.869 -0.300  0.356
# lobe[T.a2]:stimulus[T.3Octanol]         0.317    0.177  1.794 0.073 -0.029  0.663
# lobe[T.a3]:stimulus[T.3Octanol]         0.402    0.177  2.278 0.023  0.056  0.749
# lobe[T.ap1]:stimulus[T.3Octanol]        0.152    0.177  0.860 0.390 -0.194  0.498
# lobe[T.ap2]:stimulus[T.3Octanol]        0.312    0.177  1.764 0.078 -0.035  0.658
# lobe[T.ap3]:stimulus[T.3Octanol]       -0.133    0.177 -0.750 0.453 -0.479  0.214
# lobe[T.b1]:stimulus[T.3Octanol]         0.073    0.177  0.412 0.680 -0.273  0.419
# lobe[T.b2]:stimulus[T.3Octanol]        -0.206    0.177 -1.168 0.243 -0.553  0.140
# lobe[T.bp1]:stimulus[T.3Octanol]       -0.036    0.177 -0.203 0.839 -0.382  0.310
# lobe[T.bp2]:stimulus[T.3Octanol]       -0.176    0.177 -0.996 0.319 -0.522  0.170
# lobe[T.g1]:stimulus[T.3Octanol]        -0.066    0.177 -0.374 0.708 -0.412  0.280
# lobe[T.g2]:stimulus[T.3Octanol]        -0.036    0.177 -0.203 0.839 -0.382  0.310
# lobe[T.g3]:stimulus[T.3Octanol]        -0.253    0.177 -1.432 0.152 -0.599  0.093
# lobe[T.g4]:stimulus[T.3Octanol]        -0.595    0.177 -3.366 0.001 -0.941 -0.248
# lobe[T.g5]:stimulus[T.3Octanol]        -0.236    0.177 -1.335 0.182 -0.582  0.110
# lobe[T.a2]:stimulus[T.4MCH]            -0.102    0.166 -0.614 0.539 -0.426  0.223
# lobe[T.a3]:stimulus[T.4MCH]            -0.016    0.166 -0.095 0.925 -0.340  0.309
# lobe[T.ap1]:stimulus[T.4MCH]           -0.168    0.166 -1.016 0.309 -0.493  0.156
# lobe[T.ap2]:stimulus[T.4MCH]           -0.064    0.166 -0.388 0.698 -0.389  0.260
# lobe[T.ap3]:stimulus[T.4MCH]           -0.323    0.166 -1.950 0.051 -0.648  0.002
# lobe[T.b1]:stimulus[T.4MCH]             0.428    0.166  2.587 0.010  0.104  0.753
# lobe[T.b2]:stimulus[T.4MCH]             0.480    0.166  2.900 0.004  0.156  0.805
# lobe[T.bp1]:stimulus[T.4MCH]            0.030    0.166  0.183 0.855 -0.294  0.355
# lobe[T.bp2]:stimulus[T.4MCH]            0.321    0.166  1.941 0.052 -0.003  0.646
# lobe[T.g1]:stimulus[T.4MCH]            -0.077    0.166 -0.463 0.643 -0.401  0.248
# lobe[T.g2]:stimulus[T.4MCH]            -0.222    0.166 -1.338 0.181 -0.546  0.103
# lobe[T.g3]:stimulus[T.4MCH]            -0.198    0.166 -1.193 0.233 -0.522  0.127
# lobe[T.g4]:stimulus[T.4MCH]             0.220    0.166  1.328 0.184 -0.105  0.545
# lobe[T.g5]:stimulus[T.4MCH]             0.024    0.166  0.146 0.884 -0.300  0.349
# lobe[T.a2]:stimulus[T.Citronella]       0.207    0.142  1.457 0.145 -0.072  0.486
# lobe[T.a3]:stimulus[T.Citronella]       0.197    0.142  1.384 0.166 -0.082  0.476
# lobe[T.ap1]:stimulus[T.Citronella]      0.090    0.142  0.631 0.528 -0.189  0.369
# lobe[T.ap2]:stimulus[T.Citronella]      0.243    0.142  1.705 0.088 -0.036  0.521
# lobe[T.ap3]:stimulus[T.Citronella]      0.315    0.142  2.212 0.027  0.036  0.593
# lobe[T.b1]:stimulus[T.Citronella]      -0.091    0.142 -0.643 0.520 -0.370  0.187
# lobe[T.b2]:stimulus[T.Citronella]      -0.072    0.142 -0.504 0.614 -0.350  0.207
# lobe[T.bp1]:stimulus[T.Citronella]     -0.263    0.142 -1.848 0.065 -0.542  0.016
# lobe[T.bp2]:stimulus[T.Citronella]     -0.018    0.142 -0.124 0.902 -0.296  0.261
# lobe[T.g1]:stimulus[T.Citronella]      -0.082    0.142 -0.577 0.564 -0.361  0.197
# lobe[T.g2]:stimulus[T.Citronella]      -0.037    0.142 -0.257 0.797 -0.315  0.242
# lobe[T.g3]:stimulus[T.Citronella]      -0.112    0.142 -0.788 0.431 -0.391  0.167
# lobe[T.g4]:stimulus[T.Citronella]      -0.269    0.142 -1.892 0.059 -0.548  0.010
# lobe[T.g5]:stimulus[T.Citronella]       0.013    0.142  0.093 0.926 -0.266  0.292
# lobe[T.a2]:stimulus[T.Ethanol]          0.129    0.191  0.676 0.499 -0.245  0.503
# lobe[T.a3]:stimulus[T.Ethanol]          0.062    0.191  0.326 0.745 -0.312  0.436
# lobe[T.ap1]:stimulus[T.Ethanol]        -0.170    0.191 -0.890 0.373 -0.544  0.204
# lobe[T.ap2]:stimulus[T.Ethanol]         0.092    0.191  0.482 0.630 -0.282  0.466
# lobe[T.ap3]:stimulus[T.Ethanol]         0.497    0.191  2.604 0.009  0.123  0.871
# lobe[T.b1]:stimulus[T.Ethanol]         -0.034    0.191 -0.178 0.859 -0.408  0.340
# lobe[T.b2]:stimulus[T.Ethanol]         -0.006    0.191 -0.030 0.976 -0.380  0.368
# lobe[T.bp1]:stimulus[T.Ethanol]         0.126    0.191  0.662 0.508 -0.248  0.500
# lobe[T.bp2]:stimulus[T.Ethanol]        -0.238    0.191 -1.247 0.213 -0.612  0.136
# lobe[T.g1]:stimulus[T.Ethanol]         -0.204    0.191 -1.067 0.286 -0.578  0.170
# lobe[T.g2]:stimulus[T.Ethanol]         -0.204    0.191 -1.071 0.284 -0.578  0.170
# lobe[T.g3]:stimulus[T.Ethanol]         -0.366    0.191 -1.918 0.055 -0.740  0.008
# lobe[T.g4]:stimulus[T.Ethanol]         -0.490    0.191 -2.570 0.010 -0.864 -0.116
# lobe[T.g5]:stimulus[T.Ethanol]         -0.127    0.191 -0.666 0.506 -0.501  0.247
# lobe[T.a2]:stimulus[T.Geosmin]          0.125    0.183  0.682 0.495 -0.234  0.484
# lobe[T.a3]:stimulus[T.Geosmin]         -0.020    0.183 -0.111 0.912 -0.379  0.339
# lobe[T.ap1]:stimulus[T.Geosmin]        -0.147    0.183 -0.804 0.422 -0.506  0.212
# lobe[T.ap2]:stimulus[T.Geosmin]         0.148    0.183  0.807 0.420 -0.211  0.507
# lobe[T.ap3]:stimulus[T.Geosmin]         0.004    0.183  0.022 0.982 -0.355  0.363
# lobe[T.b1]:stimulus[T.Geosmin]         -0.026    0.183 -0.139 0.889 -0.385  0.333
# lobe[T.b2]:stimulus[T.Geosmin]         -0.009    0.183 -0.047 0.962 -0.368  0.350
# lobe[T.bp1]:stimulus[T.Geosmin]        -0.084    0.183 -0.457 0.648 -0.443  0.275
# lobe[T.bp2]:stimulus[T.Geosmin]        -0.103    0.183 -0.562 0.574 -0.462  0.256
# lobe[T.g1]:stimulus[T.Geosmin]         -0.193    0.183 -1.055 0.292 -0.552  0.166
# lobe[T.g2]:stimulus[T.Geosmin]         -0.267    0.183 -1.456 0.145 -0.626  0.092
# lobe[T.g3]:stimulus[T.Geosmin]         -0.519    0.183 -2.834 0.005 -0.878 -0.160
# lobe[T.g4]:stimulus[T.Geosmin]         -0.411    0.183 -2.243 0.025 -0.770 -0.052
# lobe[T.g5]:stimulus[T.Geosmin]          0.013    0.183  0.073 0.942 -0.346  0.372
# lobe[T.a2]:stimulus[T.Isoamylacetate]   0.276    0.161  1.715 0.086 -0.039  0.591
# lobe[T.a3]:stimulus[T.Isoamylacetate]   0.293    0.161  1.824 0.068 -0.022  0.608
# lobe[T.ap1]:stimulus[T.Isoamylacetate]  0.073    0.161  0.451 0.652 -0.242  0.388
# lobe[T.ap2]:stimulus[T.Isoamylacetate]  0.254    0.161  1.578 0.115 -0.061  0.568
# lobe[T.ap3]:stimulus[T.Isoamylacetate]  0.150    0.161  0.933 0.351 -0.165  0.465
# lobe[T.b1]:stimulus[T.Isoamylacetate]  -0.125    0.161 -0.777 0.437 -0.440  0.190
# lobe[T.b2]:stimulus[T.Isoamylacetate]  -0.268    0.161 -1.665 0.096 -0.583  0.047
# lobe[T.bp1]:stimulus[T.Isoamylacetate]  0.187    0.161  1.164 0.245 -0.128  0.502
# lobe[T.bp2]:stimulus[T.Isoamylacetate] -0.184    0.161 -1.144 0.252 -0.499  0.131
# lobe[T.g1]:stimulus[T.Isoamylacetate]   0.140    0.161  0.872 0.383 -0.175  0.455
# lobe[T.g2]:stimulus[T.Isoamylacetate]  -0.002    0.161 -0.015 0.988 -0.317  0.313
# lobe[T.g3]:stimulus[T.Isoamylacetate]   0.032    0.161  0.202 0.840 -0.283  0.347
# lobe[T.g4]:stimulus[T.Isoamylacetate]  -0.387    0.161 -2.408 0.016 -0.702 -0.072
# lobe[T.g5]:stimulus[T.Isoamylacetate]  -0.073    0.161 -0.456 0.648 -0.388  0.242
# lobe[T.a2]:stimulus[T.Peppermint]       0.251    0.161  1.558 0.119 -0.065  0.566
# lobe[T.a3]:stimulus[T.Peppermint]       0.293    0.161  1.822 0.068 -0.022  0.608
# lobe[T.ap1]:stimulus[T.Peppermint]      0.303    0.161  1.883 0.060 -0.012  0.618
# lobe[T.ap2]:stimulus[T.Peppermint]      0.303    0.161  1.882 0.060 -0.013  0.618
# lobe[T.ap3]:stimulus[T.Peppermint]      0.362    0.161  2.254 0.024  0.047  0.678
# lobe[T.b1]:stimulus[T.Peppermint]       0.006    0.161  0.034 0.973 -0.310  0.321
# lobe[T.b2]:stimulus[T.Peppermint]      -0.150    0.161 -0.933 0.351 -0.465  0.165
# lobe[T.bp1]:stimulus[T.Peppermint]      0.402    0.161  2.503 0.012  0.087  0.718
# lobe[T.bp2]:stimulus[T.Peppermint]      0.019    0.161  0.121 0.904 -0.296  0.335
# lobe[T.g1]:stimulus[T.Peppermint]       0.126    0.161  0.785 0.433 -0.189  0.441
# lobe[T.g2]:stimulus[T.Peppermint]       0.114    0.161  0.708 0.479 -0.201  0.429
# lobe[T.g3]:stimulus[T.Peppermint]       0.297    0.161  1.844 0.065 -0.019  0.612
# lobe[T.g4]:stimulus[T.Peppermint]      -0.120    0.161 -0.747 0.455 -0.435  0.195
# lobe[T.g5]:stimulus[T.Peppermint]       0.055    0.161  0.344 0.731 -0.260  0.370
# lobe[T.a2]:stimulus[T.Vinegar]          0.145    0.145  0.994 0.320 -0.140  0.430
# lobe[T.a3]:stimulus[T.Vinegar]         -0.006    0.145 -0.040 0.968 -0.291  0.279
# lobe[T.ap1]:stimulus[T.Vinegar]        -0.086    0.145 -0.594 0.552 -0.372  0.199
# lobe[T.ap2]:stimulus[T.Vinegar]         0.171    0.145  1.176 0.239 -0.114  0.456
# lobe[T.ap3]:stimulus[T.Vinegar]         0.297    0.145  2.038 0.042  0.011  0.582
# lobe[T.b1]:stimulus[T.Vinegar]          0.200    0.145  1.378 0.168 -0.085  0.486
# lobe[T.b2]:stimulus[T.Vinegar]          0.276    0.145  1.898 0.058 -0.009  0.561
# lobe[T.bp1]:stimulus[T.Vinegar]        -0.134    0.145 -0.922 0.357 -0.419  0.151
# lobe[T.bp2]:stimulus[T.Vinegar]         0.269    0.145  1.852 0.064 -0.016  0.554
# lobe[T.g1]:stimulus[T.Vinegar]         -0.043    0.145 -0.296 0.768 -0.328  0.242
# lobe[T.g2]:stimulus[T.Vinegar]         -0.197    0.145 -1.355 0.176 -0.482  0.088
# lobe[T.g3]:stimulus[T.Vinegar]         -0.081    0.145 -0.559 0.576 -0.366  0.204
# lobe[T.g4]:stimulus[T.Vinegar]          0.285    0.145  1.959 0.050 -0.000  0.570
# lobe[T.g5]:stimulus[T.Vinegar]          0.152    0.145  1.045 0.296 -0.133  0.437
# lobe[T.a2]:stimulus[T.Yeast]            0.198    0.144  1.372 0.170 -0.085  0.481
# lobe[T.a3]:stimulus[T.Yeast]            0.094    0.144  0.651 0.515 -0.189  0.377
# lobe[T.ap1]:stimulus[T.Yeast]          -0.023    0.144 -0.159 0.873 -0.306  0.260
# lobe[T.ap2]:stimulus[T.Yeast]           0.247    0.144  1.709 0.088 -0.036  0.530
# lobe[T.ap3]:stimulus[T.Yeast]           0.474    0.144  3.278 0.001  0.190  0.757
# lobe[T.b1]:stimulus[T.Yeast]            0.047    0.144  0.327 0.743 -0.236  0.330
# lobe[T.b2]:stimulus[T.Yeast]            0.151    0.144  1.043 0.297 -0.132  0.434
# lobe[T.bp1]:stimulus[T.Yeast]          -0.013    0.144 -0.092 0.927 -0.296  0.270
# lobe[T.bp2]:stimulus[T.Yeast]           0.317    0.144  2.194 0.028  0.034  0.600
# lobe[T.g1]:stimulus[T.Yeast]            0.045    0.144  0.310 0.757 -0.238  0.328
# lobe[T.g2]:stimulus[T.Yeast]           -0.157    0.144 -1.085 0.278 -0.440  0.126
# lobe[T.g3]:stimulus[T.Yeast]           -0.018    0.144 -0.124 0.901 -0.301  0.265
# lobe[T.g4]:stimulus[T.Yeast]            0.186    0.144  1.287 0.198 -0.097  0.469
# lobe[T.g5]:stimulus[T.Yeast]            0.139    0.144  0.964 0.335 -0.144  0.423
# lobe[T.a2]:stimulus[T.cVA]              0.296    0.142  2.089 0.037  0.018  0.574
# lobe[T.a3]:stimulus[T.cVA]              0.142    0.142  1.004 0.315 -0.135  0.420
# lobe[T.ap1]:stimulus[T.cVA]             0.158    0.142  1.117 0.264 -0.119  0.436
# lobe[T.ap2]:stimulus[T.cVA]             0.292    0.142  2.061 0.039  0.014  0.570
# lobe[T.ap3]:stimulus[T.cVA]             0.238    0.142  1.677 0.094 -0.040  0.516
# lobe[T.b1]:stimulus[T.cVA]             -0.078    0.142 -0.551 0.581 -0.356  0.200
# lobe[T.b2]:stimulus[T.cVA]              0.020    0.142  0.139 0.890 -0.258  0.297
# lobe[T.bp1]:stimulus[T.cVA]             0.070    0.142  0.495 0.621 -0.208  0.348
# lobe[T.bp2]:stimulus[T.cVA]            -0.221    0.142 -1.557 0.120 -0.498  0.057
# lobe[T.g1]:stimulus[T.cVA]             -0.108    0.142 -0.761 0.447 -0.386  0.170
# lobe[T.g2]:stimulus[T.cVA]              0.001    0.142  0.010 0.992 -0.276  0.279
# lobe[T.g3]:stimulus[T.cVA]             -0.315    0.142 -2.223 0.026 -0.593 -0.037
# lobe[T.g4]:stimulus[T.cVA]             -0.508    0.142 -3.583 0.000 -0.786 -0.230
# lobe[T.g5]:stimulus[T.cVA]             -0.113    0.142 -0.800 0.424 -0.391  0.164
# order_presented                         0.051    0.389  0.132 0.895 -0.711  0.814
# lobe[T.a2]:order_presented             -0.326    0.543 -0.600 0.548 -1.391  0.739
# lobe[T.a3]:order_presented             -0.244    0.543 -0.449 0.653 -1.308  0.821
# lobe[T.ap1]:order_presented            -0.189    0.543 -0.349 0.727 -1.254  0.875
# lobe[T.ap2]:order_presented            -0.231    0.543 -0.425 0.671 -1.296  0.834
# lobe[T.ap3]:order_presented            -1.037    0.543 -1.909 0.056 -2.101  0.028
# lobe[T.b1]:order_presented              0.331    0.543  0.609 0.542 -0.734  1.396
# lobe[T.b2]:order_presented              0.090    0.543  0.166 0.868 -0.975  1.155
# lobe[T.bp1]:order_presented            -0.585    0.543 -1.077 0.281 -1.650  0.479
# lobe[T.bp2]:order_presented            -0.227    0.543 -0.418 0.676 -1.291  0.838
# lobe[T.g1]:order_presented             -0.185    0.543 -0.340 0.734 -1.249  0.880
# lobe[T.g2]:order_presented             -0.010    0.543 -0.018 0.985 -1.075  1.055
# lobe[T.g3]:order_presented             -0.312    0.543 -0.575 0.565 -1.377  0.752
# lobe[T.g4]:order_presented             -0.542    0.543 -0.998 0.318 -1.607  0.522
# lobe[T.g5]:order_presented              0.065    0.543  0.119 0.905 -1.000  1.129
# dorsal_to_ventral_val                  -0.009    0.041 -0.226 0.822 -0.089  0.071
# lobe[T.a2]:dorsal_to_ventral_val       -0.164    0.057 -2.863 0.004 -0.277 -0.052
# lobe[T.a3]:dorsal_to_ventral_val       -0.030    0.057 -0.517 0.605 -0.142  0.083
# lobe[T.ap1]:dorsal_to_ventral_val      -0.059    0.057 -1.036 0.300 -0.172  0.053
# lobe[T.ap2]:dorsal_to_ventral_val      -0.139    0.057 -2.417 0.016 -0.251 -0.026
# lobe[T.ap3]:dorsal_to_ventral_val      -0.177    0.057 -3.076 0.002 -0.289 -0.064
# lobe[T.b1]:dorsal_to_ventral_val       -0.027    0.057 -0.474 0.635 -0.140  0.085
# lobe[T.b2]:dorsal_to_ventral_val        0.031    0.057  0.535 0.593 -0.082  0.143
# lobe[T.bp1]:dorsal_to_ventral_val       0.017    0.057  0.298 0.765 -0.095  0.130
# lobe[T.bp2]:dorsal_to_ventral_val       0.025    0.057  0.431 0.667 -0.088  0.137
# lobe[T.g1]:dorsal_to_ventral_val        0.000    0.057  0.003 0.998 -0.112  0.113
# lobe[T.g2]:dorsal_to_ventral_val       -0.062    0.057 -1.081 0.280 -0.175  0.050
# lobe[T.g3]:dorsal_to_ventral_val        0.058    0.057  1.018 0.309 -0.054  0.171
# lobe[T.g4]:dorsal_to_ventral_val        0.032    0.057  0.566 0.571 -0.080  0.145
# lobe[T.g5]:dorsal_to_ventral_val        0.050    0.057  0.870 0.384 -0.063  0.162
# starved:lobe[a1]                        0.069    0.030  2.274 0.023  0.009  0.128
# starved:lobe[a2]                       -0.001    0.030 -0.047 0.963 -0.061  0.058
# starved:lobe[a3]                       -0.001    0.030 -0.040 0.968 -0.060  0.058
# starved:lobe[ap1]                       0.005    0.030  0.150 0.881 -0.055  0.064
# starved:lobe[ap2]                      -0.012    0.030 -0.413 0.680 -0.072  0.047
# starved:lobe[ap3]                      -0.010    0.030 -0.347 0.729 -0.070  0.049
# starved:lobe[b1]                        0.118    0.030  3.910 0.000  0.059  0.177
# starved:lobe[b2]                        0.061    0.030  2.032 0.042  0.002  0.121
# starved:lobe[bp1]                       0.114    0.030  3.756 0.000  0.054  0.173
# starved:lobe[bp2]                       0.052    0.030  1.731 0.084 -0.007  0.112
# starved:lobe[g1]                        0.039    0.030  1.280 0.200 -0.021  0.098
# starved:lobe[g2]                       -0.007    0.030 -0.228 0.820 -0.066  0.052
# starved:lobe[g3]                       -0.021    0.030 -0.688 0.492 -0.080  0.038
# starved:lobe[g4]                        0.018    0.030  0.595 0.552 -0.041  0.077
# starved:lobe[g5]                        0.005    0.030  0.179 0.858 -0.054  0.065
# Group Var                               0.029    0.010
# =================================================================================
#
# """

# %%
sum((resAllmm.predict(lobe_data)-np.mean(resAllmm.predict(lobe_data)))**2)/sum((lobe_data['df_f']-np.mean(lobe_data['df_f']))**2)
# Out:
# 0.3566498009432736

# %% [markdown]
# #### Minimal models

# %%
reslobe = smf.ols(formula="df_f ~ lobe-1", data=lobe_data).fit()
y, X = dmatrices('df_f ~ lobe-1', lobe_data, return_type='dataframe')
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
np.max(vif.round(1))
# Out:
# VIF Factor           1
# features      lobe[g5]
# dtype: object

# %%
resstarved = smf.ols(formula="df_f ~ lobe+lobe:starved-1", data=lobe_data).fit()
y, X = dmatrices('df_f ~ lobe+lobe:starved-1', lobe_data, return_type='dataframe')
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
np.max(vif.round(1))
# Out:
# VIF Factor                 1.9
# features      lobe[g5]:starved
# dtype: object

# %% [markdown]
# #### Compare all models

# %%
residuals = resnoidb.resid 
fig = smapi.qqplot(residuals, line='s')
residuals = resAllmm.resid 
fig = smapi.qqplot(residuals, line='s')
residuals = resstarved.resid 
fig = smapi.qqplot(residuals, line='s')
residuals = reslobe.resid 
fig = smapi.qqplot(residuals, line='s')
plt.show()

# %% [markdown]
# The mixed model has the cleanest QQ plot (although still miss an effect in fourth quantile)

# %%
aov_table2 = anova_lm(resnoid,resstarved,reslobe)
aov_table2
# Out:
#    df_resid          ssr  df_diff     ss_diff         F  Pr(>F)
# 0    5205.0   891.149612      0.0         NaN       NaN     NaN
# 1    5400.0  1054.525520   -195.0 -163.375908  4.237381     NaN
# 2    5415.0  1070.666719    -15.0  -16.141199  5.442378     NaN

# %%
formulastim="df_f ~ lobe-1"
cv_ols_stim = cross_val_score(SMFormulaWrapper(smf.ols, formulastim),lobe_data, lobe_data['df_f'],scoring='explained_variance', cv=6)
print ("Only lobe: cross validated "+str(np.mean(cv_ols_stim))+" Rsquare:"+str(reslobe.rsquared))

formulastarved="df_f ~ lobe+lobe:starved-1"
cv_ols_starved = cross_val_score(SMFormulaWrapper(smf.ols, formulastarved),lobe_data, lobe_data['df_f'],scoring='explained_variance', cv=6)
print ("Only lobe and starved: cross validated "+str(np.mean(cv_ols_starved))+" Rsquare:"+str(resstarved.rsquared))
# Out:
# Only lobe: cross validated 0.21402598887966695 Rsquare:0.22621570409050484
# Only lobe and starved: cross validated 0.2140411474328432 Rsquare:0.2378811513191722

# %%
print(reslobe.aic,reslobe.bic)
print(resstarved.aic,resstarved.bic)
print(resnoid.aic,resnoid.bic)
# Out:
# 6623.211824183032 6722.207240376952
# 6570.726679545065 6768.717511932904
# 6046.673748798996 7531.604991707792

# %% [markdown]
# As the bic and the aic give contradictory results, we report all coefficients

# %% [markdown]
# #### Summary graphs for the coefficients

# %%
import matplotlib.transforms as transforms

# %%
fig, ax = plt.subplots(figsize=(12, 5))
offset = lambda p: transforms.ScaledTranslation(p/72.,0, plt.gcf().dpi_scale_trans)
trans = plt.gca().transData

###################3

err_series = resAllmm.params - resAllmm.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': resAllmm.params[0:15],
                       'err': err_series.values[0:15],
                       'varname': err_series.index.values[0:15]
                      })


coef_df.plot(x='varname', y='coef', kind='bar', 
            ax=ax, color='none', 
            yerr='err', 
            error_kw=dict(ecolor='blue', lw=2, capsize=5, capthick=2,transform=trans+offset(-9)),
            label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
          marker='s', s=120,transform=trans+offset(-9), 
          y=coef_df['coef'], color='blue',label="Mixed model for fly ID")

##################3
err_series = resnoid.params - resnoid.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': resnoid.params[0:15],
                        'err': err_series.values[0:15],
                        'varname': err_series.index.values[0:15]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err',
             error_kw=dict(ecolor='black', lw=2, capsize=5, capthick=2,transform=trans+offset(-3)),
             label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, transform=trans+offset(-3),
           y=coef_df['coef'], color='black',label="Full model without fly ID")
######################

#err_series = result_reg.params - result_reg.conf_int()[0]
coef_df = pd.DataFrame({'coef': result_reg_ridge.params[0:15],
                        #'err': err_series.values[0:15],
                        #'varname': err_series.index.values[0:15]
                       })
coef_df.plot(y='coef', kind='bar', 
             ax=ax, color='None',label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120,transform=trans+offset(3),
           y=coef_df['coef'], color='Green',label="Regularized")
##################

err_series = reslobe.params - reslobe.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': reslobe.params[0:15],
                        'err': err_series.values[0:15],
                        'varname': err_series.index.values[0:15]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='None', 
             yerr='err', 
             error_kw=dict(ecolor='red', lw=2, capsize=5, capthick=2,transform=trans+offset(9)),
             label='')

ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=100, transform=trans+offset(9),
           y=coef_df['coef'], color='red',label="Minimal model")

#ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(LobesGreek, 
                       rotation=0, fontsize=20)
ax.set_title("Odor response coefficients", fontsize=22)
leg = ax.legend(loc='upper left', fancybox=True, fontsize=16)
plt.show()
fig.savefig('FluoCoefficients.svg')

# %%
dff_mean=np.zeros((1,15))
dff_mean=np.array(resnoid.params[0:15]).reshape(1,15)
    
#plt.imshow(np.array(res4.params[30+31:30+31+14]).reshape(1,14), cmap='seismic',vmin=-0.18,vmax=+0.18)
plt.imshow(dff_mean, cmap=cmocean.cm.dense)
plt.colorbar()
plt.savefig('ColordffColorbar.svg')

fig, axs = plt.subplots(5, 1, figsize=(10, 3))
i=0
for ax, interp in zip(axs, [3,6,8,10,15]):
    OneLobe=dff_mean[0,range(i,interp)].reshape(1,interp-i)
    ax.imshow(OneLobe, cmap=cmocean.cm.dense, vmin=0,vmax=max(abs(dff_mean.T)))
    ax.grid(False)
    #ax.axis('off')
    ax.xaxis.set_ticks_position('none') 
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.yaxis.set_ticks_position('none')  
    i=interp

plt.show()
fig.savefig('ColorDff.svg')

# %%
resAllmm.params[len(resAllmm.params)-16:len(resAllmm.params)-1]
# Out:
# starved:lobe[a1]     0.068746
# starved:lobe[a2]    -0.001412
# starved:lobe[a3]    -0.001223
# starved:lobe[ap1]    0.004533
# starved:lobe[ap2]   -0.012482
# starved:lobe[ap3]   -0.010488
# starved:lobe[b1]     0.118216
# starved:lobe[b2]     0.061447
# starved:lobe[bp1]    0.113562
# starved:lobe[bp2]    0.052324
# starved:lobe[g1]     0.038708
# starved:lobe[g2]    -0.006890
# starved:lobe[g3]    -0.020789
# starved:lobe[g4]     0.017980
# starved:lobe[g5]     0.005416
# dtype: float64

# %%
resnoid.params[len(resAllmm.params)-16:len(resAllmm.params)-1]
# Out:
# lobe[a1]:starved     0.067622
# lobe[a2]:starved    -0.002536
# lobe[a3]:starved    -0.002347
# lobe[ap1]:starved    0.003409
# lobe[ap2]:starved   -0.013606
# lobe[ap3]:starved   -0.011612
# lobe[b1]:starved     0.117092
# lobe[b2]:starved     0.060323
# lobe[bp1]:starved    0.112438
# lobe[bp2]:starved    0.051200
# lobe[g1]:starved     0.037584
# lobe[g2]:starved    -0.008014
# lobe[g3]:starved    -0.021913
# lobe[g4]:starved     0.016856
# lobe[g5]:starved     0.004292
# dtype: float64

# %%
result_reg.params[len(resAllmm.params)-16:len(resAllmm.params)-1]
# Out:
# starved:lobe[a1]     0.067776
# starved:lobe[a2]    -0.003203
# starved:lobe[a3]    -0.002628
# starved:lobe[ap1]    0.003773
# starved:lobe[ap2]   -0.014415
# starved:lobe[ap3]   -0.012393
# starved:lobe[b1]     0.117702
# starved:lobe[b2]     0.060844
# starved:lobe[bp1]    0.113202
# starved:lobe[bp2]    0.051852
# starved:lobe[g1]     0.038468
# starved:lobe[g2]    -0.006745
# starved:lobe[g3]    -0.020367
# starved:lobe[g4]     0.018876
# starved:lobe[g5]     0.004997
# dtype: float64

# %%
resstarved.params[len(resstarved.params)-15:len(resstarved.params)]
# Out:
# lobe[a1]:starved     0.062888
# lobe[a2]:starved    -0.024186
# lobe[a3]:starved    -0.006774
# lobe[ap1]:starved   -0.024195
# lobe[ap2]:starved   -0.030887
# lobe[ap3]:starved   -0.006875
# lobe[b1]:starved     0.129547
# lobe[b2]:starved     0.054449
# lobe[bp1]:starved    0.078370
# lobe[bp2]:starved    0.101336
# lobe[g1]:starved     0.054975
# lobe[g2]:starved    -0.027469
# lobe[g3]:starved     0.024663
# lobe[g4]:starved     0.094788
# lobe[g5]:starved     0.027027
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12, 5))
offset = lambda p: transforms.ScaledTranslation(p/72.,0, plt.gcf().dpi_scale_trans)
trans = plt.gca().transData

###################3

err_series = resAllmm.params - resAllmm.conf_int(alpha=0.01)[0]
coef_df = pd.DataFrame({'coef': resAllmm.params[len(resAllmm.params)-16:len(resAllmm.params)-1],
                       'err': err_series.values[len(resAllmm.params)-16:len(resAllmm.params)-1],
                       'varname': err_series.index.values[len(resAllmm.params)-16:len(resAllmm.params)-1]
                      })


coef_df.plot(x='varname', y='coef', kind='bar', 
            ax=ax, color='none', 
            yerr='err', 
            error_kw=dict(ecolor='blue', lw=2, capsize=5, capthick=2,transform=trans+offset(-9)),
            label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
          marker='s', s=120,transform=trans+offset(-9), 
          y=coef_df['coef'], color='blue',label="Mixed model for fly ID")

##################3
err_series = resnoid.params - resnoid.conf_int(alpha=0.01)[0]
coef_df = pd.DataFrame({'coef': resnoid.params[len(resAllmm.params)-16:len(resAllmm.params)-1],
                        'err': err_series.values[len(resAllmm.params)-16:len(resAllmm.params)-1],
                        'varname': err_series.index.values[len(resAllmm.params)-16:len(resAllmm.params)-1]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err',
             error_kw=dict(ecolor='black', lw=2, capsize=5, capthick=2,transform=trans+offset(-3)),
             label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, transform=trans+offset(-3),
           y=coef_df['coef'], color='black',label="Full model without fly ID")
######################

#err_series = result_reg.params - result_reg.conf_int()[0]
coef_df = pd.DataFrame({'coef': result_reg.params[len(resAllmm.params)-16:len(resAllmm.params)-1],
                        #'err': err_series.values[0:15],
                        #'varname': err_series.index.values[0:15]
                       })
coef_df.plot(y='coef', kind='bar', 
             ax=ax, color='None',label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120,transform=trans+offset(3),
           y=coef_df['coef'], color='Green',label="Regularized")
##################

err_series = resstarved.params - resstarved.conf_int(alpha=0.01)[0]
coef_df = pd.DataFrame({'coef': resstarved.params[len(resstarved.params)-15:len(resstarved.params)],
                        'err': err_series.values[len(resstarved.params)-15:len(resstarved.params)],
                        'varname': err_series.index.values[len(resstarved.params)-15:len(resstarved.params)]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='None', 
             yerr='err', 
             error_kw=dict(ecolor='red', lw=2, capsize=5, capthick=2,transform=trans+offset(9)),
             label='')

ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=100, transform=trans+offset(9),
           y=coef_df['coef'], color='red',label="Minimal model")

ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(LobesGreek, 
                       rotation=0, fontsize=20)

ax.set_title("Starvation coefficients", fontsize=22)
leg = ax.legend(loc='upper right', fancybox=True, fontsize=16)

plt.show()
fig.savefig('StarvationCoefficients.svg')

# %%
print(lobes)
LobeValues=np.array(resnoid.params[len(resnoid.params)-15:len(resnoid.params)]).reshape(1,15)
Vmax=max(abs(LobeValues.T))
plt.imshow(LobeValues,cmap='PuOr_r',vmin=-Vmax,vmax=Vmax)
plt.colorbar()
plt.savefig('ColorHungerBar.svg')
fig, axs = plt.subplots(5, 1, figsize=(10, 3))
i=0
for ax, interp in zip(axs, [3,6,8,10,15]):
    OneLobe=LobeValues[0,range(i,interp)].reshape(1,interp-i)
    ax.imshow(OneLobe,cmap='PuOr_r',vmin=-Vmax,vmax=Vmax)
    ax.grid(False)
    #ax.axis('off')
    ax.xaxis.set_ticks_position('none') 
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.yaxis.set_ticks_position('none')  
    i=interp

plt.show()
fig.savefig('ColorHunger.svg')
# Out:
# ['a1' 'a2' 'a3' 'ap1' 'ap2' 'ap3' 'b1' 'b2' 'bp1' 'bp2' 'g1' 'g2' 'g3'
#  'g4' 'g5']

# %% [markdown]
# ## Stimulus reduced to valence

# %% [markdown]
# As odors with well-defined valence represent a subset of the data, we treat it separately

# %%
data_val=lobe_data[np.abs(lobe_data.valence)==1]

# %%
resval = smf.ols(formula="df_f ~ lobe*(starved+order_presented+dorsal_to_ventral_val)+valence:lobe-1", data=data_val).fit()
resval.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     17.15
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):          4.63e-178
# Time:                        16:52:18   Log-Likelihood:                -1897.1
# No. Observations:                3225   AIC:                             3944.
# Df Residuals:                    3150   BIC:                             4400.
# Df Model:                          74
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# lobe[a1]                              0.0843      0.055      1.534      0.125      -0.023       0.192
# lobe[a2]                              0.3875      0.055      7.050      0.000       0.280       0.495
# lobe[a3]                              0.3468      0.055      6.310      0.000       0.239       0.455
# lobe[ap1]                             0.4096      0.055      7.453      0.000       0.302       0.517
# lobe[ap2]                             0.4090      0.055      7.441      0.000       0.301       0.517
# lobe[ap3]                             0.8600      0.055     15.647      0.000       0.752       0.968
# lobe[b1]                              0.4474      0.055      8.139      0.000       0.340       0.555
# lobe[b2]                              0.6717      0.055     12.221      0.000       0.564       0.779
# lobe[bp1]                             0.9176      0.055     16.695      0.000       0.810       1.025
# lobe[bp2]                             0.7259      0.055     13.206      0.000       0.618       0.834
# lobe[g1]                              0.3522      0.055      6.408      0.000       0.244       0.460
# lobe[g2]                              0.4784      0.055      8.703      0.000       0.371       0.586
# lobe[g3]                              0.7203      0.055     13.105      0.000       0.613       0.828
# lobe[g4]                              0.6898      0.055     12.549      0.000       0.582       0.798
# lobe[g5]                              0.2164      0.055      3.937      0.000       0.109       0.324
# starved                               0.0723      0.036      2.017      0.044       0.002       0.143
# lobe[T.a2]:starved                   -0.0709      0.051     -1.398      0.162      -0.170       0.029
# lobe[T.a3]:starved                   -0.0557      0.051     -1.098      0.272      -0.155       0.044
# lobe[T.ap1]:starved                  -0.0502      0.051     -0.990      0.322      -0.150       0.049
# lobe[T.ap2]:starved                  -0.0988      0.051     -1.950      0.051      -0.198       0.001
# lobe[T.ap3]:starved                   0.0146      0.051      0.289      0.773      -0.085       0.114
# lobe[T.b1]:starved                    0.0566      0.051      1.117      0.264      -0.043       0.156
# lobe[T.b2]:starved                    0.0136      0.051      0.269      0.788      -0.086       0.113
# lobe[T.bp1]:starved                   0.0806      0.051      1.591      0.112      -0.019       0.180
# lobe[T.bp2]:starved                   0.0114      0.051      0.224      0.823      -0.088       0.111
# lobe[T.g1]:starved                   -0.0292      0.051     -0.575      0.565      -0.129       0.070
# lobe[T.g2]:starved                   -0.0791      0.051     -1.561      0.119      -0.178       0.020
# lobe[T.g3]:starved                   -0.0296      0.051     -0.583      0.560      -0.129       0.070
# lobe[T.g4]:starved                    0.0066      0.051      0.130      0.896      -0.093       0.106
# lobe[T.g5]:starved                   -0.0720      0.051     -1.421      0.155      -0.171       0.027
# order_presented                      -0.0242      0.446     -0.054      0.957      -0.898       0.850
# lobe[T.a2]:order_presented           -0.2877      0.631     -0.456      0.648      -1.524       0.949
# lobe[T.a3]:order_presented           -0.1659      0.631     -0.263      0.793      -1.402       1.071
# lobe[T.ap1]:order_presented          -0.1374      0.631     -0.218      0.828      -1.374       1.099
# lobe[T.ap2]:order_presented          -0.1987      0.631     -0.315      0.753      -1.435       1.038
# lobe[T.ap3]:order_presented          -0.8749      0.631     -1.387      0.165      -2.111       0.362
# lobe[T.b1]:order_presented            0.2628      0.631      0.417      0.677      -0.974       1.499
# lobe[T.b2]:order_presented            0.0370      0.631      0.059      0.953      -1.199       1.273
# lobe[T.bp1]:order_presented          -0.4997      0.631     -0.792      0.428      -1.736       0.737
# lobe[T.bp2]:order_presented          -0.1780      0.631     -0.282      0.778      -1.414       1.058
# lobe[T.g1]:order_presented           -0.1303      0.631     -0.207      0.836      -1.367       1.106
# lobe[T.g2]:order_presented           -0.0109      0.631     -0.017      0.986      -1.247       1.226
# lobe[T.g3]:order_presented           -0.2175      0.631     -0.345      0.730      -1.454       1.019
# lobe[T.g4]:order_presented           -0.5228      0.631     -0.829      0.407      -1.759       0.714
# lobe[T.g5]:order_presented            0.0498      0.631      0.079      0.937      -1.187       1.286
# dorsal_to_ventral_val                -0.0202      0.062     -0.328      0.743      -0.141       0.101
# lobe[T.a2]:dorsal_to_ventral_val     -0.1309      0.087     -1.500      0.134      -0.302       0.040
# lobe[T.a3]:dorsal_to_ventral_val      0.0066      0.087      0.076      0.939      -0.164       0.178
# lobe[T.ap1]:dorsal_to_ventral_val    -0.0434      0.087     -0.498      0.619      -0.215       0.128
# lobe[T.ap2]:dorsal_to_ventral_val    -0.1018      0.087     -1.167      0.243      -0.273       0.069
# lobe[T.ap3]:dorsal_to_ventral_val    -0.2420      0.087     -2.773      0.006      -0.413      -0.071
# lobe[T.b1]:dorsal_to_ventral_val     -0.0300      0.087     -0.344      0.731      -0.201       0.141
# lobe[T.b2]:dorsal_to_ventral_val     -0.0060      0.087     -0.069      0.945      -0.177       0.165
# lobe[T.bp1]:dorsal_to_ventral_val    -0.0141      0.087     -0.161      0.872      -0.185       0.157
# lobe[T.bp2]:dorsal_to_ventral_val     0.0137      0.087      0.157      0.875      -0.157       0.185
# lobe[T.g1]:dorsal_to_ventral_val      0.0280      0.087      0.321      0.748      -0.143       0.199
# lobe[T.g2]:dorsal_to_ventral_val     -0.1060      0.087     -1.215      0.224      -0.277       0.065
# lobe[T.g3]:dorsal_to_ventral_val      0.0581      0.087      0.665      0.506      -0.113       0.229
# lobe[T.g4]:dorsal_to_ventral_val      0.0491      0.087      0.562      0.574      -0.122       0.220
# lobe[T.g5]:dorsal_to_ventral_val      0.0521      0.087      0.597      0.550      -0.119       0.223
# valence:lobe[a1]                     -0.0501      0.031     -1.627      0.104      -0.111       0.010
# valence:lobe[a2]                     -0.0473      0.031     -1.536      0.125      -0.108       0.013
# valence:lobe[a3]                     -0.1182      0.031     -3.837      0.000      -0.179      -0.058
# valence:lobe[ap1]                    -0.1114      0.031     -3.616      0.000      -0.172      -0.051
# valence:lobe[ap2]                    -0.0435      0.031     -1.412      0.158      -0.104       0.017
# valence:lobe[ap3]                     0.0780      0.031      2.532      0.011       0.018       0.138
# valence:lobe[b1]                     -0.0127      0.031     -0.413      0.680      -0.073       0.048
# valence:lobe[b2]                      0.0555      0.031      1.800      0.072      -0.005       0.116
# valence:lobe[bp1]                    -0.0730      0.031     -2.370      0.018      -0.133      -0.013
# valence:lobe[bp2]                     0.0866      0.031      2.812      0.005       0.026       0.147
# valence:lobe[g1]                     -0.0231      0.031     -0.750      0.453      -0.084       0.037
# valence:lobe[g2]                     -0.1059      0.031     -3.438      0.001      -0.166      -0.046
# valence:lobe[g3]                     -0.0212      0.031     -0.687      0.492      -0.082       0.039
# valence:lobe[g4]                      0.1720      0.031      5.583      0.000       0.112       0.232
# valence:lobe[g5]                      0.0280      0.031      0.910      0.363      -0.032       0.088
# ==============================================================================
# Omnibus:                     1109.362   Durbin-Watson:                   1.414
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5713.890
# Skew:                           1.559   Prob(JB):                         0.00
# Kurtosis:                       8.727   Cond. No.                         322.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
resvalforanova = smf.ols(formula="df_f ~ lobe*(valence+order_presented+dorsal_to_ventral_val+starved)", data=data_val).fit()
resvalforanova.summary()
aov_table = anova_lm(resvalforanova, typ=2)
print(resval.rsquared)
print(100*(aov_table.sum_sq.values[1]+aov_table.sum_sq.values[2])/sum(aov_table.sum_sq.values))
aov_table
# Out:
# 0.2871918017217002
# 2.3336036329413865
#                                 sum_sq      df          F         PR(>F)
# lobe                        205.106477    14.0  75.363189  1.342971e-185
# valence                       0.474223     1.0   2.439443   1.184187e-01
# lobe:valence                 19.547945    14.0   7.182589   6.831201e-15
# order_presented               0.682760     1.0   3.512172   6.101202e-02
# lobe:order_presented          1.051409    14.0   0.386324   9.791730e-01
# dorsal_to_ventral_val         2.018706     1.0  10.384393   1.283804e-03
# lobe:dorsal_to_ventral_val    4.866708    14.0   1.788196   3.473328e-02
# starved                       6.173036     1.0  31.754607   1.903480e-08
# lobe:starved                  5.718155    14.0   2.101047   9.415150e-03
# Residual                    612.354093  3150.0        NaN            NaN

# %%
resvalmm = smf.mixedlm(formula="df_f ~ lobe*(starved+order_presented+dorsal_to_ventral_val)+valence:lobe-1", data=data_val, groups=data_val["fly_id"]).fit()

# %%
resval_reg = smf.ols(formula="df_f~ lobe*(starved+order_presented+dorsal_to_ventral_val)+valence:lobe-1", data=data_val).fit_regularized()

# %%
resonlyval = smf.ols(formula="df_f ~ lobe+lobe:valence-1", data=data_val).fit()

# %%
resnostim = smf.ols(formula="df_f ~lobe*(starved+order_presented+dorsal_to_ventral_val)-1",data=data_val).fit()

# %%
residuals = resval.resid 
fig = smapi.qqplot(residuals, line='s')
residuals = resvalmm.resid 
fig = smapi.qqplot(residuals, line='s')
residuals = resonlyval.resid 
fig = smapi.qqplot(residuals, line='s')
residuals = resnostim.resid 
fig = smapi.qqplot(residuals, line='s')
plt.show()

# %%
formulastim="df_f ~ lobe*(starved+order_presented+dorsal_to_ventral_val)+valence:lobe-1"
cv_ols_stim = cross_val_score(SMFormulaWrapper(smf.ols, formulastim),data_val,data_val['df_f'],scoring='explained_variance', cv=6)
print ("Everything with valence "+str(np.mean(cv_ols_stim))+" Rsquare:"+str(resval.rsquared))

formulavalenceonly="df_f ~lobe+lobe:valence-1"
cv_ols_valenceonly = cross_val_score(SMFormulaWrapper(smf.ols, formulavalenceonly),data_val,data_val['df_f'],scoring='explained_variance', cv=6)
print ("Only valence and lobe: cross validated "+str(np.mean(cv_ols_valenceonly))+" Rsquare:"+str(resonlyval.rsquared))

NoStim="df_f ~lobe*(starved+order_presented+dorsal_to_ventral_val)-1"
cv_ols_nostim= cross_val_score(SMFormulaWrapper(smf.ols, NoStim),data_val,data_val['df_f'],scoring='explained_variance', cv=6)
print ("No stimulus info: cross validated "+str(np.mean(cv_ols_nostim))+" Rsquare:"+str(resnostim.rsquared))
# Out:
# Everything with valence 0.23897514379851495 Rsquare:0.2871918017217002
# Only valence and lobe: cross validated 0.24379032053279803 Rsquare:0.2622736387862292
# No stimulus info: cross validated 0.2270769205642544 Rsquare:0.26388508180734416

# %%
print(resval.aic,resval.bic)
print(resonlyval.aic,resonlyval.bic)
print(resnostim.aic,resnostim.bic)
# Out:
# 3944.211002997504 4400.112620189744
# 3965.0239185719856 4147.384565448881
# 4017.9717266072494 4382.693020361042

# %% [markdown]
# In this case, the minimal model seems the more reliable

# %%
print('Parameters: ', resval.params[len(resval.params)-15:len(resval.params)])
# Out:
# Parameters:  valence:lobe[a1]    -0.050138
# valence:lobe[a2]    -0.047317
# valence:lobe[a3]    -0.118206
# valence:lobe[ap1]   -0.111395
# valence:lobe[ap2]   -0.043496
# valence:lobe[ap3]    0.078005
# valence:lobe[b1]    -0.012720
# valence:lobe[b2]     0.055455
# valence:lobe[bp1]   -0.073014
# valence:lobe[bp2]    0.086628
# valence:lobe[g1]    -0.023122
# valence:lobe[g2]    -0.105928
# valence:lobe[g3]    -0.021155
# valence:lobe[g4]     0.172016
# valence:lobe[g5]     0.028021
# dtype: float64

# %%
print('Parameters: ', resvalmm.params[len(resvalmm.params)-16:len(resvalmm.params)-1])
# Out:
# Parameters:  valence:lobe[a1]    -0.006968
# valence:lobe[a2]    -0.004146
# valence:lobe[a3]    -0.075035
# valence:lobe[ap1]   -0.068225
# valence:lobe[ap2]   -0.000325
# valence:lobe[ap3]    0.121175
# valence:lobe[b1]     0.030451
# valence:lobe[b2]     0.098625
# valence:lobe[bp1]   -0.029844
# valence:lobe[bp2]    0.129798
# valence:lobe[g1]     0.020049
# valence:lobe[g2]    -0.062758
# valence:lobe[g3]     0.022015
# valence:lobe[g4]     0.215186
# valence:lobe[g5]     0.071191
# dtype: float64

# %%
print('Parameters: ', resonlyval.params[len(resonlyval.params)-15:len(resonlyval.params)])
# Out:
# Parameters:  lobe[a1]:valence    -0.046437
# lobe[a2]:valence    -0.046416
# lobe[a3]:valence    -0.118260
# lobe[ap1]:valence   -0.110151
# lobe[ap2]:valence   -0.043937
# lobe[ap3]:valence    0.081589
# lobe[b1]:valence    -0.004254
# lobe[b2]:valence     0.060131
# lobe[bp1]:valence   -0.068049
# lobe[bp2]:valence    0.089615
# lobe[g1]:valence    -0.022064
# lobe[g2]:valence    -0.104266
# lobe[g3]:valence    -0.021140
# lobe[g4]:valence     0.172179
# lobe[g5]:valence     0.027627
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12, 5))
offset = lambda p: transforms.ScaledTranslation(p/72.,0, plt.gcf().dpi_scale_trans)
trans = plt.gca().transData

##################3
err_series = resvalmm.params - resval.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': resvalmm.params[len(resvalmm.params)-16:len(resvalmm.params)-1],
                        'err': err_series.values[len(resvalmm.params)-16:len(resvalmm.params)-1],
                        'varname': err_series.index.values[len(resvalmm.params)-16:len(resvalmm.params)-1]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err',
             error_kw=dict(ecolor='blue', lw=2, capsize=5, capthick=2,transform=trans+offset(-9)),
             label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, transform=trans+offset(-9),
           y=coef_df['coef'], color='blue',label="Mixed model for fly ID")
##################3
err_series = resval.params - resval.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': resval.params[len(resval.params)-15:len(resval.params)],
                        'err': err_series.values[len(resval.params)-15:len(resval.params)],
                        'varname': err_series.index.values[len(resval.params)-15:len(resval.params)]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err',
             error_kw=dict(ecolor='black', lw=2, capsize=5, capthick=2,transform=trans+offset(-3)),
             label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, transform=trans+offset(-3),
           y=coef_df['coef'], color='black',label="Full model without fly ID")
######################

#err_series = result_reg.params - result_reg.conf_int()[0]
coef_df = pd.DataFrame({'coef': resval_reg.params[len(resval.params)-15:len(resval.params)],
                        #'err': err_series.values[0:15],
                        #'varname': err_series.index.values[0:15]
                       })
coef_df.plot(y='coef', kind='bar', 
             ax=ax, color='None',label='')

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120,transform=trans+offset(3),
           y=coef_df['coef'], color='Green',label="Regularized")
##################

err_series = resonlyval.params - resonlyval.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': resonlyval.params[len(resonlyval.params)-15:len(resonlyval.params)],
                        'err': err_series.values[len(resonlyval.params)-15:len(resonlyval.params)],
                        'varname': err_series.index.values[len(resonlyval.params)-15:len(resonlyval.params)]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='None', 
             yerr='err', 
             error_kw=dict(ecolor='red', lw=2, capsize=5, capthick=2,transform=trans+offset(9)),
             label='')

ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=100, transform=trans+offset(9),
           y=coef_df['coef'], color='red',label="Minimal model")
ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

# ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
#            marker='s', s=120, 
#            y=coef_df['coef'], 
#            color='Red',label='Minimal model')

ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(LobesGreek, 
                       rotation=0, fontsize=20)

#ax.set_ylim([-0.2,0.6])
ax.set_title("Valence coefficients", fontsize=22)
leg = ax.legend(loc='upper left', fancybox=False, fontsize=16)
plt.show()
fig.savefig('ValenceCoefficients_woctmch_98CI.svg')

# %%
#Valence pos
print(lobes)
#plt.imshow(np.array(res4.params[30+31:30+31+14]).reshape(1,14), cmap='seismic',vmin=-0.18,vmax=+0.18)
LobeValues=np.array(resonlyval.params[len(resonlyval.params)-15:len(resonlyval.params)]).reshape(1,15)
plt.imshow(LobeValues, cmap='coolwarm', vmin=-max(abs(LobeValues.T)),vmax=max(abs(LobeValues.T)))
plt.colorbar()
plt.savefig('ColorValenceColorbarVrev.svg')
# Out:
# ['a1' 'a2' 'a3' 'ap1' 'ap2' 'ap3' 'b1' 'b2' 'bp1' 'bp2' 'g1' 'g2' 'g3'
#  'g4' 'g5']

# %%
fig, axs = plt.subplots(5, 1, figsize=(10, 3))
i=0
for ax, interp in zip(axs, [3,6,8,10,15]):
    OneLobe=LobeValues[0,range(i,interp)].reshape(1,interp-i)
    ax.imshow(OneLobe,cmap='coolwarm', vmin=-max(abs(LobeValues.T)),vmax=max(abs(LobeValues.T)))
    ax.grid(False)
    #ax.axis('off')
    ax.xaxis.set_ticks_position('none') 
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.yaxis.set_ticks_position('none')  
    i=interp

plt.show()
fig.savefig('ColorValenceVrev.svg')

# %% [markdown]
# ## Mating

# %%
# Tried to put it in the big model but tends to overfit. We know that mating was only avaluated with cVA,Fed, and different flies. It needs another model. The starvation/stimulus data should be independant. Only the lobes should be shared.
resmated = smf.ols(formula="df_f ~lobe+virgin_val", data=lobe_data[lobe_data.stimulus=="cVA"]).fit()
resmated.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     26.71
# Date:                Sun, 08 Mar 2020   Prob (F-statistic):           3.69e-63
# Time:                        18:37:34   Log-Likelihood:                -555.49
# No. Observations:                1020   AIC:                             1143.
# Df Residuals:                    1004   BIC:                             1222.
# Df Model:                          15
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.1725      0.052      3.298      0.001       0.070       0.275
# lobe[T.a2]      0.3599      0.072      4.991      0.000       0.218       0.501
# lobe[T.a3]      0.3059      0.072      4.243      0.000       0.164       0.447
# lobe[T.ap1]     0.4678      0.072      6.488      0.000       0.326       0.609
# lobe[T.ap2]     0.3395      0.072      4.708      0.000       0.198       0.481
# lobe[T.ap3]     0.7414      0.072     10.282      0.000       0.600       0.883
# lobe[T.b1]      0.1932      0.072      2.679      0.008       0.052       0.335
# lobe[T.b2]      0.5243      0.072      7.272      0.000       0.383       0.666
# lobe[T.bp1]     0.9877      0.072     13.698      0.000       0.846       1.129
# lobe[T.bp2]     0.3018      0.072      4.185      0.000       0.160       0.443
# lobe[T.g1]      0.1969      0.072      2.731      0.006       0.055       0.338
# lobe[T.g2]      0.4644      0.072      6.441      0.000       0.323       0.606
# lobe[T.g3]      0.4920      0.072      6.823      0.000       0.351       0.634
# lobe[T.g4]      0.1694      0.072      2.350      0.019       0.028       0.311
# lobe[T.g5]     -0.0322      0.072     -0.447      0.655      -0.174       0.109
# virgin_val     -0.1219      0.027     -4.599      0.000      -0.174      -0.070
# ==============================================================================
# Omnibus:                      491.172   Durbin-Watson:                   1.331
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4534.798
# Skew:                           1.994   Prob(JB):                         0.00
# Kurtosis:                      12.529   Cond. No.                         17.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Tried to put it in the big model but tends to overfit. We know that mating was only avaluated with cVA,Fed, and different flies. It needs another model. The starvation/stimulus data should be independant. Only the lobes should be shared.
resmated = smf.ols(formula="df_f ~ lobe+lobe:virgin_val", data=lobe_data[lobe_data.stimulus=="cVA"]).fit()
resmated.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     14.45
# Date:                Sun, 08 Mar 2020   Prob (F-statistic):           1.35e-57
# Time:                        18:37:35   Log-Likelihood:                -546.72
# No. Observations:                1020   AIC:                             1153.
# Df Residuals:                     990   BIC:                             1301.
# Df Model:                          29
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.1232      0.068      1.809      0.071      -0.010       0.257
# lobe[T.a2]               0.4250      0.096      4.413      0.000       0.236       0.614
# lobe[T.a3]               0.4022      0.096      4.176      0.000       0.213       0.591
# lobe[T.ap1]              0.5102      0.096      5.297      0.000       0.321       0.699
# lobe[T.ap2]              0.4061      0.096      4.217      0.000       0.217       0.595
# lobe[T.ap3]              0.8718      0.096      9.052      0.000       0.683       1.061
# lobe[T.b1]               0.1921      0.096      1.994      0.046       0.003       0.381
# lobe[T.b2]               0.5431      0.096      5.639      0.000       0.354       0.732
# lobe[T.bp1]              1.1515      0.096     11.957      0.000       0.963       1.341
# lobe[T.bp2]              0.3312      0.096      3.439      0.001       0.142       0.520
# lobe[T.g1]               0.1993      0.096      2.070      0.039       0.010       0.388
# lobe[T.g2]               0.5194      0.096      5.394      0.000       0.330       0.708
# lobe[T.g3]               0.5518      0.096      5.730      0.000       0.363       0.741
# lobe[T.g4]               0.1843      0.096      1.914      0.056      -0.005       0.373
# lobe[T.g5]              -0.0362      0.096     -0.376      0.707      -0.225       0.153
# lobe[a1]:virgin_val     -0.0102      0.103     -0.099      0.921      -0.211       0.191
# lobe[a2]:virgin_val     -0.1576      0.103     -1.538      0.124      -0.359       0.044
# lobe[a3]:virgin_val     -0.2283      0.103     -2.227      0.026      -0.429      -0.027
# lobe[ap1]:virgin_val    -0.1061      0.103     -1.034      0.301      -0.307       0.095
# lobe[ap2]:virgin_val    -0.1613      0.103     -1.574      0.116      -0.363       0.040
# lobe[ap3]:virgin_val    -0.3056      0.103     -2.981      0.003      -0.507      -0.104
# lobe[b1]:virgin_val     -0.0076      0.103     -0.074      0.941      -0.209       0.194
# lobe[b2]:virgin_val     -0.0527      0.103     -0.514      0.607      -0.254       0.148
# lobe[bp1]:virgin_val    -0.3815      0.103     -3.721      0.000      -0.583      -0.180
# lobe[bp2]:virgin_val    -0.0768      0.103     -0.750      0.454      -0.278       0.124
# lobe[g1]:virgin_val     -0.0157      0.103     -0.153      0.878      -0.217       0.186
# lobe[g2]:virgin_val     -0.1348      0.103     -1.315      0.189      -0.336       0.066
# lobe[g3]:virgin_val     -0.1457      0.103     -1.421      0.155      -0.347       0.055
# lobe[g4]:virgin_val     -0.0438      0.103     -0.427      0.669      -0.245       0.157
# lobe[g5]:virgin_val     -0.0013      0.103     -0.012      0.990      -0.202       0.200
# ==============================================================================
# Omnibus:                      488.268   Durbin-Watson:                   1.315
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4495.897
# Skew:                           1.979   Prob(JB):                         0.00
# Kurtosis:                      12.493   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
err_series = resmated.params - resmated.conf_int(alpha=0.01)[0]
coef_df = pd.DataFrame({'coef': -resmated.params.values[len(resmated.params)-15:len(resmated.params)],
                        'err': err_series.values[len(resmated.params)-15:len(resmated.params)],
                        'varname': err_series.index.values[len(resmated.params)-15:len(resmated.params)]
                       })

fig, ax = plt.subplots(figsize=(12, 5))
coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', legend=False)

ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, 
           y=coef_df['coef'], color='black')

ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(LobesGreek, 
                       rotation=0, fontsize=20)
ax.set_title("Mating coefficients", fontsize=22)
plt.show()
fig.savefig('MatingCoefficients.svg')
fig.savefig('MatingCoefficients.png')

# %%
print(lobes)
#plt.imshow(np.array(res4.params[30+31:30+31+14]).reshape(1,14), cmap='seismic',vmin=-0.18,vmax=+0.18)
LobeValues=np.array(resmated.params[len(resmated.params)-15:len(resmated.params)]).reshape(1,15)
#LobeValues=np.array(resmated.params[len(resmated.params)-15:len(resmated.params)]).reshape(1,15)
plt.imshow(-LobeValues, cmap='Greens', vmin=min(-LobeValues.T),vmax=max(-LobeValues.T))
plt.colorbar()
plt.savefig('ColorMatedColorbar.svg')
# Out:
# ['a1' 'a2' 'a3' 'ap1' 'ap2' 'ap3' 'b1' 'b2' 'bp1' 'bp2' 'g1' 'g2' 'g3'
#  'g4' 'g5']

# %%
fig, axs = plt.subplots(5, 1, figsize=(10, 3))
i=0
for ax, interp in zip(axs, [3,6,8,10,15]):
    OneLobe=LobeValues[0,range(i,interp)].reshape(1,interp-i)
    ax.imshow(-OneLobe, cmap='Greens',vmin=min(-LobeValues.T),vmax=max(-LobeValues.T))
    ax.grid(False)
    #ax.axis('off')
    ax.xaxis.set_ticks_position('none') 
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.yaxis.set_ticks_position('none')  
    i=interp

plt.show()
fig.savefig('ColorMated.svg')

# %% [markdown]
# ### Baseline variability

# %%
#preSTD
pre_std_mean=np.zeros((1,15))
for i in range(15):
    Lobe_lobe_data=lobe_data[lobe_data['lobe']==Lobes[i]]
    pre_std_mean[0,i]=np.mean(Lobe_lobe_data["single_pre_amp"])
    
#plt.imshow(np.array(res4.params[30+31:30+31+14]).reshape(1,14), cmap='seismic',vmin=-0.18,vmax=+0.18)
plt.imshow(pre_std_mean, cmap='Blues',vmin=0)
plt.colorbar()
plt.savefig('ColorPrestdColorbar.svg')

# %%
fig, axs = plt.subplots(5, 1, figsize=(10, 3))
i=0
for ax, interp in zip(axs, [3,6,8,10,15]):
    OneLobe=pre_std_mean[0,range(i,interp)].reshape(1,interp-i)
    ax.imshow(OneLobe, cmap='Blues', vmin=0,vmax=max(abs(pre_std_mean.T)))
    ax.grid(False)
    #ax.axis('off')
    ax.xaxis.set_ticks_position('none') 
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.yaxis.set_ticks_position('none')  
    i=interp

plt.show()
fig.savefig('ColorPreAmp.svg')

# %% [markdown]
# # Spontaneous activity

# %%
# Tried to put it in the big model but tends to overfit. We know that mating was only avaluated with cVA,Fed, and different flies. It needs another model. The starvation/stimulus data should be independant. Only the lobes should be shared.
resspont= smf.ols(formula="single_pre_amp ~ lobe-1", data=lobe_data).fit()
resspont.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         single_pre_amp   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     84.15
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):          6.27e-219
# Time:                        17:31:41   Log-Likelihood:                 4772.8
# No. Observations:                5430   AIC:                            -9516.
# Df Residuals:                    5415   BIC:                            -9417.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lobe[a1]       0.2516      0.005     47.578      0.000       0.241       0.262
# lobe[a2]       0.2181      0.005     41.243      0.000       0.208       0.228
# lobe[a3]       0.2637      0.005     49.876      0.000       0.253       0.274
# lobe[ap1]      0.3062      0.005     57.900      0.000       0.296       0.317
# lobe[ap2]      0.1923      0.005     36.375      0.000       0.182       0.203
# lobe[ap3]      0.2188      0.005     41.383      0.000       0.208       0.229
# lobe[b1]       0.2038      0.005     38.533      0.000       0.193       0.214
# lobe[b2]       0.2118      0.005     40.054      0.000       0.201       0.222
# lobe[bp1]      0.1502      0.005     28.414      0.000       0.140       0.161
# lobe[bp2]      0.2518      0.005     47.611      0.000       0.241       0.262
# lobe[g1]       0.2569      0.005     48.589      0.000       0.247       0.267
# lobe[g2]       0.2698      0.005     51.028      0.000       0.259       0.280
# lobe[g3]       0.2466      0.005     46.630      0.000       0.236       0.257
# lobe[g4]       0.1531      0.005     28.946      0.000       0.143       0.163
# lobe[g5]       0.1383      0.005     26.159      0.000       0.128       0.149
# ==============================================================================
# Omnibus:                     2031.740   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11173.594
# Skew:                           1.704   Prob(JB):                         0.00
# Kurtosis:                       9.146   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
err_series = resspont.params - resspont.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': resspont.params.values,
                        'err': err_series.values,
                        'varname': err_series.index.values
                       })

fig, ax = plt.subplots(figsize=(12, 5))
coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', legend=False)

ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, 
           y=coef_df['coef'], color='black')

#ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(LobesGreek, 
                       rotation=0, fontsize=20)
ax.set_title("Baseline deviations coefficients", fontsize=22)
plt.show()
fig.savefig('CoefficientsSpontaneous_98CIV2.svg')
fig.savefig('CoefficientsSpontaneous_98CIV2.png')

# %%
dff_mean_spont=np.zeros((1,15))
dff_mean_spont=np.array(resspont.params[0:15]).reshape(1,15)
    
#plt.imshow(np.array(res4.params[30+31:30+31+14]).reshape(1,14), cmap='seismic',vmin=-0.18,vmax=+0.18)
plt.imshow(dff_mean_spont,cmap='Blues', vmin=0,vmax=max(abs(dff_mean_spont.T)))
plt.colorbar()
plt.savefig('ColordffSpontColorbar.svg')

fig, axs = plt.subplots(5, 1, figsize=(10, 3))
i=0
for ax, interp in zip(axs, [3,6,8,10,15]):
    OneLobe=dff_mean_spont[0,range(i,interp)].reshape(1,interp-i)
    ax.imshow(OneLobe, cmap='Blues', vmin=0,vmax=max(abs(dff_mean_spont.T)))
    ax.grid(False)
    #ax.axis('off')
    ax.xaxis.set_ticks_position('none') 
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.yaxis.set_ticks_position('none')  
    i=interp

plt.show()
fig.savefig('ColorDffSpont.svg')

# %%
# Tried to put it in the big model but tends to overfit. We know that mating was only avaluated with cVA,Fed, and different flies. It needs another model. The starvation/stimulus data should be independant. Only the lobes should be shared.
resmatedpre = smf.ols(formula="single_pre_amp ~ lobe+lobe:virgin_val", data=lobe_data[lobe_data.stimulus=="cVA"]).fit()
resmatedpre.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         single_pre_amp   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     14.89
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           2.04e-59
# Time:                        17:34:46   Log-Likelihood:                 1064.6
# No. Observations:                1020   AIC:                            -2069.
# Df Residuals:                     990   BIC:                            -1921.
# Df Model:                          29
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.2313      0.014     16.487      0.000       0.204       0.259
# lobe[T.a2]              -0.0412      0.020     -2.076      0.038      -0.080      -0.002
# lobe[T.a3]               0.0470      0.020      2.371      0.018       0.008       0.086
# lobe[T.ap1]              0.0908      0.020      4.575      0.000       0.052       0.130
# lobe[T.ap2]             -0.0303      0.020     -1.526      0.127      -0.069       0.009
# lobe[T.ap3]             -0.0269      0.020     -1.356      0.176      -0.066       0.012
# lobe[T.b1]              -0.0471      0.020     -2.372      0.018      -0.086      -0.008
# lobe[T.b2]              -0.0164      0.020     -0.827      0.408      -0.055       0.023
# lobe[T.bp1]             -0.0712      0.020     -3.587      0.000      -0.110      -0.032
# lobe[T.bp2]             -0.0171      0.020     -0.860      0.390      -0.056       0.022
# lobe[T.g1]               0.0835      0.020      4.211      0.000       0.045       0.122
# lobe[T.g2]               0.0390      0.020      1.967      0.049    9.38e-05       0.078
# lobe[T.g3]               0.0450      0.020      2.270      0.023       0.006       0.084
# lobe[T.g4]              -0.1015      0.020     -5.117      0.000      -0.140      -0.063
# lobe[T.g5]              -0.1143      0.020     -5.759      0.000      -0.153      -0.075
# lobe[a1]:virgin_val      0.0077      0.021      0.363      0.717      -0.034       0.049
# lobe[a2]:virgin_val     -0.0124      0.021     -0.588      0.557      -0.054       0.029
# lobe[a3]:virgin_val      0.0066      0.021      0.311      0.756      -0.035       0.048
# lobe[ap1]:virgin_val    -0.0233      0.021     -1.101      0.271      -0.065       0.018
# lobe[ap2]:virgin_val    -0.0339      0.021     -1.602      0.109      -0.075       0.008
# lobe[ap3]:virgin_val    -0.0173      0.021     -0.821      0.412      -0.059       0.024
# lobe[b1]:virgin_val     -0.0168      0.021     -0.796      0.426      -0.058       0.025
# lobe[b2]:virgin_val      0.0020      0.021      0.093      0.926      -0.039       0.043
# lobe[bp1]:virgin_val     0.0010      0.021      0.047      0.963      -0.040       0.042
# lobe[bp2]:virgin_val     0.0051      0.021      0.239      0.811      -0.036       0.047
# lobe[g1]:virgin_val     -0.0655      0.021     -3.102      0.002      -0.107      -0.024
# lobe[g2]:virgin_val      0.0102      0.021      0.482      0.630      -0.031       0.052
# lobe[g3]:virgin_val     -0.0014      0.021     -0.067      0.947      -0.043       0.040
# lobe[g4]:virgin_val      0.0284      0.021      1.346      0.178      -0.013       0.070
# lobe[g5]:virgin_val      0.0282      0.021      1.337      0.181      -0.013       0.070
# ==============================================================================
# Omnibus:                      200.218   Durbin-Watson:                   1.774
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              445.634
# Skew:                           1.082   Prob(JB):                     1.71e-97
# Kurtosis:                       5.409   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
aov_table = anova_lm(resmatedpre, typ=2)
print(resmatedpre.rsquared)
print(100*(aov_table.sum_sq.values[1]+aov_table.sum_sq.values[2])/sum(aov_table.sum_sq.values))
aov_table
# Out:
# 0.30375265763894166
# 70.97407873122897
#                    sum_sq     df          F        PR(>F)
# lobe             3.087518   14.0  29.480145  1.745632e-65
# lobe:virgin_val  0.143531   15.0   1.279096  2.080239e-01
# Residual         7.406058  990.0        NaN           NaN

# %%
err_series = resmated.params - resmated.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': -resmated.params.values[len(resmated.params)-15:len(resmated.params)],
                        'err': err_series.values[len(resmated.params)-15:len(resmated.params)],
                        'varname': err_series.index.values[len(resmated.params)-15:len(resmated.params)]
                       })

fig, ax = plt.subplots(figsize=(12, 5))
coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', legend=False)

ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, 
           y=coef_df['coef'], color='black')

ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(LobesGreek, 
                       rotation=0, fontsize=20)
ax.set_title("Mating coefficients (baseline)", fontsize=22)
plt.show()
fig.savefig('MatingCoefficientsSpontaneous_98CIV2.svg')
fig.savefig('MatingCoefficientsSpontaneous_98CIV2.png')

# %%
# Tried to put it in the big model but tends to overfit. We know that mating was only avaluated with cVA,Fed, and different flies. It needs another model. The starvation/stimulus data should be independant. Only the lobes should be shared.
resStarvedSpont = smf.ols(formula="single_pre_amp ~ lobe+lobe:hours_starved", data=lobe_data[lobe_data]).fit()
resStarvedSpont.summary()
aov_table = anova_lm(resStarvedSpont, typ=2)
print(resmatedpre.rsquared)
print(100*(aov_table.sum_sq.values[1]+aov_table.sum_sq.values[2])/sum(aov_table.sum_sq.values))
aov_table
# Out:
# 0.30375265763894166
# 82.13178252137352
#                        sum_sq      df          F         PR(>F)
# lobe                11.924150    14.0  84.513828  8.925207e-220
# lobe:hours_starved   0.388845    15.0   2.572255   7.626325e-04
# Residual            54.420858  5400.0        NaN            NaN

# %%
err_series = resStarvedSpont.params - resStarvedSpont.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': resStarvedSpont.params.values[len(resStarvedSpont.params)-15:len(resStarvedSpont.params)],
                        'err': err_series.values[len(resStarvedSpont.params)-15:len(resStarvedSpont.params)],
                        'varname': err_series.index.values[len(resStarvedSpont.params)-15:len(resStarvedSpont.params)]
                       })

fig, ax = plt.subplots(figsize=(12, 5))
coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', legend=False)

ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, 
           y=coef_df['coef'], color='black')

ax.axhline(y=0, linestyle='--', color='black', linewidth=2)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(LobesGreek, 
                       rotation=0, fontsize=20)
ax.set_title("Starvation coefficients (baseline)", fontsize=22)
plt.show()
fig.savefig('StarvationCoefficientsSpontaneous_98CIV2.svg')
fig.savefig('StarvationCoefficientsSpontaneous_98CIV2.png')

# %% [markdown]
# ### Coefficients for Walking

# %% [markdown]
# Obtained from light field data sets

# %%
Lobes_walk=[0.01185791, 0.00786684, 0.00831484, 0.01032995, 0.00741971,
       0.01087686, 0.02580228, 0.02794888, 0.02756843, 0.04469564,
       0.0187518 , 0.01637661, 0.0456082 , 0.05365562, 0.03737648]

# %%
#Valence pos
print(lobes)
#plt.imshow(np.array(res4.params[30+31:30+31+14]).reshape(1,14), cmap='seismic',vmin=-0.18,vmax=+0.18)
LobeValues=np.array(Lobes_walk).reshape(1,15)
plt.imshow(LobeValues, cmap='Reds', vmin=0,vmax=np.max(LobeValues))
plt.colorbar()
plt.savefig('ColorWalkColorbar.svg')
# Out:
# ['a1' 'a2' 'a3' 'ap1' 'ap2' 'ap3' 'b1' 'b2' 'bp1' 'bp2' 'g1' 'g2' 'g3'
#  'g4' 'g5']

# %%
fig, axs = plt.subplots(5, 1, figsize=(10, 3))
i=0
for ax, interp in zip(axs, [3,6,8,10,15]):
    OneLobe=LobeValues[0,range(i,interp)].reshape(1,interp-i)
    ax.imshow(OneLobe, cmap='Reds', vmin=0,vmax=max(LobeValues.T))
    ax.grid(False)
    #ax.axis('off')
    ax.xaxis.set_ticks_position('none') 
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.yaxis.set_ticks_position('none')  
    i=interp

plt.show()
fig.savefig('ColorWalk.svg')

# %% [markdown]
# # Taste

# %%
data_tastequi=pd.read_excel("Taste_data.xlsx",'quinine').transpose()

data_tastesuc=pd.read_excel("Taste_data.xlsx",'sucrose').transpose()

db1=data_tastesuc.stack().reset_index()

db2=data_tastequi.stack().reset_index()

#taste_mean=pd.concat([suc_mean,qui_mean], ignore_index=True, sort=False)

db2['taste']='quinine'
db1['taste']='sucrose'

data_taste = pd.concat([db1, db2], ignore_index=True, sort=False)

data_taste.columns = ['lobe', 'num','df_f','taste']

data_taste['df_f_norm']=0
data_taste['norm']=0

Nums=[170,110,29,177,176,173,188,151,174,175,168,170]

for taste in ['quinine', 'sucrose']:
    for i in Nums:
        if any((data_taste['num']==i) & (data_taste['taste']==taste)):
            subData=data_taste[data_taste['num']==i][data_taste['taste']==taste]
            Norm=np.float(subData[subData['lobe']=='Mean'].df_f)
            data_taste.loc[(data_taste['num']==i) & (data_taste['taste']==taste),'Mean']=Norm


data_taste.df_f_norm=data_taste.df_f/data_taste.norm
# Out:
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\aimon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# Tried to put it in the big model but tends to overfit. We know that mating was only avaluated with cVA,Fed, and different flies. It needs another model. The starvation/stimulus data should be independant. Only the lobes should be shared.
resTaste = smf.ols(formula="df_f~Mean+lobe+lobe:taste-1", data=data_taste).fit()
resTaste.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.711
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     18.40
# Date:                Sun, 08 Mar 2020   Prob (F-statistic):           6.10e-48
# Time:                        18:10:34   Log-Likelihood:                 620.46
# No. Observations:                 272   AIC:                            -1175.
# Df Residuals:                     239   BIC:                            -1056.
# Df Model:                          32
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# lobe[Mean]                     -0.0004      0.009     -0.049      0.961      -0.018       0.017
# lobe[a1]                       -0.0209      0.009     -2.209      0.028      -0.040      -0.002
# lobe[a2]                       -0.0024      0.009     -0.251      0.802      -0.021       0.016
# lobe[a3]                       -0.0079      0.011     -0.731      0.466      -0.029       0.013
# lobe[ap1]                       0.0224      0.009      2.364      0.019       0.004       0.041
# lobe[ap2]                       0.0014      0.009      0.151      0.880      -0.017       0.020
# lobe[ap3]                      -0.0171      0.011     -1.571      0.118      -0.038       0.004
# lobe[b1]                       -0.0142      0.009     -1.587      0.114      -0.032       0.003
# lobe[b2]                        0.0037      0.009      0.416      0.678      -0.014       0.021
# lobe[bp1]                       0.0033      0.009      0.352      0.726      -0.015       0.022
# lobe[bp2]                       0.0187      0.009      1.970      0.050    9.42e-07       0.037
# lobe[g1]                        0.0068      0.010      0.676      0.500      -0.013       0.027
# lobe[g2]                        0.0203      0.009      2.146      0.033       0.002       0.039
# lobe[g3]                       -0.0031      0.009     -0.323      0.747      -0.022       0.016
# lobe[g4]                       -0.0116      0.009     -1.227      0.221      -0.030       0.007
# lobe[g5]                        0.0008      0.009      0.087      0.931      -0.018       0.019
# lobe[Mean]:taste[T.sucrose] -8.088e-05      0.012     -0.007      0.995      -0.024       0.024
# lobe[a1]:taste[T.sucrose]       0.0117      0.013      0.911      0.363      -0.014       0.037
# lobe[a2]:taste[T.sucrose]      -0.0210      0.013     -1.677      0.095      -0.046       0.004
# lobe[a3]:taste[T.sucrose]      -0.0096      0.014     -0.675      0.501      -0.038       0.018
# lobe[ap1]:taste[T.sucrose]     -0.0411      0.013     -3.205      0.002      -0.066      -0.016
# lobe[ap2]:taste[T.sucrose]     -0.0251      0.013     -2.007      0.046      -0.050      -0.000
# lobe[ap3]:taste[T.sucrose]     -0.0038      0.014     -0.265      0.791      -0.032       0.024
# lobe[b1]:taste[T.sucrose]       0.0111      0.012      0.912      0.363      -0.013       0.035
# lobe[b2]:taste[T.sucrose]       0.0396      0.012      3.266      0.001       0.016       0.063
# lobe[bp1]:taste[T.sucrose]     -0.0180      0.013     -1.407      0.161      -0.043       0.007
# lobe[bp2]:taste[T.sucrose]      0.0272      0.013      2.122      0.035       0.002       0.052
# lobe[g1]:taste[T.sucrose]      -0.0318      0.014     -2.323      0.021      -0.059      -0.005
# lobe[g2]:taste[T.sucrose]      -0.0319      0.013     -2.489      0.014      -0.057      -0.007
# lobe[g3]:taste[T.sucrose]      -0.0023      0.013     -0.180      0.857      -0.028       0.023
# lobe[g4]:taste[T.sucrose]       0.0197      0.013      1.535      0.126      -0.006       0.045
# lobe[g5]:taste[T.sucrose]       0.0641      0.013      4.998      0.000       0.039       0.089
# Mean                            1.0142      0.050     20.212      0.000       0.915       1.113
# ==============================================================================
# Omnibus:                      154.573   Durbin-Watson:                   2.400
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2172.147
# Skew:                           1.951   Prob(JB):                         0.00
# Kurtosis:                      16.283   Cond. No.                         9.70
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
err_series = resTaste.params - resTaste.conf_int(alpha=0.02)[0]
coef_df = pd.DataFrame({'coef': resTaste.params.values[len(resTaste.params)-16:len(resTaste.params)-1],
                        'err': err_series.values[len(resTaste.params)-16:len(resTaste.params)-1],
                        'varname': err_series.index.values[len(resTaste.params)-16:len(resTaste.params)-1]
                       })

fig, ax = plt.subplots(figsize=(12, 5))
coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', legend=False)

ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Compartment', fontsize=20)

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, 
           y=coef_df['coef'], color='black')

ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
_ = ax.set_xticklabels(LobesGreek, 
                       rotation=0, fontsize=20)
ax.set_title("Tastingcoefficients", fontsize=22)
plt.show()
fig.savefig('TastingCoefficients.svg')

# %%
np.max(LobeValues)

# %%
#plt.imshow(np.array(res4.params[30+31:30+31+14]).reshape(1,14), cmap='seismic',vmin=-0.18,vmax=+0.18)
LobeValues=np.array(resTaste.params[len(resTaste.params)-16:len(resTaste.params)-1]).reshape(1,15)
#LobeValues=np.array(resmated.params[len(resmated.params)-15:len(resmated.params)]).reshape(1,15)
Vmax=np.max([np.max(-LobeValues),np.max(LobeValues)])
plt.imshow(LobeValues, cmap='coolwarm', vmin=-Vmax,vmax=Vmax)
plt.colorbar()
plt.savefig('ColorTasteColorbar.svg')
fig, axs = plt.subplots(5, 1, figsize=(10, 3))
i=0
for ax, interp in zip(axs, [3,6,8,10,15]):
    OneLobe=LobeValues[0,range(i,interp)].reshape(1,interp-i)
    ax.imshow(OneLobe,cmap='coolwarm', vmin=-Vmax,vmax=Vmax)
    ax.grid(False)
    #ax.axis('off')
    ax.xaxis.set_ticks_position('none') 
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.yaxis.set_ticks_position('none')  
    i=interp

plt.show()
fig.savefig('ColorTaste.svg')

# %% [markdown]
# ## Interactions between starvation and stimuli

# %%
fig, ax = plt.subplots(figsize=(12, 5))

resnoidb = smf.ols(formula="df_f ~ stimulus:starved+lobe*(stimulus+order_presented+dorsal_to_ventral_val)+lobe:starved-1", data=lobe_data).fit()
Stimuli=[s[9:len(s)-9] for s in resnoidb.params.index.values[len(resnoidb.params)-56:len(resnoidb.params)-57+12]]

err_series = resnoidb.params - resnoidb.conf_int()[0]
coef_df = pd.DataFrame({'coef': resnoidb.params[len(resnoidb.params)-56:len(resnoidb.params)-57+12],
                        'err': err_series.values[len(resnoidb.params)-56:len(resnoidb.params)-57+12],
                        'varname': err_series.index.values[len(resnoidb.params)-56:len(resnoidb.params)-57+12]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err',  ecolor='blue',
             label="")

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, 
           y=coef_df['coef'],label="Full model no ID")

########
resstarvestim = smf.ols(formula="df_f ~ lobe+starved:stimulus", data=lobe_data).fit()

err_series = resstarvestim.params - resstarvestim.conf_int()[0]
coef_df = pd.DataFrame({'coef': resstarvestim.params[len(resstarvestim.params)-12:len(resstarvestim.params)-1],
                        'err': err_series.values[len(resstarvestim.params)-12:len(resstarvestim.params)-1],
                        'varname': err_series.index.values[len(resstarvestim.params)-12:len(resstarvestim.params)-1]
                       })


coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', ecolor='orange',
             label="")

ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=120, 
           y=coef_df['coef'],label="Minimal model")

ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')

_ = ax.set_xticklabels(Stimuli, fontsize=20)
ax.set_title("Stimuli specific starvation coefficients", fontsize=22)
leg = ax.legend(loc='upper right', fancybox=True, fontsize=20)
ax.set_ylabel('Regression coefficient', fontsize=20)
ax.set_xlabel('Odor', fontsize=20)

plt.show()
fig.savefig('StimulivsStarvation.svg')

# %%
resstarvestim.summary()
# Out:
# C:\Users\aimon\Anaconda3\lib\site-packages\statsmodels\base\model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\aimon\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\aimon\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\aimon\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   df_f   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.243
# Method:                 Least Squares   F-statistic:                     70.61
# Date:                Tue, 10 Mar 2020   Prob (F-statistic):          4.42e-308
# Time:                        15:38:26   Log-Likelihood:                -3225.5
# No. Observations:                5430   AIC:                             6503.
# Df Residuals:                    5404   BIC:                             6675.
# Df Model:                          25
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            0.1359      0.024      5.720      0.000       0.089       0.182
# lobe[T.a2]                           0.2088      0.033      6.394      0.000       0.145       0.273
# lobe[T.a3]                           0.2453      0.033      7.511      0.000       0.181       0.309
# lobe[T.ap1]                          0.3101      0.033      9.497      0.000       0.246       0.374
# lobe[T.ap2]                          0.2012      0.033      6.161      0.000       0.137       0.265
# lobe[T.ap3]                          0.6560      0.033     20.088      0.000       0.592       0.720
# lobe[T.b1]                           0.3267      0.033     10.005      0.000       0.263       0.391
# lobe[T.b2]                           0.5223      0.033     15.994      0.000       0.458       0.586
# lobe[T.bp1]                          0.9422      0.033     28.853      0.000       0.878       1.006
# lobe[T.bp2]                          0.5145      0.033     15.755      0.000       0.450       0.578
# lobe[T.g1]                           0.2565      0.033      7.856      0.000       0.193       0.321
# lobe[T.g2]                           0.3322      0.033     10.173      0.000       0.268       0.396
# lobe[T.g3]                           0.6166      0.033     18.883      0.000       0.553       0.681
# lobe[T.g4]                           0.4541      0.033     13.907      0.000       0.390       0.518
# lobe[T.g5]                           0.0278      0.033      0.851      0.395      -0.036       0.092
# starved:stimulus[1-Hexanol]          0.0314      0.018      1.743      0.081      -0.004       0.067
# starved:stimulus[2-Heptanone]       -0.0035      0.017     -0.210      0.834      -0.037       0.030
# starved:stimulus[3Octanol]           0.0942      0.020      4.664      0.000       0.055       0.134
# starved:stimulus[4MCH]               0.1929      0.020      9.803      0.000       0.154       0.231
# starved:stimulus[Citronella]         0.0112      0.013      0.829      0.407      -0.015       0.038
# starved:stimulus[Ethanol]           -0.0131      0.022     -0.599      0.550      -0.056       0.030
# starved:stimulus[Geosmin]           -0.0544      0.024     -2.312      0.021      -0.100      -0.008
# starved:stimulus[Isoamylacetate]     0.0143      0.017      0.830      0.406      -0.020       0.048
# starved:stimulus[Peppermint]         0.0744      0.018      4.023      0.000       0.038       0.111
# starved:stimulus[Vinegar]            0.0058      0.014      0.418      0.676      -0.021       0.033
# starved:stimulus[Yeast]              0.0461      0.014      3.362      0.001       0.019       0.073
# starved:stimulus[cVA]                     0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                     1826.437   Durbin-Watson:                   1.447
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9025.392
# Skew:                           1.545   Prob(JB):                         0.00
# Kurtosis:                       8.508   Cond. No.                     1.07e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.42e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ## Extra stuff

# %%
#resadapt = smf.ols(formula="adaptnorm ~ C(lobe)*stimulus", data=lobe_data).fit()
#resadapt.summary()

# %%
## Also play with mixed models in R

import rpy2
from rpy2.robjects import r, pandas2ri
pandas2ri.activate()

r_lobe_data = pandas2ri.py2ri(lobe_data)

# %load_ext rpy2.ipython
# %Rpush lobe_data

# %%R

#library(lmerTest)
library(lme4)
#library(MuMIn) 
m_rt <- lmer(df_f ~ lobe*(order_presented+ dorsal_to_ventral)+lobe*stimulus+valence)+(1|valence)+(1|valence:lobe)+(lobe-1):hours_starved-1,data = lobe_data)

rfs <- ranef(m_rt)
ffs <- fixef(m_rt) 

# Jarret Byrnes (correlation between the fitted and the observed values)
r2.corr.mer <- function(m) {
   lmfit <-  lm(model.response(model.frame(m)) ~ fitted(m))
   summary(lmfit)$r.squared
}
r2.corr.mer(m_rt)

# Xu 2003
Res=1-var(residuals(m_rt))/(var(model.response(model.frame(m_rt))))

#Res=var(predict(mod1,newdata=lobe_data, re.form=~0))
Summixedmod=summary(m_rt)


# Nakagawa & Schielzeth's (2013)
#R2[2]=r.squaredGLMM(m_rt)

# %%R
plot(m_rt)

# %%R
library(lme4)

Summixedmod=summary(m_rt)
anovamixed=anova(m_rt)
capture.output(Summixedmod, file = "SummaryMixModel.txt")
capture.output(anovamixed, file = "anova results.txt")
capture.output(ffs, file = "Fixed.txt")
capture.output(rfs, file = "Random.txt")
capture.output(Res, file = "R2.txt")

# %% [markdown]
# Mixed models for valence and stimuli

# %%
md = smf.mixedlm("df_f ~ lobe*(stimulus+order_presented+C(dorsal_to_ventral))+(lobe-1):hours_starved-1", lobe_data, groups=lobe_data["valence"],missing='drop')
mdf = md.fit()
print(mdf.summary())

# %%
#Nested
vc = {'lv': 'lobe:valence'}
nestVal=smf.MixedLM.from_formula("df_f ~ lobe*(stimulus+order_presented+C(dorsal_to_ventral))+(lobe-1):hours_starved-1", vc_formula=vc,re_formula='1', groups='valence', data=lobe_data,missing='drop').fit()

print(nestVal.summary())

sum((mdf.predict(lobe_data[np.logical_or(lobe_data["valence"]==1,lobe_data["valence"]==-1)])-np.mean(mdf.predict(lobe_data[np.logical_or(lobe_data["valence"]==1,lobe_data["valence"]==-1)])))**2)/sum((lobe_data[np.logical_or(lobe_data["valence"]==1,lobe_data["valence"]==-1)]['df_f']-np.mean(lobe_data[np.logical_or(lobe_data["valence"]==1,lobe_data["valence"]==-1)]['df_f']))**2)
